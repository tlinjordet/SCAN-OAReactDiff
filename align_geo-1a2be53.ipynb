# %% [markdown]
# # Helper functions (and examples) to align (and view) molecules

# %%
from pymatgen.core import Molecule
from pymatgen.analysis import molecule_matcher

def align(base_atoms, target_atoms, threshold=0.5, allow_inversion=True, verbose=False):
    if verbose: print('Generating Pymatgen molecules from ASE atoms')
    target = Molecule.from_ase_atoms(target_atoms)
    base = Molecule.from_ase_atoms(base_atoms)
    if allow_inversion:
        inverted_base_atoms = base_atoms.copy()
        inverted_base_atoms.positions *= -1
        inverted_base = Molecule.from_ase_atoms(inverted_base_atoms)
    
    # Get initial guess
    if verbose: print('Computing initial guess via cheap and naive alignment')
    matcher_guess = molecule_matcher.HungarianOrderMatcher(target)
    aligned_guess, rmsd_guess = matcher_guess.fit(base)
    if allow_inversion:
        alt_aligned_guess, alt_rmsd_guess = matcher_guess.fit(inverted_base)
        # Swap structures if inversion yields better RMSD
        swap = (alt_rmsd_guess < rmsd_guess)
        if swap:
            rmsd_guess, alt_rmsd_guess = alt_rmsd_guess, rmsd_guess
            aligned_guess, alt_aligned_guess = alt_aligned_guess, aligned_guess
    if verbose: print(f'Hungarian-based alignment yielded: iRMSD={rmsd_guess}') 
    
    # Exact matcher
    effective_threshold = min(rmsd_guess+1e-3, threshold)
    if verbose: print(f'Attempting exact match with iRMSD threshold: {effective_threshold}')
    matcher = molecule_matcher.GeneticOrderMatcher(target, threshold=effective_threshold)
    results = matcher.fit(aligned_guess)
    
    # Extract best result
    if not results:
        results = [(aligned_guess, rmsd_guess)]
    aligned, rmsd = min(results, key=lambda x:x[-1])

    # Try alignment with alternative structure
    if allow_inversion:
        effective_threshold = min(rmsd+1e-3, threshold)
        if verbose: print(f'Re-attempting exact match w/wo inversion with iRMSD threshold: {effective_threshold}')
        matcher.threshold = effective_threshold
        alt_results = matcher.fit(alt_aligned_guess)
        if not alt_results:
            alt_results = [(alt_aligned_guess, alt_rmsd_guess)]
        alt_aligned, alt_rmsd = min(alt_results, key=lambda x:x[-1])
        # Report w/wo inversion
        if (alt_rmsd < rmsd) ^ swap:
            print('Info: Best alignment requires inversion/reflection')
        # Swap results if alternative yields better RMSD
        if alt_rmsd < rmsd:
            rmsd, alt_rmsd = alt_rmsd, rmsd
            aligned, alt_aligned = alt_aligned, aligned
    
    if rmsd <= threshold:
        if verbose: print(f'Best alignment found with iRMSD={rmsd}')
    else:
        if verbose: print(f'Could not find alignment below iRMSD threshold {threshold}')
        rmsd = None
    return(aligned.to_ase_atoms(), rmsd)

# %%
def get_baseline_threshold(ts_ref, reactant_ref, product_ref, threshold=float('inf'), verbose=False, strict=True):
    # Align reactants with TS
    aligned_reactants, rmsd_reactants = align(reactant_ref, ts_ref, threshold=threshold, verbose=verbose)

    # Align products with TS, using improved threshold guess
    if strict:
        effective_threshold = min(threshold, rmsd_reactants+1e-3) if rmsd_reactants is not None else threshold
    else:
        effective_threshold = threshold
    aligned_products, rmsd_products = align(product_ref, ts_ref, threshold=effective_threshold, verbose=verbose)

    # Compile adapted threshold
    all_baseline_thresholds = [rmsd+1e-3 for rmsd in [rmsd_reactants, rmsd_products] if rmsd is not None]
    if len(all_baseline_thresholds) == 0:
        baseline_threshold = None
    else:
        baseline_threshold = min(all_baseline_thresholds) if strict else max(all_baseline_thresholds) 
    return(baseline_threshold, aligned_reactants, aligned_products)

# %%
def extract_comments(atoms):
    comments = ' '.join(key if value is True else key+'='+value for key, value in atoms.info.items())
    return(comments)

# %%
import ase.io

def write_all_aligned(input_path, output_path, index_target=0, threshold=0.5, allow_inversion=True, verbose=False):
    if verbose: print(f'Reading geometries from {input_path}')
    all_atoms = ase.io.read(input_path, index=':')

    if verbose: print(f'Aligning all {len(all_atoms)} geometries found, w.r.t. to geometry {index_target}, using threshold {threshold}')
    target = all_atoms[index_target]
    all_comments = []
    for current_index, atoms in enumerate(all_atoms):
        # Extract comments
        comments = extract_comments(atoms)
        
        # Skip if reference geometry
        if current_index == index_target:
            all_comments.append(comments)
            continue

        # Compute and save aligned geometry
        aligned, rmsd = align(atoms, target, threshold=threshold, allow_inversion=allow_inversion, verbose=verbose)
        all_atoms[current_index] = aligned
        all_comments.append(f'{comments} (iRMSD={rmsd})')

    if verbose: print(f'Writing all {len(all_atoms)} aligned geometries to {output_path}')
    for current_index, (atoms, comment) in enumerate(zip(all_atoms, all_comments)):
        ase.io.write(output_path, atoms, comment=comment, append=(current_index > 0))

def write_all_aligned_opt(input_path, output_path, index_ts=1, index_reactants=0, index_products=2, threshold=float('inf'), strict_baseline=True, allow_inversion=True, verbose=False):
    if verbose: print(f'Reading geometries from {input_path}')
    all_atoms = ase.io.read(input_path, index=':')
    if verbose: print(f'Found {len(all_atoms)} geometries')

    if verbose: print(f'Estimate optimal threshold from EQ endpoints: {index_reactants} ← {index_ts} → {index_products}')
    ts = all_atoms[index_ts]
    reactants = all_atoms[index_reactants]
    products = all_atoms[index_products]
    baseline_threshold, aligned_reactants, aligned_products = get_baseline_threshold(ts, reactants, products, threshold=threshold, strict=strict_baseline, verbose=verbose)
    if baseline_threshold is None:
        print(f'Could not find EQ/TS alignment below given threshold {threshold}, using this threshold instead')
        baseline_threshold = threshold

    if verbose: print(f'Aligning all remaining geometries found, w.r.t. to geometry {index_ts}, using optimal threshold {baseline_threshold}')
    all_atoms[index_reactants] = aligned_reactants
    all_atoms[index_products] = aligned_products
    pre_aligned_idx = set([index_ts, index_reactants, index_products])
    all_comments = []
    for current_index, atoms in enumerate(all_atoms):
        # Extract comments
        comments = extract_comments(atoms)
        if verbose:
            print(f'Processing structure n°{current_index}')
        
        # Skip if pre-aligned geometry
        if current_index in pre_aligned_idx:
            all_comments.append(comments)
            continue

        # Compute and save aligned geometry
        aligned, rmsd = align(atoms, ts, threshold=baseline_threshold, allow_inversion=allow_inversion, verbose=verbose)
        all_atoms[current_index] = aligned
        all_comments.append(f'{comments} (iRMSD={rmsd})')

    output_path = output_path.replace('{baseline}', f'{baseline_threshold:.2f}')
    if verbose: print(f'Writing all {len(all_atoms)} aligned geometries to {output_path}')
    for current_index, (atoms, comment) in enumerate(zip(all_atoms, all_comments)):
        ase.io.write(output_path, atoms, comment=comment, append=(current_index > 0))

# %%
# conda install -c conda-forge ipywidgets nglview
from ase.visualize import view

def view_aligned(aligned, target):
    v = view(aligned+target, viewer='ngl')
    v.view.remove_spacefill()
    v.view.add_ball_and_stick(selection=range(len(aligned)), cylinderOnly=False, aspectRatio=3.0, radiusScale=0.2, radiusType='covalent')
    v.view.add_ball_and_stick(selection=range(len(aligned),len(aligned)+len(target)), cylinderOnly=False, aspectRatio=3.0, radiusScale=0.1, radiusType='covalent')
    return(v)

# %% [markdown]
# # Example on single pair for molecules to align and view

# %%
import ase.io

all_atoms = ase.io.read('/tmp/sample_selected_TS-20250806-SCAN-11-w_wo-w_wo-w_wo-vs_SCAN-9w_valid/rcmconly_passerini-TS17328.xyz', index=':')
target = all_atoms[1]
base = all_atoms[0]
base.positions *= 1
extract_comments(base)
# Out:
# 'True/calculated reference reactant state.'

# %%
aligned_base, rmsd = align(base, target, threshold=0.4, allow_inversion=False, verbose=True)
print(f'iRSMD={rmsd}')
# Out:
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=1.170921998857861
# Attempting exact match with iRMSD threshold: 0.4
# Best alignment found with iRMSD=0.06266470509572349
# iRSMD=0.06266470509572349

# %%
view_aligned(aligned_base, target)
# Out:
# HBox(children=(NGLWidget(), VBox(children=(Dropdown(description='Show', options=('All', 'O', 'C', 'H', 'N'), v…

# %% [markdown]
# # Example to produce aligned XYZs

# %%
input_path = '/tmp/sample_selected_TS-20250806-SCAN-11-w_wo-w_wo-w_wo-vs_SCAN-9w_valid/rcmconly_passerini-TS1206.xyz'
output_path = input_path.removesuffix('.xyz') + '_aligned.xyz'

write_all_aligned(input_path, output_path, index_target=1, threshold=0.5, verbose=True)
# Out:
# Reading geometries from /tmp/sample_selected_TS-20250806-SCAN-11-w_wo-w_wo-w_wo-vs_SCAN-9w_valid/rcmconly_passerini-TS1206.xyz
# Aligning all 33 geometries found, w.r.t. to geometry 1, using threshold 0.5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=1.0582529824556157
# Attempting exact match with iRMSD threshold: 0.5
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.5
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7283357248954305
# Attempting exact match with iRMSD threshold: 0.5
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.4773910091255308
# Best alignment found with iRMSD=0.4763910091255308
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.9456044284702051
# Attempting exact match with iRMSD threshold: 0.5
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.5
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.480288058285222
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7357048260268326
# Attempting exact match with iRMSD threshold: 0.5
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.4837266811250245
# Best alignment found with iRMSD=0.4827266811250245
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=75.12657752712718
# Attempting exact match with iRMSD threshold: 0.5
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.5
# Could not find alignment below iRMSD threshold 0.5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=1.158563859874816
# Attempting exact match with iRMSD threshold: 0.5
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.5
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.948972261909586
# Attempting exact match with iRMSD threshold: 0.5
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.5
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.9957542618518574
# Attempting exact match with iRMSD threshold: 0.5
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.5
# Could not find alignment below iRMSD threshold 0.5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5449785235950905
# Attempting exact match with iRMSD threshold: 0.5
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.438788103118587
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.437788103118587
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=3720651.2146356665
# Attempting exact match with iRMSD threshold: 0.5
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.5
# Could not find alignment below iRMSD threshold 0.5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.607682824473588
# Attempting exact match with iRMSD threshold: 0.5
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.5
# Could not find alignment below iRMSD threshold 0.5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.4884713696567894
# Attempting exact match with iRMSD threshold: 0.4894713696567894
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.48534276578427593
# Best alignment found with iRMSD=0.48434276578427593
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=1.125283106073019
# Attempting exact match with iRMSD threshold: 0.5
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.5
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=1.065557428316734
# Attempting exact match with iRMSD threshold: 0.5
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.5
# Could not find alignment below iRMSD threshold 0.5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.9578382228038771
# Attempting exact match with iRMSD threshold: 0.5
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.5
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=1.046622232702955
# Attempting exact match with iRMSD threshold: 0.5
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.5
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.8867872970012953
# Attempting exact match with iRMSD threshold: 0.5
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.5
# Could not find alignment below iRMSD threshold 0.5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.9780416892225148
# Attempting exact match with iRMSD threshold: 0.5
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.5
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5781593734429143
# Attempting exact match with iRMSD threshold: 0.5
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.5
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.8700574041833106
# Attempting exact match with iRMSD threshold: 0.5
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.5
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=1.030257103478397
# Attempting exact match with iRMSD threshold: 0.5
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.5
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5620411263690739
# Attempting exact match with iRMSD threshold: 0.5
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.5
# Could not find alignment below iRMSD threshold 0.5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.903408586057258
# Attempting exact match with iRMSD threshold: 0.5
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.5
# Could not find alignment below iRMSD threshold 0.5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.9516085065481537
# Attempting exact match with iRMSD threshold: 0.5
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.5
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.8664736483104221
# Attempting exact match with iRMSD threshold: 0.5
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.46653744856755375
# Best alignment found with iRMSD=0.46553744856755375
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=1.1028631332873264
# Attempting exact match with iRMSD threshold: 0.5
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.5
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.8600748891556304
# Attempting exact match with iRMSD threshold: 0.5
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.5
# Could not find alignment below iRMSD threshold 0.5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=1.023802026442521
# Attempting exact match with iRMSD threshold: 0.5
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.5
# Could not find alignment below iRMSD threshold 0.5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=358.6990052324066
# Attempting exact match with iRMSD threshold: 0.5
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.5
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=1.1504792190025317
# Attempting exact match with iRMSD threshold: 0.5
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.5
# Could not find alignment below iRMSD threshold 0.5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5859812196287298
# Attempting exact match with iRMSD threshold: 0.5
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.5
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7585841527333731
# Attempting exact match with iRMSD threshold: 0.5
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.47573511794256484
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.47473511794256484
# Writing all 33 aligned geometries to /tmp/sample_selected_TS-20250806-SCAN-11-w_wo-w_wo-w_wo-vs_SCAN-9w_valid/rcmconly_passerini-TS1206_aligned.xyz

# %%
v = view_aligned(aligned_base, target)
v

# %% [markdown]
# # Example to produce/view aligned XYZs (optimized)

# %%
import glob

for input_path in glob.glob('/tmp/sample_selected_TS-20250806-SCAN-11-w_wo-w_wo-w_wo-vs_SCAN-9w_valid/*[0-9].xyz'):
    # Use strict baseline
    output_path = input_path.removesuffix('.xyz') + '_aligned_baseline{baseline}_strict.xyz'
    write_all_aligned_opt(input_path, output_path, index_ts=1, index_reactants=0, index_products=2, threshold=1.0, strict_baseline=True, verbose=True)
    # Use loose baseline
    output_path = input_path.removesuffix('.xyz') + '_aligned_baseline{baseline}_loose.xyz'
    write_all_aligned_opt(input_path, output_path, index_ts=1, index_reactants=0, index_products=2, threshold=1.0, strict_baseline=False, verbose=True)
# Out:
# Reading geometries from /tmp/sample_selected_TS-20250806-SCAN-11-w_wo-w_wo-w_wo-vs_SCAN-9w_valid/WL1-TS11193.xyz
# Found 33 geometries
# Estimate optimal threshold from EQ endpoints: 0 ← 1 → 2
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.20079499811474927
# Attempting exact match with iRMSD threshold: 0.20179499811474927
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.19764742069855243
# Best alignment found with iRMSD=0.19664742069855243
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.4871225304794986
# Attempting exact match with iRMSD threshold: 0.19764742069855243
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.19764742069855243
# Best alignment found with iRMSD=0.07141106780287627
# Aligning all remaining geometries found, w.r.t. to geometry 1, using optimal threshold 0.07241106780287627
# Processing structure n°0
# Processing structure n°1
# Processing structure n°2
# Processing structure n°3
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.21980924197194987
# Attempting exact match with iRMSD threshold: 0.07241106780287627
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.07241106780287627
# Could not find alignment below iRMSD threshold 0.07241106780287627
# Processing structure n°4
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5563451367015942
# Attempting exact match with iRMSD threshold: 0.07241106780287627
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.07241106780287627
# Could not find alignment below iRMSD threshold 0.07241106780287627
# Processing structure n°5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6809286048588414
# Attempting exact match with iRMSD threshold: 0.07241106780287627
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.07241106780287627
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.07241106780287627
# Processing structure n°6
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5245856944278587
# Attempting exact match with iRMSD threshold: 0.07241106780287627
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.07241106780287627
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.07241106780287627
# Processing structure n°7
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7213333389936223
# Attempting exact match with iRMSD threshold: 0.07241106780287627
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.07241106780287627
# Could not find alignment below iRMSD threshold 0.07241106780287627
# Processing structure n°8
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.46753517563986374
# Attempting exact match with iRMSD threshold: 0.07241106780287627
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.07241106780287627
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.07241106780287627
# Processing structure n°9
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.22728710670479546
# Attempting exact match with iRMSD threshold: 0.07241106780287627
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.07241106780287627
# Could not find alignment below iRMSD threshold 0.07241106780287627
# Processing structure n°10
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7214679307949007
# Attempting exact match with iRMSD threshold: 0.07241106780287627
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.07241106780287627
# Could not find alignment below iRMSD threshold 0.07241106780287627
# Processing structure n°11
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5642724673970867
# Attempting exact match with iRMSD threshold: 0.07241106780287627
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.07241106780287627
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.07241106780287627
# Processing structure n°12
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.40974985338192704
# Attempting exact match with iRMSD threshold: 0.07241106780287627
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.07241106780287627
# Could not find alignment below iRMSD threshold 0.07241106780287627
# Processing structure n°13
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5516359972306152
# Attempting exact match with iRMSD threshold: 0.07241106780287627
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.07241106780287627
# Could not find alignment below iRMSD threshold 0.07241106780287627
# Processing structure n°14
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6667241497501396
# Attempting exact match with iRMSD threshold: 0.07241106780287627
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.07241106780287627
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.07241106780287627
# Processing structure n°15
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.40434887391234126
# Attempting exact match with iRMSD threshold: 0.07241106780287627
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.07241106780287627
# Could not find alignment below iRMSD threshold 0.07241106780287627
# Processing structure n°16
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5249560829740803
# Attempting exact match with iRMSD threshold: 0.07241106780287627
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.07241106780287627
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.07241106780287627
# Processing structure n°17
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5763132683785559
# Attempting exact match with iRMSD threshold: 0.07241106780287627
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.07241106780287627
# Could not find alignment below iRMSD threshold 0.07241106780287627
# Processing structure n°18
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5868311214208078
# Attempting exact match with iRMSD threshold: 0.07241106780287627
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.07241106780287627
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.07241106780287627
# Processing structure n°19
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.40194924234362955
# Attempting exact match with iRMSD threshold: 0.07241106780287627
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.07241106780287627
# Could not find alignment below iRMSD threshold 0.07241106780287627
# Processing structure n°20
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.3295457801017625
# Attempting exact match with iRMSD threshold: 0.07241106780287627
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.07241106780287627
# Could not find alignment below iRMSD threshold 0.07241106780287627
# Processing structure n°21
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6594575125201714
# Attempting exact match with iRMSD threshold: 0.07241106780287627
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.07241106780287627
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.07241106780287627
# Processing structure n°22
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.3822410047363289
# Attempting exact match with iRMSD threshold: 0.07241106780287627
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.07241106780287627
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.07241106780287627
# Processing structure n°23
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6013698346938555
# Attempting exact match with iRMSD threshold: 0.07241106780287627
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.07241106780287627
# Could not find alignment below iRMSD threshold 0.07241106780287627
# Processing structure n°24
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.1414228909864017
# Attempting exact match with iRMSD threshold: 0.07241106780287627
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.07241106780287627
# Could not find alignment below iRMSD threshold 0.07241106780287627
# Processing structure n°25
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7179865714931984
# Attempting exact match with iRMSD threshold: 0.07241106780287627
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.07241106780287627
# Could not find alignment below iRMSD threshold 0.07241106780287627
# Processing structure n°26
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.39619475165916856
# Attempting exact match with iRMSD threshold: 0.07241106780287627
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.07241106780287627
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.07241106780287627
# Processing structure n°27
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.39918795710408744
# Attempting exact match with iRMSD threshold: 0.07241106780287627
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.07241106780287627
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.07241106780287627
# Processing structure n°28
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5416952519434393
# Attempting exact match with iRMSD threshold: 0.07241106780287627
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.07241106780287627
# Could not find alignment below iRMSD threshold 0.07241106780287627
# Processing structure n°29
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.18992102782238937
# Attempting exact match with iRMSD threshold: 0.07241106780287627
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.07241106780287627
# Could not find alignment below iRMSD threshold 0.07241106780287627
# Processing structure n°30
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5291326744573552
# Attempting exact match with iRMSD threshold: 0.07241106780287627
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.07241106780287627
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.07241106780287627
# Processing structure n°31
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6037421385755906
# Attempting exact match with iRMSD threshold: 0.07241106780287627
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.07241106780287627
# Could not find alignment below iRMSD threshold 0.07241106780287627
# Processing structure n°32
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.17198040203497839
# Attempting exact match with iRMSD threshold: 0.07241106780287627
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.07241106780287627
# Could not find alignment below iRMSD threshold 0.07241106780287627
# Writing all 33 aligned geometries to /tmp/sample_selected_TS-20250806-SCAN-11-w_wo-w_wo-w_wo-vs_SCAN-9w_valid/WL1-TS11193_aligned_baseline0.07_strict.xyz
# Reading geometries from /tmp/sample_selected_TS-20250806-SCAN-11-w_wo-w_wo-w_wo-vs_SCAN-9w_valid/WL1-TS11193.xyz
# Found 33 geometries
# Estimate optimal threshold from EQ endpoints: 0 ← 1 → 2
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.20079499811474927
# Attempting exact match with iRMSD threshold: 0.20179499811474927
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.19764742069855243
# Best alignment found with iRMSD=0.19664742069855243
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.4871225304794986
# Attempting exact match with iRMSD threshold: 0.4881225304794986
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.48342485369078747
# Best alignment found with iRMSD=0.07141106780287627
# Aligning all remaining geometries found, w.r.t. to geometry 1, using optimal threshold 0.19764742069855243
# Processing structure n°0
# Processing structure n°1
# Processing structure n°2
# Processing structure n°3
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.21980924197194987
# Attempting exact match with iRMSD threshold: 0.19764742069855243
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.19764742069855243
# Could not find alignment below iRMSD threshold 0.19764742069855243
# Processing structure n°4
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5563451367015942
# Attempting exact match with iRMSD threshold: 0.19764742069855243
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.19764742069855243
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.19136968581891825
# Processing structure n°5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6809286048588414
# Attempting exact match with iRMSD threshold: 0.19764742069855243
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.19764742069855243
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.19764742069855243
# Processing structure n°6
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5245856944278587
# Attempting exact match with iRMSD threshold: 0.19764742069855243
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.19764742069855243
# Best alignment found with iRMSD=0.18137546879643288
# Processing structure n°7
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7213333389936223
# Attempting exact match with iRMSD threshold: 0.19764742069855243
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.19764742069855243
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.19151323494835304
# Processing structure n°8
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.46753517563986374
# Attempting exact match with iRMSD threshold: 0.19764742069855243
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.19764742069855243
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.19764742069855243
# Processing structure n°9
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.22728710670479546
# Attempting exact match with iRMSD threshold: 0.19764742069855243
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.19764742069855243
# Could not find alignment below iRMSD threshold 0.19764742069855243
# Processing structure n°10
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7214679307949007
# Attempting exact match with iRMSD threshold: 0.19764742069855243
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.19764742069855243
# Could not find alignment below iRMSD threshold 0.19764742069855243
# Processing structure n°11
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5642724673970867
# Attempting exact match with iRMSD threshold: 0.19764742069855243
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.19764742069855243
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.19764742069855243
# Processing structure n°12
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.40974985338192704
# Attempting exact match with iRMSD threshold: 0.19764742069855243
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.19764742069855243
# Could not find alignment below iRMSD threshold 0.19764742069855243
# Processing structure n°13
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5516359972306152
# Attempting exact match with iRMSD threshold: 0.19764742069855243
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.19764742069855243
# Could not find alignment below iRMSD threshold 0.19764742069855243
# Processing structure n°14
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6667241497501396
# Attempting exact match with iRMSD threshold: 0.19764742069855243
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.19764742069855243
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.19764742069855243
# Processing structure n°15
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.40434887391234126
# Attempting exact match with iRMSD threshold: 0.19764742069855243
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.19764742069855243
# Could not find alignment below iRMSD threshold 0.19764742069855243
# Processing structure n°16
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5249560829740803
# Attempting exact match with iRMSD threshold: 0.19764742069855243
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.19764742069855243
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.19764742069855243
# Processing structure n°17
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5763132683785559
# Attempting exact match with iRMSD threshold: 0.19764742069855243
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.19764742069855243
# Could not find alignment below iRMSD threshold 0.19764742069855243
# Processing structure n°18
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5868311214208078
# Attempting exact match with iRMSD threshold: 0.19764742069855243
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.19764742069855243
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.19764742069855243
# Processing structure n°19
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.40194924234362955
# Attempting exact match with iRMSD threshold: 0.19764742069855243
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.19764742069855243
# Could not find alignment below iRMSD threshold 0.19764742069855243
# Processing structure n°20
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.3295457801017625
# Attempting exact match with iRMSD threshold: 0.19764742069855243
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.19764742069855243
# Could not find alignment below iRMSD threshold 0.19764742069855243
# Processing structure n°21
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6594575125201714
# Attempting exact match with iRMSD threshold: 0.19764742069855243
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.19764742069855243
# Best alignment found with iRMSD=0.19563853838155315
# Processing structure n°22
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.3822410047363289
# Attempting exact match with iRMSD threshold: 0.19764742069855243
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.19764742069855243
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.19764742069855243
# Processing structure n°23
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6013698346938555
# Attempting exact match with iRMSD threshold: 0.19764742069855243
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.19764742069855243
# Could not find alignment below iRMSD threshold 0.19764742069855243
# Processing structure n°24
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.1414228909864017
# Attempting exact match with iRMSD threshold: 0.1424228909864017
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.1413423525252608
# Best alignment found with iRMSD=0.1403423525252608
# Processing structure n°25
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7179865714931984
# Attempting exact match with iRMSD threshold: 0.19764742069855243
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.19764742069855243
# Could not find alignment below iRMSD threshold 0.19764742069855243
# Processing structure n°26
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.39619475165916856
# Attempting exact match with iRMSD threshold: 0.19764742069855243
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.19764742069855243
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.19764742069855243
# Processing structure n°27
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.39918795710408744
# Attempting exact match with iRMSD threshold: 0.19764742069855243
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.19764742069855243
# Best alignment found with iRMSD=0.19233828201508615
# Processing structure n°28
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5416952519434393
# Attempting exact match with iRMSD threshold: 0.19764742069855243
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.19764742069855243
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.1799327641854761
# Processing structure n°29
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.18992102782238937
# Attempting exact match with iRMSD threshold: 0.19092102782238937
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.18689390052470486
# Best alignment found with iRMSD=0.18589390052470486
# Processing structure n°30
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5291326744573552
# Attempting exact match with iRMSD threshold: 0.19764742069855243
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.19764742069855243
# Best alignment found with iRMSD=0.15699970778174394
# Processing structure n°31
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6037421385755906
# Attempting exact match with iRMSD threshold: 0.19764742069855243
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.19764742069855243
# Could not find alignment below iRMSD threshold 0.19764742069855243
# Processing structure n°32
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.17198040203497839
# Attempting exact match with iRMSD threshold: 0.1729804020349784
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.16996475955542856
# Best alignment found with iRMSD=0.16896475955542856
# Writing all 33 aligned geometries to /tmp/sample_selected_TS-20250806-SCAN-11-w_wo-w_wo-w_wo-vs_SCAN-9w_valid/WL1-TS11193_aligned_baseline0.20_loose.xyz
# Reading geometries from /tmp/sample_selected_TS-20250806-SCAN-11-w_wo-w_wo-w_wo-vs_SCAN-9w_valid/rcmconly_passerini-TS5435.xyz
# Found 33 geometries
# Estimate optimal threshold from EQ endpoints: 0 ← 1 → 2
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=1.0420848337892155
# Attempting exact match with iRMSD threshold: 1.0
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.650361282958355
# Best alignment found with iRMSD=0.34163329259966363
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7622759934469311
# Attempting exact match with iRMSD threshold: 0.34263329259966363
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.34263329259966363
# Could not find alignment below iRMSD threshold 0.34263329259966363
# Aligning all remaining geometries found, w.r.t. to geometry 1, using optimal threshold 0.34263329259966363
# Processing structure n°0
# Processing structure n°1
# Processing structure n°2
# Processing structure n°3
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.9631646993270605
# Attempting exact match with iRMSD threshold: 0.34263329259966363
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.34263329259966363
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.34263329259966363
# Processing structure n°4
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=1.0478810913961962
# Attempting exact match with iRMSD threshold: 0.34263329259966363
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.34263329259966363
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.34263329259966363
# Processing structure n°5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.9153186169581429
# Attempting exact match with iRMSD threshold: 0.34263329259966363
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.34263329259966363
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.34263329259966363
# Processing structure n°6
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=1.0113240910936998
# Attempting exact match with iRMSD threshold: 0.34263329259966363
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.34263329259966363
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.34263329259966363
# Processing structure n°7
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6759815880644108
# Attempting exact match with iRMSD threshold: 0.34263329259966363
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.34263329259966363
# Could not find alignment below iRMSD threshold 0.34263329259966363
# Processing structure n°8
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=1.0663734520678145
# Attempting exact match with iRMSD threshold: 0.34263329259966363
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.34263329259966363
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.34263329259966363
# Processing structure n°9
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7340046917146895
# Attempting exact match with iRMSD threshold: 0.34263329259966363
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.34263329259966363
# Could not find alignment below iRMSD threshold 0.34263329259966363
# Processing structure n°10
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=1.0435464606855542
# Attempting exact match with iRMSD threshold: 0.34263329259966363
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.34263329259966363
# Could not find alignment below iRMSD threshold 0.34263329259966363
# Processing structure n°11
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7615646570529246
# Attempting exact match with iRMSD threshold: 0.34263329259966363
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.34263329259966363
# Could not find alignment below iRMSD threshold 0.34263329259966363
# Processing structure n°12
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=175.41795549191914
# Attempting exact match with iRMSD threshold: 0.34263329259966363
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.34263329259966363
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.34263329259966363
# Processing structure n°13
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.8169149076853803
# Attempting exact match with iRMSD threshold: 0.34263329259966363
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.34263329259966363
# Could not find alignment below iRMSD threshold 0.34263329259966363
# Processing structure n°14
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.8989659909487144
# Attempting exact match with iRMSD threshold: 0.34263329259966363
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.34263329259966363
# Could not find alignment below iRMSD threshold 0.34263329259966363
# Processing structure n°15
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.8276988369072277
# Attempting exact match with iRMSD threshold: 0.34263329259966363
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.34263329259966363
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.34263329259966363
# Processing structure n°16
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=1.0105566813754256
# Attempting exact match with iRMSD threshold: 0.34263329259966363
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.34263329259966363
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.34263329259966363
# Processing structure n°17
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.927976588161998
# Attempting exact match with iRMSD threshold: 0.34263329259966363
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.34263329259966363
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.34263329259966363
# Processing structure n°18
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.9181491418827902
# Attempting exact match with iRMSD threshold: 0.34263329259966363
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.34263329259966363
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.34263329259966363
# Processing structure n°19
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.8820845748446925
# Attempting exact match with iRMSD threshold: 0.34263329259966363
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.34263329259966363
# Could not find alignment below iRMSD threshold 0.34263329259966363
# Processing structure n°20
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.9949100665605844
# Attempting exact match with iRMSD threshold: 0.34263329259966363
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.34263329259966363
# Could not find alignment below iRMSD threshold 0.34263329259966363
# Processing structure n°21
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.9617686741672006
# Attempting exact match with iRMSD threshold: 0.34263329259966363
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.34263329259966363
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.34263329259966363
# Processing structure n°22
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=1.036332515938678
# Attempting exact match with iRMSD threshold: 0.34263329259966363
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.34263329259966363
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.34263329259966363
# Processing structure n°23
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.8746000257274293
# Attempting exact match with iRMSD threshold: 0.34263329259966363
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.34263329259966363
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.34263329259966363
# Processing structure n°24
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7248681322558234
# Attempting exact match with iRMSD threshold: 0.34263329259966363
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.34263329259966363
# Could not find alignment below iRMSD threshold 0.34263329259966363
# Processing structure n°25
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.9768840112391017
# Attempting exact match with iRMSD threshold: 0.34263329259966363
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.34263329259966363
# Could not find alignment below iRMSD threshold 0.34263329259966363
# Processing structure n°26
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.9528411420071573
# Attempting exact match with iRMSD threshold: 0.34263329259966363
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.34263329259966363
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.34263329259966363
# Processing structure n°27
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.905628708133444
# Attempting exact match with iRMSD threshold: 0.34263329259966363
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.34263329259966363
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.34263329259966363
# Processing structure n°28
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.8707183599195505
# Attempting exact match with iRMSD threshold: 0.34263329259966363
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.34263329259966363
# Could not find alignment below iRMSD threshold 0.34263329259966363
# Processing structure n°29
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.4817247183168633
# Attempting exact match with iRMSD threshold: 0.34263329259966363
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.32047144931051197
# Best alignment found with iRMSD=0.31947144931051197
# Processing structure n°30
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.9943624387922402
# Attempting exact match with iRMSD threshold: 0.34263329259966363
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.34263329259966363
# Could not find alignment below iRMSD threshold 0.34263329259966363
# Processing structure n°31
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=1.0134421797848
# Attempting exact match with iRMSD threshold: 0.34263329259966363
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.34263329259966363
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.34263329259966363
# Processing structure n°32
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.8707143020952847
# Attempting exact match with iRMSD threshold: 0.34263329259966363
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.34263329259966363
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.34263329259966363
# Writing all 33 aligned geometries to /tmp/sample_selected_TS-20250806-SCAN-11-w_wo-w_wo-w_wo-vs_SCAN-9w_valid/rcmconly_passerini-TS5435_aligned_baseline0.34_strict.xyz
# Reading geometries from /tmp/sample_selected_TS-20250806-SCAN-11-w_wo-w_wo-w_wo-vs_SCAN-9w_valid/rcmconly_passerini-TS5435.xyz
# Found 33 geometries
# Estimate optimal threshold from EQ endpoints: 0 ← 1 → 2
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=1.0420848337892155
# Attempting exact match with iRMSD threshold: 1.0
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.650361282958355
# Best alignment found with iRMSD=0.34163329259966363
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7622759934469311
# Attempting exact match with iRMSD threshold: 0.7632759934469311
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.722559709493676
# Best alignment found with iRMSD=0.721559709493676
# Aligning all remaining geometries found, w.r.t. to geometry 1, using optimal threshold 0.722559709493676
# Processing structure n°0
# Processing structure n°1
# Processing structure n°2
# Processing structure n°3
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.9631646993270605
# Attempting exact match with iRMSD threshold: 0.722559709493676
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.43428227946647
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.43328227946647
# Processing structure n°4
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=1.0478810913961962
# Attempting exact match with iRMSD threshold: 0.722559709493676
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.722559709493676
# Best alignment found with iRMSD=0.6594495330802734
# Processing structure n°5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.9153186169581429
# Attempting exact match with iRMSD threshold: 0.722559709493676
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.722559709493676
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.722559709493676
# Processing structure n°6
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=1.0113240910936998
# Attempting exact match with iRMSD threshold: 0.722559709493676
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.6413193248587409
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.6403193248587409
# Processing structure n°7
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6759815880644108
# Attempting exact match with iRMSD threshold: 0.6769815880644108
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.42788957979421305
# Best alignment found with iRMSD=0.42688957979421305
# Processing structure n°8
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=1.0663734520678145
# Attempting exact match with iRMSD threshold: 0.722559709493676
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.6125375162478901
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.6115375162478901
# Processing structure n°9
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7340046917146895
# Attempting exact match with iRMSD threshold: 0.722559709493676
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.722559709493676
# Could not find alignment below iRMSD threshold 0.722559709493676
# Processing structure n°10
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=1.0435464606855542
# Attempting exact match with iRMSD threshold: 0.722559709493676
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.7113982795786501
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.5894799323809782
# Processing structure n°11
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7615646570529246
# Attempting exact match with iRMSD threshold: 0.722559709493676
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.6604319231019048
# Best alignment found with iRMSD=0.6594319231019048
# Processing structure n°12
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=175.41795549191914
# Attempting exact match with iRMSD threshold: 0.722559709493676
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.722559709493676
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.722559709493676
# Processing structure n°13
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.8169149076853803
# Attempting exact match with iRMSD threshold: 0.722559709493676
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.722559709493676
# Could not find alignment below iRMSD threshold 0.722559709493676
# Processing structure n°14
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.8989659909487144
# Attempting exact match with iRMSD threshold: 0.722559709493676
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.660185392325747
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.5934868236151074
# Processing structure n°15
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.8276988369072277
# Attempting exact match with iRMSD threshold: 0.722559709493676
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.722559709493676
# ...
# Processing structure n°28
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.8644400615170884
# Attempting exact match with iRMSD threshold: 0.12051044132598829
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.12051044132598829
# Could not find alignment below iRMSD threshold 0.12051044132598829
# Processing structure n°29
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7330618593162546
# Attempting exact match with iRMSD threshold: 0.12051044132598829
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.07080157065843987
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.06980157065843987
# Processing structure n°30
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=1.133174140233913
# Attempting exact match with iRMSD threshold: 0.12051044132598829
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.12051044132598829
# Could not find alignment below iRMSD threshold 0.12051044132598829
# Processing structure n°31
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.9611800227278862
# Attempting exact match with iRMSD threshold: 0.12051044132598829
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.12051044132598829
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.12051044132598829
# Processing structure n°32
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.538718728452883
# Attempting exact match with iRMSD threshold: 0.12051044132598829
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.12051044132598829
# Best alignment found with iRMSD=0.11592063491950481
# Writing all 33 aligned geometries to /tmp/sample_selected_TS-20250806-SCAN-11-w_wo-w_wo-w_wo-vs_SCAN-9w_valid/rcmconly_strecker-TS5528_aligned_baseline0.12_strict.xyz
# Reading geometries from /tmp/sample_selected_TS-20250806-SCAN-11-w_wo-w_wo-w_wo-vs_SCAN-9w_valid/rcmconly_strecker-TS5528.xyz
# Found 33 geometries
# Estimate optimal threshold from EQ endpoints: 0 ← 1 → 2
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.12429449689969971
# Attempting exact match with iRMSD threshold: 0.1252944968996997
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.12051044132598829
# Best alignment found with iRMSD=0.11951044132598829
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.8287378368465737
# Attempting exact match with iRMSD threshold: 0.8297378368465737
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.30583920468803194
# Best alignment found with iRMSD=0.30483920468803194
# Aligning all remaining geometries found, w.r.t. to geometry 1, using optimal threshold 0.30583920468803194
# Processing structure n°0
# Processing structure n°1
# Processing structure n°2
# Processing structure n°3
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=1.2873915375947647
# Attempting exact match with iRMSD threshold: 0.30583920468803194
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.30583920468803194
# Could not find alignment below iRMSD threshold 0.30583920468803194
# Processing structure n°4
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.9414801778725229
# Attempting exact match with iRMSD threshold: 0.30583920468803194
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.30583920468803194
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.132609409423573
# Processing structure n°5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=999765000.898353
# Attempting exact match with iRMSD threshold: 0.30583920468803194
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.30583920468803194
# Could not find alignment below iRMSD threshold 0.30583920468803194
# Processing structure n°6
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.8807552797802918
# Attempting exact match with iRMSD threshold: 0.30583920468803194
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.30583920468803194
# Could not find alignment below iRMSD threshold 0.30583920468803194
# Processing structure n°7
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=1.1972225235947525
# Attempting exact match with iRMSD threshold: 0.30583920468803194
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.30583920468803194
# Could not find alignment below iRMSD threshold 0.30583920468803194
# Processing structure n°8
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.9802645927442021
# Attempting exact match with iRMSD threshold: 0.30583920468803194
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.30583920468803194
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.13123157802463062
# Processing structure n°9
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5395700151643423
# Attempting exact match with iRMSD threshold: 0.30583920468803194
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.30583920468803194
# Best alignment found with iRMSD=0.14130292441354547
# Processing structure n°10
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=1.092189464492202
# Attempting exact match with iRMSD threshold: 0.30583920468803194
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.30583920468803194
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.18619856738496024
# Processing structure n°11
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.9697596954489347
# Attempting exact match with iRMSD threshold: 0.30583920468803194
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.30583920468803194
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.30583920468803194
# Processing structure n°12
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.9874858641190698
# Attempting exact match with iRMSD threshold: 0.30583920468803194
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.30583920468803194
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.30583920468803194
# Processing structure n°13
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=1.1667729557021327
# Attempting exact match with iRMSD threshold: 0.30583920468803194
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.30583920468803194
# Could not find alignment below iRMSD threshold 0.30583920468803194
# Processing structure n°14
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5128372903322677
# Attempting exact match with iRMSD threshold: 0.30583920468803194
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.30583920468803194
# Could not find alignment below iRMSD threshold 0.30583920468803194
# Processing structure n°15
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.9273129854890353
# Attempting exact match with iRMSD threshold: 0.30583920468803194
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.30583920468803194
# Could not find alignment below iRMSD threshold 0.30583920468803194
# Processing structure n°16
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=1.112520254274295
# Attempting exact match with iRMSD threshold: 0.30583920468803194
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.30583920468803194
# Could not find alignment below iRMSD threshold 0.30583920468803194
# Processing structure n°17
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=1.1537415258497605
# Attempting exact match with iRMSD threshold: 0.30583920468803194
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.2518962044143569
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.2508962044143569
# Processing structure n°18
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=1.1388228661648887
# Attempting exact match with iRMSD threshold: 0.30583920468803194
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.30583920468803194
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.30583920468803194
# Processing structure n°19
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7281084841303596
# Attempting exact match with iRMSD threshold: 0.30583920468803194
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.30583920468803194
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.30583920468803194
# Processing structure n°20
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7879974135281799
# Attempting exact match with iRMSD threshold: 0.30583920468803194
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.30583920468803194
# Could not find alignment below iRMSD threshold 0.30583920468803194
# Processing structure n°21
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5351915826303438
# Attempting exact match with iRMSD threshold: 0.30583920468803194
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.30583920468803194
# Best alignment found with iRMSD=0.1286922490969825
# Processing structure n°22
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=1.1514857924498734
# Attempting exact match with iRMSD threshold: 0.30583920468803194
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.30583920468803194
# Could not find alignment below iRMSD threshold 0.30583920468803194
# Processing structure n°23
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5232271740664857
# Attempting exact match with iRMSD threshold: 0.30583920468803194
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.30583920468803194
# Best alignment found with iRMSD=0.1197376762469871
# Processing structure n°24
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=1.4428412912518065
# Attempting exact match with iRMSD threshold: 0.30583920468803194
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.30583920468803194
# Could not find alignment below iRMSD threshold 0.30583920468803194
# Processing structure n°25
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=1.2785189748238492
# Attempting exact match with iRMSD threshold: 0.30583920468803194
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.30583920468803194
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.30583920468803194
# Processing structure n°26
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.783555313710953
# Attempting exact match with iRMSD threshold: 0.30583920468803194
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.30583920468803194
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.30583920468803194
# Processing structure n°27
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.18073318707319952
# Attempting exact match with iRMSD threshold: 0.18173318707319952
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.18173318707319952
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.18073318707319952
# Processing structure n°28
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.8644400615170884
# Attempting exact match with iRMSD threshold: 0.30583920468803194
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.30583920468803194
# Could not find alignment below iRMSD threshold 0.30583920468803194
# Processing structure n°29
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7330618593162546
# Attempting exact match with iRMSD threshold: 0.30583920468803194
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.07080157065843987
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.06980157065843987
# Processing structure n°30
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=1.133174140233913
# Attempting exact match with iRMSD threshold: 0.30583920468803194
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.303192673845324
# Best alignment found with iRMSD=0.302192673845324
# Processing structure n°31
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.9611800227278862
# Attempting exact match with iRMSD threshold: 0.30583920468803194
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.30583920468803194
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.30583920468803194
# Processing structure n°32
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.538718728452883
# Attempting exact match with iRMSD threshold: 0.30583920468803194
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.30583920468803194
# Best alignment found with iRMSD=0.11592063491950481
# Writing all 33 aligned geometries to /tmp/sample_selected_TS-20250806-SCAN-11-w_wo-w_wo-w_wo-vs_SCAN-9w_valid/rcmconly_strecker-TS5528_aligned_baseline0.31_loose.xyz

# %%
import ase.io

all_atoms = ase.io.read('/tmp/sample_selected_TS-20250806-SCAN-11-w_wo-w_wo-w_wo-vs_SCAN-9w_valid/rcmconly_passerini-TS17328_aligned_baseline0.06.xyz', index=':')
target = all_atoms[1]
aligned_base = all_atoms[0]
extract_comments(aligned_base)
# Out:
# ''

# %%
view_aligned(aligned_base, target)
# Out:
# HBox(children=(NGLWidget(), VBox(children=(Dropdown(description='Show', options=('All', 'O', 'C', 'H', 'N'), v…
