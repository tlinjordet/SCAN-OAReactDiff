# %% [markdown]
# # Apply this code to sample TS from model.

# %%
import os

# Set to '0' for the first GPU, '1' for the second, etc.
# Or use a comma-separated string for multiple visible devices, e.g., '0,1'
os.environ["CUDA_VISIBLE_DEVICES"] = "0" # UPDATE

# Verify the setting (optional)
print(f"CUDA_VISIBLE_DEVICES is set to: {os.environ.get('CUDA_VISIBLE_DEVICES')}")

# Now, when you import your deep learning library, it will only see the specified device(s)
import torch
print(f"PyTorch sees {torch.cuda.device_count()} CUDA device(s).")
if torch.cuda.is_available():
    print(f"Current PyTorch device: {torch.cuda.current_device()}")
    print(f"Device name: {torch.cuda.get_device_name(0)}")

# For TensorFlow
# import tensorflow as tf
# print(f"TensorFlow sees {len(tf.config.list_physical_devices('GPU'))} GPU device(s).")
# Out:
# CUDA_VISIBLE_DEVICES is set to: 0
# PyTorch sees 1 CUDA device(s).
# Current PyTorch device: 0
# Device name: NVIDIA A100-PCIE-40GB

# %%
# --- Importing and defining some functions ----
import os
import torch
import py3Dmol
import numpy as np

from typing import Optional
from torch import tensor
from e3nn import o3
from torch_scatter import scatter_mean

from oa_reactdiff.model import LEFTNet

default_float = torch.float64
torch.set_default_dtype(default_float)  # Use double precision for more accurate testing


def remove_mean_batch(
    x: tensor, 
    indices: Optional[tensor] = None
) -> tensor:
    """Remove the mean from each batch in x

    Args:
        x (tensor): input tensor.
        indices (Optional[tensor], optional): batch indices. Defaults to None.

    Returns:
        tensor: output tensor with batch mean as 0.
    """
    if indices == None:
         return x - torch.mean(x, dim=0)
    mean = scatter_mean(x, indices, dim=0)
    x = x - mean[indices]
    return x


def draw_in_3dmol(mol: str, fmt: str = "xyz") -> py3Dmol.view:
    """Draw the molecule

    Args:
        mol (str): str content of molecule.
        fmt (str, optional): format. Defaults to "xyz".

    Returns:
        py3Dmol.view: output viewer
    """
    viewer = py3Dmol.view(1024, 576)
    viewer.addModel(mol, fmt)
    viewer.setStyle({'stick': {}, "sphere": {"radius": 0.36}})
    viewer.zoomTo()
    return viewer


def assemble_xyz(z: list, pos: tensor) -> str:
    """Assembling atomic numbers and positions into xyz format

    Args:
        z (list): chemical elements
        pos (tensor): 3D coordinates

    Returns:
        str: xyz string
    """
    natoms =len(z)
    xyz = f"{natoms}\n\n"
    for _z, _pos in zip(z, pos): #.numpy()):
        xyz += f"{_z}\t" + "\t".join([str(x) for x in _pos]) + "\n"
    return xyz

# %% [markdown]
# ### Building a LEFTNet model
#
# A simple test is performed to verify SE(3) symmetry. The model here is for testing, so we only need to build a very small model.
#
# Note: [LEFTNet](https://arxiv.org/abs/2304.04757) is a new SOTA-level SE(3) graph neural network. Although we use LEFTNet here, the properties it exhibits are model-independent (other SE(3) models, such as [EGNN](https://arxiv.org/pdf/2102.09844.pdf), will give the same results)
#
# TL: EGNN is not SE$(3)$  equivariant?

# %%
num_layers = 2
hidden_channels = 8
in_hidden_channels = 4
num_radial = 4

model =  LEFTNet(
    num_layers=num_layers,
    hidden_channels=hidden_channels,
    in_hidden_channels=in_hidden_channels,
    num_radial=num_radial,
    object_aware=False,
)

sum(p.numel() for p in model.parameters() if p.requires_grad)
# Out:
# /misc/home/guest50/micromamba/envs/oa_reactdiff_m/lib/python3.10/site-packages/torch_geometric/nn/conv/message_passing.py:972: UserWarning: 'EquiMessage.jittable' is deprecated and a no-op. Please remove its usage.
#   warnings.warn(f"'{self.__class__.__name__}.jittable' is deprecated "
# 7882

# %% [raw]
# xyz = assemble_xyz(z, pos)
# view = draw_in_3dmol(xyz, "xyz")
# view  # Display Molecules

# %% [markdown]
# ### Create an "Object-Aware" LEFTNet

# %% [raw]
# model_oa =  LEFTNet(
#     num_layers=num_layers,
#     hidden_channels=hidden_channels,
#     in_hidden_channels=in_hidden_channels,
#     num_radial=num_radial,
#     object_aware=True,  # Using the object-aware model
# )

# %%
# --- Importing necessary function ---
from torch.utils.data import DataLoader

from oa_reactdiff.trainer.pl_trainer import DDPMModule


from oa_reactdiff.dataset import ProcessedTS1x, ProcessedSCAN
from oa_reactdiff.diffusion._schedule import DiffSchedule, PredefinedNoiseSchedule

from oa_reactdiff.diffusion._normalizer import FEATURE_MAPPING
from oa_reactdiff.analyze.rmsd import batch_rmsd

from oa_reactdiff.utils.sampling_tools import assemble_sample_inputs, write_tmp_xyz

# %%
# !pwd
# Out:
# /home/guest50/OAReactDiff

# %% [markdown]
# ### Import the pre-trained model and redefine the schedule.

# %%
# TL fix: {
from oa_reactdiff.trainer.pl_trainer import DDPMModule
# } fix. Why didn' this carry over from the previous cell import statement?

device = torch.device("cpu") if not torch.cuda.is_available() else torch.device("cuda")
print(device) # TL
print(device.index)
print(device.type)


tspath = os.path.abspath(os.path.join(os.getcwd(), "oa_reactdiff","trainer"))
print(tspath)
# zenodo_pretrained_ckpt
ddpm_trainer = DDPMModule.load_from_checkpoint(
    checkpoint_path="./oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/leftnet-SCAN-6-w_selfoops-lr2.5e-4-rcmconly_passerini-03516f3022c5/ddpm-epoch=1899-val-totloss=736.23.ckpt",    
    #checkpoint_path="./oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/leftnet-SCAN-6-w_selfoops-lr2.5e-4-rcmconly_passerini-03516f3022c5/ddpm-epoch=1799-val-totloss=787.66.ckpt", --
    #
    #checkpoint_path="./pretrained-ts1x-diff.ckpt", # original
    #checkpoint_path=f"{tspath}/checkpoint/OAReactDiff/leftnet-0-f1ff7dc18fa3/ddpm-epoch=1999-val-totloss=509.31.ckpt", # Our recapitulation
    map_location=device,
)
ddpm_trainer = ddpm_trainer.to(device)
# Out:
# cuda
# None
# cuda
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer
# /misc/home/guest50/micromamba/envs/oa_reactdiff_m/lib/python3.10/site-packages/torch_geometric/nn/conv/message_passing.py:972: UserWarning: 'EquiMessage.jittable' is deprecated and a no-op. Please remove its usage.
#   warnings.warn(f"'{self.__class__.__name__}.jittable' is deprecated "

# %% [raw]
# loaded_from_scratch_ckpt = torch.load("./trained_models/pretrained-ts1x-diff-from-scratch.ckpt")
# loaded_from_scratch_ckpt

# %% [raw]
# loaded_zenodo_ckpt = torch.load("./trained_models/pretrained-ts1x-diff-zenodo.ckpt")
# loaded_zenodo_ckpt

# %%
noise_schedule: str = "polynomial_2"
timesteps: int = 150
precision: float = 1e-5

gamma_module = PredefinedNoiseSchedule(
            noise_schedule=noise_schedule,
            timesteps=timesteps,
            precision=precision,
        )
schedule = DiffSchedule(
    gamma_module=gamma_module,
    norm_values=ddpm_trainer.ddpm.norm_values
)
ddpm_trainer.ddpm.schedule = schedule
ddpm_trainer.ddpm.T = timesteps
ddpm_trainer = ddpm_trainer.to(device)

# %%
def prep_ddpm_trainer(ckpt_path: str, device=device):
    ddpm_trainer = DDPMModule.load_from_checkpoint(
        checkpoint_path=ckpt_path,
        map_location=device,
    )
    ddpm_trainer = ddpm_trainer.to(device)

    noise_schedule: str = "polynomial_2"
    timesteps: int = 150
    precision: float = 1e-5
    
    gamma_module = PredefinedNoiseSchedule(
                noise_schedule=noise_schedule,
                timesteps=timesteps,
                precision=precision,
            )
    schedule = DiffSchedule(
        gamma_module=gamma_module,
        norm_values=ddpm_trainer.ddpm.norm_values
    )
    ddpm_trainer.ddpm.schedule = schedule
    ddpm_trainer.ddpm.T = timesteps
    ddpm_trainer = ddpm_trainer.to(device)
    return ddpm_trainer

# %% [raw]
# ddpm_trainer = prep_ddpm_trainer(ckpt_path, device=device)

# %% [markdown]
# ### Prepare dataset and data loader and select a reaction involving multiple molecules

# %%
import pickle

# npz_path = "./oa_reactdiff/data/C6H6_5710-0-wSL-wBL-w3pBC/train.pkl" # w  self-loops after Angstrom correction
# 24/06/2026: update to check filtering results
npz_path = "./oa_reactdiff/data/C6H6_5710-filtered/train.pkl"

train_pkl = pickle.load(open(npz_path, "rb"))

# %%
npz_path_valid = "./oa_reactdiff/data/C6H6_5710-filtered/valid_addprop.pkl"
valid_pkl = pickle.load(open(npz_path_valid, "rb"))

# %%
npz_path_test = "/scr/trond/SCAN/C6H6_5710-filtered-test.pkl"
test_pkl = pickle.load(open(npz_path_test, "rb"))

# %%
pos = np.array(test_pkl['transition_state']['positions'][0])

# %%
z_num = test_pkl['transition_state']['charges'][0]

# %%
num2sym = {1: "H", 6: "C"}

# %%
test_xyz = assemble_xyz([num2sym[num] for num in z_num], pos)
print(test_xyz)
# Out:
# 12
#
# C	-0.516900648343	-0.174294636273	-1.067970800786
# C	-1.8274168923979999	0.281855646809	-0.665555170387
# C	0.7204072213550001	0.3062477260559999	-0.429570871693
# C	-1.5569540082030002	-0.259379067575	0.501820927983
# C	0.746055826415	0.301589139332	0.917287820757
# C	-0.49997865703499994	-0.314533123402	1.535236083393
# H	-2.717388734537	0.6617476993339999	-1.181950702773
# H	1.5862774498539998	0.587394946715	-1.041990254096
# H	-0.312462548756	-1.355347111461	1.8643291315180002
# H	1.5520855533639997	0.7188507795929999	1.5318461719469998
# H	-0.842730787701	0.22958547243399996	2.4369996781390006
# H	-0.42212630402	-0.9837174715619998	-1.81221449399

# %%
train_pkl["use_ind"][:10]
# Out:
# [0, 1, 2, 3, 5, 6, 7, 8, 9, 10]

# %%
valid_pkl["use_ind"][:10]
# Out:
# [4, 16, 114, 116, 119, 127, 143, 154, 160, 190]

# %% [raw]
# # 01/7/2025:
# # Something doesn't make sense
# # 957  cp /scr/trond/SCAN/SCAN_train_wo_selfloops-rcmconly_passerini_fix.pkl train_addprop.pkl
# # 958  cp train_addprop.pkl train.pkl
# # 959  cp /scr/trond/SCAN/SCAN-6_valid_wo_selfloops-rcmconly_passerini_fix.pkl valid_addprop.pkl
#
# train_pkl2 = pickle.load(open("/scr/trond/SCAN/SCAN_train_w_selfloops-rcmconly_passerini_fix.pkl", "rb"))
# valid_pkl2 = pickle.load(open("/scr/trond/SCAN/SCAN-6_valid_w_selfloops-rcmconly_passerini_fix.pkl", "rb"))

# %%
#assert sorted(list(set(train_pkl2["use_ind"] + valid_pkl2["use_ind"]))) == list(range(len(train_pkl2["transition_state"]["rxn"])))

# %% [raw]
# train_pkl2["use_ind"] == valid_pkl2["use_ind"]

# %%
train_pkl["reactant"]["rxn"][177]
# Out:
# 'C6H6_5710-TS446 CON(114,174)'

# %%
len(valid_pkl["use_ind"])
# Out:
# 330

# %%
train_pkl["reactant"]['num_atoms'][177]
# Out:
# 12

# %% [raw]
# selected_rxns = {'WL1-TS784',
#                  'WL1-TS63029',
#                  'WL1-TS11193',
#                  'rcmconly_passerini-TS1206',
#                  'rcmconly_passerini-TS5435',
#                  'rcmconly_passerini-TS7394',
#                  'rcmconly_passerini-TS13605',
#                  'rcmconly_passerini-TS15965',
#                  'rcmconly_passerini-TS17328',
#                  'rcmconly_passerini-TS17605',
#                  'rcmconly_strecker-TS3978',
#                  'rcmconly_strecker-TS5528',
#                  'rcmconly_strecker-TS7950'}

# %%
selected_passerini_rcmconly_pts = [13605, 17605, 1206, 7394, 15965, 5435, 17328]
selected_strecker_rcmconly_pts = [3978, 5528, 7950]
selected_wl2_pts = [6029, 784, 11193]

# %%
from parse import parse
from pprint import pprint

# %%
set(selected_passerini_rcmconly_pts+selected_strecker_rcmconly_pts+selected_wl2_pts)
# Out:
# {784,
#  1206,
#  3978,
#  5435,
#  5528,
#  6029,
#  7394,
#  7950,
#  11193,
#  13605,
#  15965,
#  17328,
#  17605}

# %%
prefixes = {'ALD1',
 'EN1',
 'HDF1',
 'WL1',
 'f260_DFG1',
 'rcmconly_passerini',
 'rcmconly_strecker'}

select_prefixes = {'WL1', 'rcmconly_passerini', 'rcmconly_strecker'}
rxn_pattern = "{prefix}-TS{id_num}"

for i, rxn in enumerate(valid_pkl["transition_state"]["rxn"]): # valid, not train
    parsed = parse(rxn_pattern, rxn)
    prefix = parsed["prefix"]
    id_num = parsed["id_num"]
    #prefixes.add(prefix)
    if prefix not in select_prefixes: 
        continue
    if int(id_num) in set(selected_passerini_rcmconly_pts+selected_strecker_rcmconly_pts+selected_wl2_pts):
        print(rxn)
        print(i)
        print(i in valid_pkl["use_ind"]) # valid, not train
        print("")

# %%
select_rxns = []

selection = {'WL1': selected_wl2_pts, 'rcmconly_strecker': selected_strecker_rcmconly_pts, 'rcmconly_passerini': selected_passerini_rcmconly_pts}

for prefix, id_list in selection.items():
    for id_num in id_list:
        select_rxns.append(f"{prefix}-TS{id_num}")

print(select_rxns)
# Out:
# ['WL1-TS6029', 'WL1-TS784', 'WL1-TS11193', 'rcmconly_strecker-TS3978', 'rcmconly_strecker-TS5528', 'rcmconly_strecker-TS7950', 'rcmconly_passerini-TS13605', 'rcmconly_passerini-TS17605', 'rcmconly_passerini-TS1206', 'rcmconly_passerini-TS7394', 'rcmconly_passerini-TS15965', 'rcmconly_passerini-TS5435', 'rcmconly_passerini-TS17328']

# %%
# assert sorted(list(set(train_pkl["use_ind"] + valid_pkl["use_ind"]))) == list(range(len(train_pkl["transition_state"]["rxn"])))

# %%
len(train_pkl["transition_state"]["rxn"])
# Out:
# 6603

# %%
len(valid_pkl["transition_state"]["rxn"])
# Out:
# 6603

# %%
train_pkl["use_ind"] == valid_pkl["use_ind"]
# Out:
# False

# %%
selected_train_indices = []
selected_valid_indices = []
selected_rxns_dict = {}
for i, rxn in enumerate(train_pkl["transition_state"]["rxn"]):
    if rxn in select_rxns:
        print(rxn)
        print(i)
        print(i in train_pkl["use_ind"])
        if i in train_pkl["use_ind"]:
            selected_train_indices.append(train_pkl["use_ind"].index(i))
        elif i in valid_pkl["use_ind"]:
            selected_valid_indices.append(valid_pkl["use_ind"].index(i))
        selected_rxns_dict[i] = rxn
        print("")

# %%
selected_train_indices
# Out:
# []

# %%
selected_valid_indices
# Out:
# []

# %%
# update, just selecting some random validation TSes for C6H6 for now
import random

random.seed(33)
#selected_valid_pre_indices = sorted(list(random.sample(valid_pkl["use_ind"], 10)))
selected_valid_pre_indices = sorted(list(random.sample(valid_pkl["use_ind"], 100)))

selected_valid_indices = []
for i in selected_valid_pre_indices:
    selected_valid_indices.append(valid_pkl["use_ind"].index(i))
print(selected_valid_indices)
# Out:
# [1, 3, 4, 16, 26, 28, 29, 32, 33, 35, 36, 41, 47, 56, 60, 61, 62, 63, 76, 80, 85, 92, 94, 95, 97, 98, 103, 109, 113, 119, 124, 125, 126, 138, 139, 141, 143, 144, 145, 154, 155, 157, 158, 162, 163, 164, 170, 178, 179, 181, 183, 185, 186, 187, 194, 198, 199, 201, 209, 211, 215, 218, 220, 223, 227, 232, 234, 239, 242, 245, 246, 247, 248, 254, 257, 260, 262, 265, 268, 270, 272, 278, 282, 284, 288, 292, 294, 299, 300, 303, 304, 308, 315, 316, 318, 320, 322, 323, 325, 327]

# %% [raw]
# dataset = ProcessedSCAN(
#     npz_path=npz_path,
#     center=True,
#     pad_fragments=0,
#     device=device,
#     zero_charge=False,
#     remove_h=False,
#     single_frag_only=False,
#     swapping_react_prod=False,
#     use_by_ind=True,
# )
# loader = DataLoader(
#     dataset,
#     batch_size=1,
#     shuffle=False,
#     num_workers=0,
#     collate_fn=dataset.collate_fn
# )
# itl = iter(loader)
# idx = -1 # TL: why?
#
# len(dataset)

# %% [raw]
# # train dataset size, SCAN-9w:
# 97866

# %%
# valid dataset to test against:
dataset = ProcessedSCAN(
    npz_path=npz_path_valid,
    center=True,
    pad_fragments=0,
    device=device,
    zero_charge=False,
    remove_h=False,
    single_frag_only=False,
    swapping_react_prod=False,
    use_by_ind=True,
    keep_use_by_ind_ordered=True, # Used for analysis but not training? 18/07/2025
)
loader = DataLoader(
    dataset, 
    batch_size=1,
    shuffle=False,
    num_workers=0,
    collate_fn=dataset.collate_fn
)
itl = iter(loader)
idx = -1 # TL: why?

len(dataset)
# Out:
# 330

# %%
len(valid_pkl["use_ind"])
# Out:
# 330

# %%
dataset.raw_dataset["use_ind"] == valid_pkl["use_ind"]
# Out:
# True

# %% [raw]
# num_indices_to_select = 20
# SEED = 747
# np.random.default_rng(seed=SEED)
# np.random.seed(SEED)
# random_indices = np.random.choice(len(dataset), size=num_indices_to_select, replace=False)
# random_indices = sorted(random_indices)
# random_indices

# %% [raw]
# for _ in range(4):  # The 4th sample happens to be a multimolecular reaction
#     representations, res = next(itl)
# idx += 1
# n_samples = representations[0]["size"].size(0)
# if n_samples != 1: #
#     print(n_samples)#
# fragments_nodes = [
#     repre["size"] for repre in representations
# ]
# conditions = torch.tensor([[0] for _ in range(n_samples)], device=device)

# %%
# TL visualize each state:
atomic_num2sym = {
    1: 'H',    2: 'He',   3: 'Li',   4: 'Be',   5: 'B',    6: 'C',    7: 'N',    8: 'O',    9: 'F',    10: 'Ne',
    11: 'Na',  12: 'Mg',  13: 'Al',  14: 'Si',  15: 'P',   16: 'S',   17: 'Cl',  18: 'Ar',  19: 'K',   20: 'Ca',
    21: 'Sc',  22: 'Ti',  23: 'V',   24: 'Cr',  25: 'Mn',  26: 'Fe',  27: 'Co',  28: 'Ni',  29: 'Cu',  30: 'Zn',
    31: 'Ga',  32: 'Ge',  33: 'As',  34: 'Se',  35: 'Br',  36: 'Kr',  37: 'Rb',  38: 'Sr',  39: 'Y',   40: 'Zr',
    41: 'Nb',  42: 'Mo',  43: 'Tc',  44: 'Ru',  45: 'Rh',  46: 'Pd',  47: 'Ag',  48: 'Cd',  49: 'In',  50: 'Sn',
    51: 'Sb',  52: 'Te',  53: 'I',   54: 'Xe',  55: 'Cs',  56: 'Ba',  57: 'La',  58: 'Ce',  59: 'Pr',  60: 'Nd',
    61: 'Pm',  62: 'Sm',  63: 'Eu',  64: 'Gd', 65: 'Tb',  66: 'Dy',  67: 'Ho',  68: 'Er',  69: 'Tm',  70: 'Yb',
    71: 'Lu',  72: 'Hf',  73: 'Ta',  74: 'W',   75: 'Re',  76: 'Os',  77: 'Ir',  78: 'Pt',  79: 'Au',  80: 'Hg',
    81: 'Tl',  82: 'Pb',  83: 'Bi',  84: 'Po',  85: 'At',  86: 'Rn',  87: 'Fr',  88: 'Ra',  89: 'Ac',  90: 'Th',
    91: 'Pa',  92: 'U',   93: 'Np',  94: 'Pu',  95: 'Am',  96: 'Cm',  97: 'Bk',  98: 'Cf',  99: 'Es', 100: 'Fm',
    101: 'Md', 102: 'No', 103: 'Lr', 104: 'Rf', 105: 'Db', 106: 'Sg', 107: 'Bh', 108: 'Hs', 109: 'Mt', 110: 'Ds',
    111: 'Rg', 112: 'Cn', 113: 'Nh', 114: 'Fl', 115: 'Mc', 116: 'Lv', 117: 'Ts', 118: 'Og'
}

# %%
def xyz_block_from_node_features(xh: torch.tensor, comment: str="", c2a: dict=atomic_num2sym) -> str:
    num_atoms = xh.shape[0]
    xyz_lines = [str(num_atoms), comment]
    for row in xh:
        position = row[:3].cpu().numpy()
        z = c2a[row[-1].long().item()]
        xyz_lines.append(f"{z}\t" + "\t".join([str(x) for x in position]))
    return "\n".join(xyz_lines)

# %%
output_dir_basename = "sample_random_TS-20260626-C6H6-filtered_new-w_wo-w_wo-w_wo-vs_www_valid" # UPDATE
output_dir = os.path.abspath(os.path.join("results/", output_dir_basename))
os.makedirs(output_dir, exist_ok=True)

# %% [raw]
# ddpm_trainer = prep_ddpm_trainer(ckpt_path, device=device)

# %%
# !ls -haltr oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/ | grep C6H6 | grep bz64
# Out:
# drwxr-xr-x   2 guest50 users 4.0K Aug 22  2025 C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5
# drwxr-xr-x   2 guest50 users 4.0K Aug 22  2025 C6H6_5710-0-wSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet0c6a5355a394
# drwxr-xr-x   2 guest50 users 4.0K Aug 22  2025 C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93
# drwxr-xr-x   2 guest50 users 4.0K Aug 23  2025 C6H6_5710-0-wSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnetd095e07080e3
# drwxr-xr-x   2 guest50 users 4.0K Aug 23  2025 C6H6_5710-0-woSL-wBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet22b35e509597
# drwxr-xr-x   2 guest50 users 4.0K Aug 23  2025 C6H6_5710-0-wSL-wBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnetad3824c569fd
# drwxr-xr-x   2 guest50 users 4.0K Aug 23  2025 C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9
# drwxr-xr-x   2 guest50 users 4.0K Aug 23  2025 C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211

# %% [raw]
# C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5
# C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93
# C6H6_5710-0-woSL-wBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet22b35e509597
# C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211
# C6H6_5710-0-wSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet0c6a5355a394
# C6H6_5710-0-wSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnetd095e07080e3
# C6H6_5710-0-wSL-wBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnetad3824c569fd
# C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9

# %%
# !ls -haltr oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5
# Out:
# total 1.6G
# -rw-r--r--   1 guest50 users  29K Aug 16  2025 leftnet.py
# -rw-r--r--   1 guest50 users 163M Aug 19  2025 ddpm-epoch=1053-val-totloss=474.38.ckpt
# -rw-r--r--   1 guest50 users 163M Aug 19  2025 ddpm-epoch=1078-val-totloss=479.92.ckpt
# -rw-r--r--   1 guest50 users 163M Aug 19  2025 ddpm-epoch=1411-val-totloss=474.10.ckpt
# -rw-r--r--   1 guest50 users 163M Aug 20  2025 ddpm-epoch=1824-val-totloss=483.62.ckpt
# -rw-r--r--   1 guest50 users 163M Aug 20  2025 ddpm-epoch=1932-val-totloss=485.03.ckpt
# -rw-r--r--   1 guest50 users 163M Aug 21  2025 ddpm-epoch=2184-val-totloss=483.80.ckpt
# -rw-r--r--   1 guest50 users 163M Aug 21  2025 ddpm-epoch=2368-val-totloss=481.17.ckpt
# -rw-r--r--   1 guest50 users 163M Aug 21  2025 ddpm-epoch=2370-val-totloss=480.35.ckpt
# -rw-r--r--   1 guest50 users 163M Aug 22  2025 ddpm-epoch=2501-val-totloss=483.48.ckpt
# -rw-r--r--   1 guest50 users 163M Aug 22  2025 ddpm-epoch=2512-val-totloss=482.90.ckpt
# drwxr-xr-x   2 guest50 users 4.0K Aug 22  2025 .
# drwxr-xr-x 173 guest50 users  16K Jun 24 15:22 ..

# %%
#checkpoints_to_try = ["./oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/leftnet-SCAN-6-w_selfoops-lr2.5e-4-rcmconly_passerini-03516f3022c5/ddpm-epoch=1899-val-totloss=736.23.ckpt"]

# %%
from collections import defaultdict
per_checkpoint_ts_rmsds = defaultdict(list)

# %%
from parse import parse

# %%
import os

basedir = os.path.abspath("oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN")
# UPDATE :
run_names = [ #"C6H6_5710-0-woSL-wBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet22b35e509597", 
             #"C6H6_5710-0-wSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet0c6a5355a394", 
             #"C6H6_5710-0-wSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnetd095e07080e3", 
             #"C6H6_5710-0-wSL-wBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnetad3824c569fd", 
             "C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9",
             "C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211",
             "C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93",
             "C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5",
             "C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0",
            ]

selected_checkpoint_paths = {}
self_loops=True
lr = "5e-4"
for run_name in run_names:
    print(run_name)
    runpath = os.path.join(basedir, run_name)
    #parsed = parse("9{self_loops}-{lr}e-4-{etc}", run_name)
    #self_loops = parsed["self_loops"]+"_self_loops"
    name_parts = run_name.split("-")
    lrs = None
    if "StepLR" in name_parts:
        lrs = "StepLR"
    elif "CosAnnl" in name_parts:
        lrs = "CosineAnnealing"
    #lr = parsed["lr"]+"e-4"
 
    # Let's select only the latest saved checkpoint and those among the top-k older checkpoints that have better val-totloss.
    checkpoints = []
    for file in os.listdir(runpath):
         if file.endswith(".ckpt"):
             ckpt_path = os.path.join(runpath, file)
             mod_time = os.path.getmtime(ckpt_path)
             checkpoints.append(tuple([file, mod_time]))
    checkpoints.sort(key=lambda x: x[1], reverse=True) # Most recent first.
    
    selected_checkpoints = []
    seen_val_totloss = set()
    for ckpt, _ in checkpoints:
        parsed2 = parse("ddpm-epoch={epoch}-val-totloss={val-totloss}.ckpt", ckpt)
        val_totloss = float(parsed2["val-totloss"])
        epoch = int(parsed2["epoch"])
        if all(val_totloss < value for value in seen_val_totloss):
            seen_val_totloss.add(val_totloss)
            selected_checkpoints.append(ckpt)
            ckpt_path = os.path.join(runpath, ckpt)
            selected_checkpoint_paths[ckpt_path] = {"self_loops":self_loops, "lr":lr, "lr_scheduler":lrs, "epoch":epoch, "val-totloss":val_totloss} # , "rmsds":{}
    print(list(reversed(selected_checkpoints)))
    print(len(selected_checkpoints))
    print("")
# Out:
# C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9
# ['ddpm-epoch=2760-val-totloss=471.14.ckpt', 'ddpm-epoch=2991-val-totloss=476.16.ckpt']
# 2
#
# C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211
# ['ddpm-epoch=1905-val-totloss=477.35.ckpt', 'ddpm-epoch=2510-val-totloss=477.80.ckpt', 'ddpm-epoch=2991-val-totloss=479.30.ckpt']
# 3
#
# C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93
# ['ddpm-epoch=2168-val-totloss=468.57.ckpt', 'ddpm-epoch=2827-val-totloss=477.90.ckpt']
# 2
#
# C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5
# ['ddpm-epoch=1411-val-totloss=474.10.ckpt', 'ddpm-epoch=2370-val-totloss=480.35.ckpt', 'ddpm-epoch=2512-val-totloss=482.90.ckpt']
# 3
#
# C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0
# ['ddpm-epoch=2932-val-totloss=457.68.ckpt', 'ddpm-epoch=2947-val-totloss=465.87.ckpt']
# 2

# %%
all([x==1 for x in dataset.raw_dataset["single_fragment"]])
# Out:
# True

# %% [raw]
# # No longer required with sort in SCAN.py working correctly.
#
# # Valid indexing different from train?
#
# for i in range(len(dataset)):
#     representations, res = next(itl)
#     if i % 500 == 0:
#         print(i)
#     #valid_idx = single_frag_inds[i] #valid_pkl["use_ind"][i] ## THIS IS WHERE THE UNSORTED SET IN SCAN.py CAUSED ISSUES.
#     valid_idx = valid_pkl["use_ind"][i]
#     #print(valid_idx)
#     rxn_id = valid_pkl["reactant"]["rxn"][valid_idx]
#     #print(rxn_id)
#     n_samples = representations[0]["size"].size(0)
#     fragments_nodes = [
#         repre["size"] for repre in representations
#     ]
#     conditions = torch.tensor([[0] for _ in range(n_samples)], device=device)
#     # skipping permutation of indices in reactant state
#     xh_fixed = [
#         torch.cat(
#             [repre[feature_type] for feature_type in FEATURE_MAPPING],
#             dim=1,
#         )
#         for repre in representations
#     ]
#     #print(xh_fixed[2].shape[0])
#     #print(valid_pkl["reactant"]['num_atoms'][valid_idx])
#     #print("")
#     #continue
#     assert xh_fixed[2].shape[0] == valid_pkl["reactant"]['num_atoms'][valid_idx]

# %%
corr_plot_data = {"val-totloss":[], "rmsd":[], "rxn_id":[], "epoch":[], "checkpoint":[], "num_atoms":[]}
per_rxn_rmsds = defaultdict(list)

# %%
selected_representation_triples = {}
rs_rmsdsx = []
ts_rmsdsx = []
ps_rmsdsx = []

selected_indices = selected_valid_indices # valid, not train

for i in range(len(dataset)): 
    representations, res = next(itl)
    if i in selected_indices: #random_indices:
        xyz_blocks = []
        print(i)
        valid_idx = valid_pkl["use_ind"][i]
        print(valid_idx)
        rxn_id = valid_pkl["reactant"]["rxn"][valid_idx]
        print(rxn_id)
        n_samples = representations[0]["size"].size(0)
        fragments_nodes = [
            repre["size"] for repre in representations
        ]
        conditions = torch.tensor([[0] for _ in range(n_samples)], device=device)
        # skipping permutation of indices in reactant state
        xh_fixed = [
            torch.cat(
                [repre[feature_type] for feature_type in FEATURE_MAPPING],
                dim=1,
            )
            for repre in representations
        ]
        print(xh_fixed[2].shape[0])
        print(valid_pkl["reactant"]['num_atoms'][valid_idx])
        assert xh_fixed[2].shape[0] == valid_pkl["reactant"]['num_atoms'][valid_idx]
        #ground_truth_ts = xh_fixed[1]

        if output_dir is not None:            
            # Now wrap up XYZs into an output file with informative comments.
            file_name = f"{rxn_id}.xyz"
            # Reactant state, two versions
            rs_ref_xyz = xyz_block_from_node_features(xh_fixed[0], comment=f"True/calculated reference reactant state.")
            xyz_blocks.append(rs_ref_xyz)
            #rs_rec_xyz = xyz_block_from_node_features(out_samples[0][0], comment=f"Reconstructed reactant state. RMSD: {str(round(rs_rmsds[0],6))} Å.")
            #xyz_blocks.append(rs_rec_xyz)
            
            # Transition state, two versions
            ts_ref_xyz = xyz_block_from_node_features(xh_fixed[1], comment=f"True/calculated reference transition state.")
            xyz_blocks.append(ts_ref_xyz)
            #ts_gen_xyz = xyz_block_from_node_features(out_samples[0][1], comment=f"Generated/inpainted transition state. RMSD: {str(round(ts_rmsds[0],6))} Å.")
            #xyz_blocks.append(ts_gen_xyz)
    
            # Product state, two versions
            ps_ref_xyz = xyz_block_from_node_features(xh_fixed[2], comment=f"True/calculated reference product state.")
            xyz_blocks.append(ps_ref_xyz)
            #ps_rec_xyz = xyz_block_from_node_feattotures(out_samples[0][2], comment=f"Reconstructed product state. RMSD: {str(round(ps_rmsds[0],6))} Å.")
            #xyz_blocks.append(ps_rec_xyz)

        for checkpoint_path, ckpt_vals in selected_checkpoint_paths.items():
            checkpoint_name = f"{os.path.dirname(checkpoint_path)}/{os.path.basename(checkpoint_path)}" 
            ddpm_trainer = prep_ddpm_trainer(checkpoint_path, device=device)
            out_samples, out_masks = ddpm_trainer.ddpm.inpaint(
                n_samples=n_samples,
                fragments_nodes=fragments_nodes,
                conditions=conditions,
                return_frames=1,
                resamplings=5,
                jump_length=5,
                timesteps=None,
                xh_fixed=xh_fixed,
                frag_fixed=[0, 2],
            )
            
            # # reactant state (ts_..):
            # rs_rmsds = batch_rmsd(
            #     fragments_nodes, 
            #     out_samples[0],
            #     xh_fixed,
            #     idx=0,
            # )
            # print(rs_rmsds)
            # rs_rmsdsx.append(rs_rmsds[0])
    
            # transition state (ts_..):
            ts_rmsds = batch_rmsd(
                fragments_nodes, 
                out_samples[0],
                xh_fixed,
                idx=1,
            )
            print(f"{checkpoint_name}: {ts_rmsds[0]}")
            per_checkpoint_ts_rmsds[checkpoint_name].append(ts_rmsds[0])
            corr_plot_data["val-totloss"].append(ckpt_vals["val-totloss"])
            corr_plot_data["rmsd"].append(ts_rmsds[0])
            corr_plot_data["rxn_id"].append(rxn_id)
            corr_plot_data["checkpoint"].append(checkpoint_name)
            corr_plot_data["num_atoms"].append(valid_pkl["reactant"]['num_atoms'][valid_idx])
            corr_plot_data["epoch"].append(ckpt_vals["epoch"])

            if output_dir is not None:
                ts_gen_xyz = xyz_block_from_node_features(out_samples[0][1], comment=f"Generated/inpainted transition state. RMSD: {str(round(ts_rmsds[0],6))} Å. By model {checkpoint_name}.")
                xyz_blocks.append(ts_gen_xyz)
        
            # # product state (ps_..):
            # ps_rmsds = batch_rmsd(
            #     fragments_nodes, 
            #     out_samples[0],
            #     xh_fixed,
            #     idx=2,
            # )
            # print(ps_rmsds)
            # ps_rmsdsx.append(ps_rmsds[0])
            #assert len(rmsds) == 1
        print("")

        if output_dir is not None:
            with open(os.path.join(output_dir, file_name), "w") as f_out:
                f_out.write("\n".join(xyz_blocks))
            
        if i == selected_indices[-1]: # no need to keep iterating.
            break
# Out:
# 1
# 16
# C6H6_5710-TS165 CON(24,23)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2991-val-totloss=476.16.ckpt: 0.20902324241875408
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2760-val-totloss=471.14.ckpt: 0.21943652055328766
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2991-val-totloss=479.30.ckpt: 0.20967802348648368
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2510-val-totloss=477.80.ckpt: 0.2141004020320009
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=1905-val-totloss=477.35.ckpt: 0.2033701437689698
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2827-val-totloss=477.90.ckpt: 0.21104377238938044
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2168-val-totloss=468.57.ckpt: 0.21352640537682588
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2512-val-totloss=482.90.ckpt: 0.2098637523028675
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2370-val-totloss=480.35.ckpt: 0.21225058221583323
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=1411-val-totloss=474.10.ckpt: 0.20330215137080776
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.19077390182468285
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.1379380544824253
#
# 3
# 116
# C6H6_5710-TS282 CON(29,37)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2991-val-totloss=476.16.ckpt: 0.023813358022573044
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2760-val-totloss=471.14.ckpt: 0.025589639166003722
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2991-val-totloss=479.30.ckpt: 0.016708563225929743
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2510-val-totloss=477.80.ckpt: 0.023256617925392145
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=1905-val-totloss=477.35.ckpt: 0.01901472115014219
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2827-val-totloss=477.90.ckpt: 0.013198156144763948
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2168-val-totloss=468.57.ckpt: 1.0
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2512-val-totloss=482.90.ckpt: 0.35351873357222874
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2370-val-totloss=480.35.ckpt: 0.030159136161380176
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=1411-val-totloss=474.10.ckpt: 0.09653733183445967
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.10568316922405918
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.030532488662420712
#
# 4
# 119
# C6H6_5710-TS287 CON(86,123)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2991-val-totloss=476.16.ckpt: 0.38494925828517373
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2760-val-totloss=471.14.ckpt: 0.3692833141268779
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2991-val-totloss=479.30.ckpt: 0.6063988152354546
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2510-val-totloss=477.80.ckpt: 0.4135414561256274
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=1905-val-totloss=477.35.ckpt: 0.6555733911316026
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2827-val-totloss=477.90.ckpt: 0.40726400334830526
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2168-val-totloss=468.57.ckpt: 0.029264313520660504
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2512-val-totloss=482.90.ckpt: 0.12079887410625173
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2370-val-totloss=480.35.ckpt: 0.07164752219613423
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=1411-val-totloss=474.10.ckpt: 0.14548350153640574
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.411784802533787
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.22774735944134558
#
# 16
# 512
# C6H6_5710-TS1558 CON(464,100)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2991-val-totloss=476.16.ckpt: 0.01896023784445862
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2760-val-totloss=471.14.ckpt: 0.11380094212778206
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2991-val-totloss=479.30.ckpt: 0.1658016669071915
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2510-val-totloss=477.80.ckpt: 0.01801856002096437
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=1905-val-totloss=477.35.ckpt: 0.041351108539805836
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2827-val-totloss=477.90.ckpt: 0.014518508529094145
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2168-val-totloss=468.57.ckpt: 0.06887759061535259
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2512-val-totloss=482.90.ckpt: 0.27935636156550436
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2370-val-totloss=480.35.ckpt: 0.28723846106040857
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=1411-val-totloss=474.10.ckpt: 0.29240170462479825
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.4806998131546158
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.31616089315463125
#
# 26
# 616
# C6H6_5710-TS17754 CON(521,425)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2991-val-totloss=476.16.ckpt: 0.2398082734772392
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2760-val-totloss=471.14.ckpt: 0.11053629124968155
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2991-val-totloss=479.30.ckpt: 0.08145571210057824
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2510-val-totloss=477.80.ckpt: 0.0762638222639964
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=1905-val-totloss=477.35.ckpt: 0.1134355308535107
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2827-val-totloss=477.90.ckpt: 0.09375090789209704
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2168-val-totloss=468.57.ckpt: 0.11909248684741829
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2512-val-totloss=482.90.ckpt: 0.2992757039712926
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2370-val-totloss=480.35.ckpt: 1.0
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2827-val-totloss=477.90.ckpt: 0.31968114808983744
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2168-val-totloss=468.57.ckpt: 0.012166239063829734
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2512-val-totloss=482.90.ckpt: 0.03169796375524035
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2370-val-totloss=480.35.ckpt: 0.3139574156936916
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=1411-val-totloss=474.10.ckpt: 0.3158502096869725
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.03399003817503499
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.3146919983379919
#
# 29
# 699
# C6H6_5710-TS2996 CON(431,570)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2991-val-totloss=476.16.ckpt: 0.11981132124597918
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2760-val-totloss=471.14.ckpt: 0.1026366116491911
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2991-val-totloss=479.30.ckpt: 0.16410587834580048
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2510-val-totloss=477.80.ckpt: 0.1593305348870486
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=1905-val-totloss=477.35.ckpt: 0.2037409064339953
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2827-val-totloss=477.90.ckpt: 0.18958442452036417
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2168-val-totloss=468.57.ckpt: 0.29462314853880983
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2512-val-totloss=482.90.ckpt: 0.2849734976624483
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2370-val-totloss=480.35.ckpt: 0.1826184274349971
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=1411-val-totloss=474.10.ckpt: 0.15250252261571967
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.3771882986357411
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.31027396835929116
#
# 32
# 740
# C6H6_5710-TS2227 CON(220,416)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2991-val-totloss=476.16.ckpt: 0.4381607341861369
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2760-val-totloss=471.14.ckpt: 0.4357284984444478
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2991-val-totloss=479.30.ckpt: 0.02560995400134171
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2510-val-totloss=477.80.ckpt: 0.44240987535432696
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=1905-val-totloss=477.35.ckpt: 0.43995188815472247
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2827-val-totloss=477.90.ckpt: 0.4307073858444396
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2168-val-totloss=468.57.ckpt: 0.4180148068423455
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2512-val-totloss=482.90.ckpt: 0.441762280813659
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2370-val-totloss=480.35.ckpt: 0.4432369432038996
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=1411-val-totloss=474.10.ckpt: 0.31942187419737145
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.442447177021155
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.38040641985990026
#
# 33
# 753
# C6H6_5710-TS14070 CON(600,237)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2991-val-totloss=476.16.ckpt: 0.3589462785491571
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2760-val-totloss=471.14.ckpt: 0.33136340704589967
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2991-val-totloss=479.30.ckpt: 0.3283801992671348
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2510-val-totloss=477.80.ckpt: 0.3448375388152695
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=1905-val-totloss=477.35.ckpt: 0.2970319886166376
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2827-val-totloss=477.90.ckpt: 0.7974166136933967
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2168-val-totloss=468.57.ckpt: 0.2954008054035632
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2512-val-totloss=482.90.ckpt: 0.2585207224910428
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2370-val-totloss=480.35.ckpt: 0.3208854036488122
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=1411-val-totloss=474.10.ckpt: 0.6569574431993869
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.2825047600770991
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.3573923107565229
#
# 35
# 815
# C6H6_5710-TS2465 CON(214,547)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2991-val-totloss=476.16.ckpt: 0.16011038120734117
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2760-val-totloss=471.14.ckpt: 0.427616722924336
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2991-val-totloss=479.30.ckpt: 0.0949132880239494
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2510-val-totloss=477.80.ckpt: 0.16339853557790138
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=1905-val-totloss=477.35.ckpt: 1.0
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2827-val-totloss=477.90.ckpt: 0.14660324735874328
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2168-val-totloss=468.57.ckpt: 0.06339916759260818
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2512-val-totloss=482.90.ckpt: 0.3148670450580372
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2370-val-totloss=480.35.ckpt: 0.4100006045620754
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=1411-val-totloss=474.10.ckpt: 0.2494948033600014
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.10695195845926284
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.7558577089593618
#
# 36
# 825
# C6H6_5710-TS2491 CON(606,486)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2991-val-totloss=476.16.ckpt: 0.026932421960698415
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2760-val-totloss=471.14.ckpt: 0.40581759757793284
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2991-val-totloss=479.30.ckpt: 0.0191957884697857
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2510-val-totloss=477.80.ckpt: 0.5123416344385296
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=1905-val-totloss=477.35.ckpt: 0.032004040369633
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2827-val-totloss=477.90.ckpt: 0.02649751115648598
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2168-val-totloss=468.57.ckpt: 0.46854769599966495
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2512-val-totloss=482.90.ckpt: 0.46380467887085414
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2370-val-totloss=480.35.ckpt: 0.4604179631847097
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=1411-val-totloss=474.10.ckpt: 0.2944387186167776
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.7230100416510199
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.02871755074615375
#
# 41
# 895
# C6H6_5710-TS2673 CON(529,345)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2991-val-totloss=476.16.ckpt: 0.21594800642558434
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2760-val-totloss=471.14.ckpt: 0.19056709119252432
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2991-val-totloss=479.30.ckpt: 0.20870926375580617
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2510-val-totloss=477.80.ckpt: 0.08947414920050208
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=1905-val-totloss=477.35.ckpt: 0.3922155220547453
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2827-val-totloss=477.90.ckpt: 0.19239295622214492
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2168-val-totloss=468.57.ckpt: 0.1312197727445668
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2512-val-totloss=482.90.ckpt: 0.3958859885273464
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2370-val-totloss=480.35.ckpt: 0.162747864721444
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=1411-val-totloss=474.10.ckpt: 0.13608235241186978
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.27064552285920873
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.41860988497715573
#
# 47
# 991
# C6H6_5710-TS2935 CON(215,338)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2991-val-totloss=476.16.ckpt: 0.4721631536429812
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2760-val-totloss=471.14.ckpt: 0.3346622274561605
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2991-val-totloss=479.30.ckpt: 0.17744710525126423
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2510-val-totloss=477.80.ckpt: 0.3844086346458794
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=1905-val-totloss=477.35.ckpt: 0.7356729997629728
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2827-val-totloss=477.90.ckpt: 0.07375718373972119
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2168-val-totloss=468.57.ckpt: 0.06534000327556047
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2512-val-totloss=482.90.ckpt: 0.4522247251855321
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2370-val-totloss=480.35.ckpt: 0.3872166617396302
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=1411-val-totloss=474.10.ckpt: 0.5326655884227779
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.4455334264292099
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.5254249922055021
#
# 56
# 1122
# C6H6_5710-TS3282 CON(64,198)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2991-val-totloss=476.16.ckpt: 0.03332278727452317
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2760-val-totloss=471.14.ckpt: 0.029254816215079367
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2991-val-totloss=479.30.ckpt: 0.033690040651596406
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2510-val-totloss=477.80.ckpt: 0.02163354669519482
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=1905-val-totloss=477.35.ckpt: 0.401165158000315
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2827-val-totloss=477.90.ckpt: 0.03041010724089407
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2168-val-totloss=468.57.ckpt: 0.02574447764827831
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2512-val-totloss=482.90.ckpt: 0.02069617619770447
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2370-val-totloss=480.35.ckpt: 0.023782427313175973
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=1411-val-totloss=474.10.ckpt: 0.03500476905272232
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.4360336031483188
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.39982620632669075
#
# 60
# 1156
# C6H6_5710-TS3385 CON(550,71)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2991-val-totloss=476.16.ckpt: 0.026714666750183077
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2760-val-totloss=471.14.ckpt: 0.031165404440902968
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2991-val-totloss=479.30.ckpt: 0.24532385317599134
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2510-val-totloss=477.80.ckpt: 0.017519063390606392
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=1905-val-totloss=477.35.ckpt: 0.23611392628640768
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2827-val-totloss=477.90.ckpt: 0.018717042573254225
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2168-val-totloss=468.57.ckpt: 0.3309191592274435
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2512-val-totloss=482.90.ckpt: 0.20779604270168436
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2370-val-totloss=480.35.ckpt: 0.33510517928089395
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=1411-val-totloss=474.10.ckpt: 0.38687689891281185
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.48843795855931316
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.42675761294930775
#
# 61
# 1166
# C6H6_5710-TS3430 CON(216,236)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2991-val-totloss=476.16.ckpt: 0.30437715481377337
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2760-val-totloss=471.14.ckpt: 0.3849175814261651
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2991-val-totloss=479.30.ckpt: 0.3316909218010049
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2510-val-totloss=477.80.ckpt: 0.30965840847625786
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=1905-val-totloss=477.35.ckpt: 0.425379027440279
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2827-val-totloss=477.90.ckpt: 0.37986366013980777
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2168-val-totloss=468.57.ckpt: 0.38305088321167235
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2512-val-totloss=482.90.ckpt: 0.3444542195889174
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2370-val-totloss=480.35.ckpt: 0.318579959748991
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=1411-val-totloss=474.10.ckpt: 0.3357919341083429
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.3766885062095954
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.3184481399495659
#
# 62
# 1167
# C6H6_5710-TS3434 CON(15,742)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2991-val-totloss=476.16.ckpt: 0.010918410437823163
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2760-val-totloss=471.14.ckpt: 0.03993935208232892
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2991-val-totloss=479.30.ckpt: 0.3559523500178777
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2510-val-totloss=477.80.ckpt: 0.3137503197342869
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=1905-val-totloss=477.35.ckpt: 0.7640001143663459
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2827-val-totloss=477.90.ckpt: 0.07084183431082643
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2168-val-totloss=468.57.ckpt: 0.028851846654282334
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2512-val-totloss=482.90.ckpt: 0.449590869577825
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2370-val-totloss=480.35.ckpt: 0.3293572398568506
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=1411-val-totloss=474.10.ckpt: 0.45001041154942695
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.7059333401875155
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.389068246136796
#
# 63
# 1218
# C6H6_5710-TS3588 CON(712,766)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2991-val-totloss=476.16.ckpt: 0.0191979486706509
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2760-val-totloss=471.14.ckpt: 0.024615066401685367
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2991-val-totloss=479.30.ckpt: 0.3729405261464969
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2510-val-totloss=477.80.ckpt: 0.7032919296384859
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=1905-val-totloss=477.35.ckpt: 0.6691686452610225
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2827-val-totloss=477.90.ckpt: 0.7675116019673786
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2168-val-totloss=468.57.ckpt: 0.8276734001135909
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2512-val-totloss=482.90.ckpt: 0.4468711704374842
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2370-val-totloss=480.35.ckpt: 0.3588397215848592
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=1411-val-totloss=474.10.ckpt: 0.6031712647578622
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.8550294068448374
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.6910049800345256
#
# 76
# 1635
# C6H6_5710-TS4745 CON(418,344)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2991-val-totloss=476.16.ckpt: 0.09067338484351266
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2760-val-totloss=471.14.ckpt: 0.0175774069092199
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2991-val-totloss=479.30.ckpt: 0.04795872897209746
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2510-val-totloss=477.80.ckpt: 0.27907726843601377
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=1905-val-totloss=477.35.ckpt: 0.0665222009028153
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2827-val-totloss=477.90.ckpt: 0.022457070316978828
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2168-val-totloss=468.57.ckpt: 0.038753863312497736
# ...
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.1294092116119812
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.45194097463583344
#
# 308
# 6274
# C6H6_5710-TS17719 CON(44,1452)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2991-val-totloss=476.16.ckpt: 0.014307516829068041
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2760-val-totloss=471.14.ckpt: 0.01779671533957144
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2991-val-totloss=479.30.ckpt: 1.0
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2510-val-totloss=477.80.ckpt: 0.04347405542653333
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=1905-val-totloss=477.35.ckpt: 0.02966316548090349
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2827-val-totloss=477.90.ckpt: 0.09471381683942148
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2168-val-totloss=468.57.ckpt: 0.3735670366180264
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2512-val-totloss=482.90.ckpt: 0.3490251848715497
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2370-val-totloss=480.35.ckpt: 0.4094433885507146
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=1411-val-totloss=474.10.ckpt: 0.17522222255648423
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.2904759514506162
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.4202142002772632
#
# 315
# 6376
# C6H6_5710-TS18025 CON(751,945)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2991-val-totloss=476.16.ckpt: 0.03984336971061472
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2760-val-totloss=471.14.ckpt: 0.3449347837255003
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2991-val-totloss=479.30.ckpt: 0.03177588619124982
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2510-val-totloss=477.80.ckpt: 0.1088660445666766
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=1905-val-totloss=477.35.ckpt: 0.06380510877418616
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2827-val-totloss=477.90.ckpt: 0.06247025480791651
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2168-val-totloss=468.57.ckpt: 0.053135008457853815
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2512-val-totloss=482.90.ckpt: 0.06393940812386929
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2370-val-totloss=480.35.ckpt: 0.02883611627072847
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=1411-val-totloss=474.10.ckpt: 0.03583302056347295
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.13113301463415244
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.6157923009806537
#
# 316
# 6405
# C6H6_5710-TS18158 CON(1116,417)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2991-val-totloss=476.16.ckpt: 0.09024764124789633
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2760-val-totloss=471.14.ckpt: 0.2402670406114245
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2991-val-totloss=479.30.ckpt: 0.06558558344757075
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2510-val-totloss=477.80.ckpt: 0.0725773544106647
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=1905-val-totloss=477.35.ckpt: 0.2755825384865373
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2827-val-totloss=477.90.ckpt: 0.06212710331933768
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2168-val-totloss=468.57.ckpt: 0.1718516582303191
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2512-val-totloss=482.90.ckpt: 0.44356149498728875
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2370-val-totloss=480.35.ckpt: 0.44241358161683425
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=1411-val-totloss=474.10.ckpt: 0.57056092732691
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.5206225270348711
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.5554607711091389
#
# 318
# 6453
# C6H6_5710-TS18298 CON(1396,356)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2991-val-totloss=476.16.ckpt: 0.09101265350249714
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2760-val-totloss=471.14.ckpt: 0.19499836651338615
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2991-val-totloss=479.30.ckpt: 0.0672658196152863
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2510-val-totloss=477.80.ckpt: 0.3415814938210293
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=1905-val-totloss=477.35.ckpt: 0.1480950482112763
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2827-val-totloss=477.90.ckpt: 0.03944045238456538
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2168-val-totloss=468.57.ckpt: 0.2974761083761961
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2512-val-totloss=482.90.ckpt: 0.37294586301177846
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2370-val-totloss=480.35.ckpt: 0.39004124550856534
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=1411-val-totloss=474.10.ckpt: 0.39394626617005374
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.9436091771955548
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.43306732815939436
#
# 320
# 6513
# C6H6_5710-TS18461 CON(188,1519)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2991-val-totloss=476.16.ckpt: 0.3756393659076294
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2760-val-totloss=471.14.ckpt: 0.18894957582852903
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2991-val-totloss=479.30.ckpt: 0.27373487921466766
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2510-val-totloss=477.80.ckpt: 0.30480226308215913
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=1905-val-totloss=477.35.ckpt: 0.32410387868582846
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2827-val-totloss=477.90.ckpt: 0.26016185266146963
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2168-val-totloss=468.57.ckpt: 0.4434059839715958
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2512-val-totloss=482.90.ckpt: 0.4310087262021623
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2370-val-totloss=480.35.ckpt: 0.305186482040736
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=1411-val-totloss=474.10.ckpt: 0.3761773323821384
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.4488436359989094
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.43208726533225605
#
# 322
# 6534
# C6H6_5710-TS18515 CON(597,1522)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2991-val-totloss=476.16.ckpt: 0.260650138784276
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2760-val-totloss=471.14.ckpt: 0.32329703940132354
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2991-val-totloss=479.30.ckpt: 0.3123207068181629
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2510-val-totloss=477.80.ckpt: 0.2623117032058032
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=1905-val-totloss=477.35.ckpt: 0.33792792981709224
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2827-val-totloss=477.90.ckpt: 0.26724371486060977
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2168-val-totloss=468.57.ckpt: 0.26078455886918794
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2512-val-totloss=482.90.ckpt: 0.03198845767203508
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2370-val-totloss=480.35.ckpt: 0.3075457998833354

# %%
selected_rxns_dict
# Out:
# {}

# %%
1-3/13
# Out:
# 0.7692307692307692

# %%
#select_rxns
pprint(dict(sorted(selected_rxns_dict.items())))
# Out:
# {}

# %%
# Report/analysis of RMSDs seen:

#rs_mean = round(np.mean(rs_rmsdsx), 6)
#rs_std = round(np.std(rs_rmsdsx), 6)
#print(f"Reactant state reconstruction RMSD was mean ± std.dev.: \t{rs_mean} \t± {rs_std} Å.")
ts_mean = round(np.mean(ts_rmsds), 6)
ts_std = round(np.std(ts_rmsds), 6)
print(f"Transition state inpainting RMSD was mean ± std.dev.: \t\t{ts_mean} \t± {ts_std} Å.")
#ps_mean = round(np.mean(ps_rmsdsx), 6)
#ps_std = round(np.std(ps_rmsdsx), 6)
#print(f"Product state reconstruction RMSD was mean ± std.dev.: \t\t{ps_mean} \t± {ps_std} Å.")
# Out:
# Transition state inpainting RMSD was mean ± std.dev.: 		0.359765 	± 0.18323 Å.

# %% [markdown]
# Tried checkpoints, fraction of RMSD==1.0, and mean RMSD:
#
# `checkpoint_path="./oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/leftnet-SCAN-6-w_selfoops-lr2.5e-4-rcmconly_passerini-03516f3022c5/...`
#
# `ddpm-epoch=999-val-totloss=770.24.ckpt`: ...
#
# `ddpm-epoch=1799-val-totloss=787.66.ckpt`: 12/20, 0.819974 	± 0.273995 Å.

# %%
for checkpoint_name, ts_rmsds in per_checkpoint_ts_rmsds.items():
    print(checkpoint_name)
    ts_mean = round(np.mean(ts_rmsds), 6)
    ts_std = round(np.std(ts_rmsds), 6)
    failures = len([x for x in ts_rmsds if x == 1.0])
    print(f"    Transition state inpainting RMSD was mean ± std.dev.: \t\t{ts_mean} \t± {ts_std} Å.")
    print(f"    Number of 1.0 RMSD indicating complete failure: {failures} out of {len(ts_rmsds)}.")
    print("")
# Out:
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2991-val-totloss=476.16.ckpt
#     Transition state inpainting RMSD was mean ± std.dev.: 		0.165109 	± 0.157268 Å.
#     Number of 1.0 RMSD indicating complete failure: 0 out of 100.
#
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9/ddpm-epoch=2760-val-totloss=471.14.ckpt
#     Transition state inpainting RMSD was mean ± std.dev.: 		0.186536 	± 0.173363 Å.
#     Number of 1.0 RMSD indicating complete failure: 0 out of 100.
#
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2991-val-totloss=479.30.ckpt
#     Transition state inpainting RMSD was mean ± std.dev.: 		0.198943 	± 0.217327 Å.
#     Number of 1.0 RMSD indicating complete failure: 3 out of 100.
#
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=2510-val-totloss=477.80.ckpt
#     Transition state inpainting RMSD was mean ± std.dev.: 		0.209758 	± 0.195345 Å.
#     Number of 1.0 RMSD indicating complete failure: 1 out of 100.
#
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211/ddpm-epoch=1905-val-totloss=477.35.ckpt
#     Transition state inpainting RMSD was mean ± std.dev.: 		0.248375 	± 0.234682 Å.
#     Number of 1.0 RMSD indicating complete failure: 3 out of 100.
#
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2827-val-totloss=477.90.ckpt
#     Transition state inpainting RMSD was mean ± std.dev.: 		0.172786 	± 0.191474 Å.
#     Number of 1.0 RMSD indicating complete failure: 1 out of 100.
#
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93/ddpm-epoch=2168-val-totloss=468.57.ckpt
#     Transition state inpainting RMSD was mean ± std.dev.: 		0.186113 	± 0.189946 Å.
#     Number of 1.0 RMSD indicating complete failure: 1 out of 100.
#
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2512-val-totloss=482.90.ckpt
#     Transition state inpainting RMSD was mean ± std.dev.: 		0.257999 	± 0.206266 Å.
#     Number of 1.0 RMSD indicating complete failure: 2 out of 100.
#
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=2370-val-totloss=480.35.ckpt
#     Transition state inpainting RMSD was mean ± std.dev.: 		0.254866 	± 0.196181 Å.
#     Number of 1.0 RMSD indicating complete failure: 1 out of 100.
#
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5/ddpm-epoch=1411-val-totloss=474.10.ckpt
#     Transition state inpainting RMSD was mean ± std.dev.: 		0.287096 	± 0.206179 Å.
#     Number of 1.0 RMSD indicating complete failure: 1 out of 100.
#
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt
#     Transition state inpainting RMSD was mean ± std.dev.: 		0.419391 	± 0.215831 Å.
#     Number of 1.0 RMSD indicating complete failure: 1 out of 100.
#
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt
#     Transition state inpainting RMSD was mean ± std.dev.: 		0.359765 	± 0.18323 Å.
#     Number of 1.0 RMSD indicating complete failure: 0 out of 100.

# %%
output_dir
# Out:
# '/misc/home/guest50/OAReactDiff/results/sample_random_TS-20260626-C6H6-filtered_new-w_wo-w_wo-w_wo-vs_www_valid'

# %%
import pandas as pd

# %%
for key, val in corr_plot_data.items():
    print(f"{key}: {len(val)}")
# Out:
# val-totloss: 1200
# rmsd: 1200
# rxn_id: 1200
# epoch: 1200
# checkpoint: 1200
# num_atoms: 1200

# %%
if len(corr_plot_data["epoch"]) == 0:
    fix_epochs = []
    for checkpoint_name in corr_plot_data["checkpoint"]:
        parts = checkpoint_name.split("-")
        for part in parts:
            if part[:6] == "epoch=":
                epoch = int(part[6:])
                fix_epochs.append(epoch)
    corr_plot_data["epoch"] = fix_epochs

# %%
df = pd.DataFrame(data=corr_plot_data)
df
# Out:
#       val-totloss      rmsd                         rxn_id  epoch  \
# 0          476.16  0.209023     C6H6_5710-TS165 CON(24,23)   2991
# 1          471.14  0.219437     C6H6_5710-TS165 CON(24,23)   2760
# 2          479.30  0.209678     C6H6_5710-TS165 CON(24,23)   2991
# 3          477.80  0.214100     C6H6_5710-TS165 CON(24,23)   2510
# 4          477.35  0.203370     C6H6_5710-TS165 CON(24,23)   1905
# ...           ...       ...                            ...    ...
# 1195       482.90  0.034181  C6H6_5710-TS18622 CON(195,71)   2512
# 1196       480.35  0.239770  C6H6_5710-TS18622 CON(195,71)   2370
# 1197       474.10  0.217805  C6H6_5710-TS18622 CON(195,71)   1411
# 1198       465.87  0.723009  C6H6_5710-TS18622 CON(195,71)   2947
# 1199       457.68  0.266385  C6H6_5710-TS18622 CON(195,71)   2932
#
#                                              checkpoint  num_atoms
# 0     /misc/home/guest50/OAReactDiff/oa_reactdiff/tr...         12
# 1     /misc/home/guest50/OAReactDiff/oa_reactdiff/tr...         12
# 2     /misc/home/guest50/OAReactDiff/oa_reactdiff/tr...         12
# 3     /misc/home/guest50/OAReactDiff/oa_reactdiff/tr...         12
# 4     /misc/home/guest50/OAReactDiff/oa_reactdiff/tr...         12
# ...                                                 ...        ...
# 1195  /misc/home/guest50/OAReactDiff/oa_reactdiff/tr...         12
# 1196  /misc/home/guest50/OAReactDiff/oa_reactdiff/tr...         12
# 1197  /misc/home/guest50/OAReactDiff/oa_reactdiff/tr...         12
# 1198  /misc/home/guest50/OAReactDiff/oa_reactdiff/tr...         12
# 1199  /misc/home/guest50/OAReactDiff/oa_reactdiff/tr...         12
#
# [1200 rows x 6 columns]

# %%
df.plot(x="val-totloss", y="rmsd", kind="scatter")
# Out:
# <Axes: xlabel='val-totloss', ylabel='rmsd'>

# %%
df.plot(x="epoch", y="val-totloss", kind="scatter")
# Out:
# <Axes: xlabel='epoch', ylabel='val-totloss'>

# %%
df.plot(x="epoch", y="rmsd", kind="scatter")
# Out:
# <Axes: xlabel='epoch', ylabel='rmsd'>

# %%
import ase
from ase.io import read, write

# %%
output_dir
# Out:
# '/misc/home/guest50/OAReactDiff/results/sample_random_TS-20260626-C6H6-filtered_new-w_wo-w_wo-w_wo-vs_www_valid'

# %%
# !ls -haltr /misc/home/guest50/OAReactDiff/results/sample_random_TS-20260626-C6H6-filtered_new-w_wo-w_wo-w_wo-vs_www_valid
# Out:
# total 1.6M
# drwxr-xr-x 31 guest50 users 4.0K Jun 26 11:50 ..
# -rw-r--r--  1 guest50 users  14K Jun 26 11:53 C6H6_5710-TS165 CON(24,23).xyz
# -rw-r--r--  1 guest50 users  13K Jun 26 11:56 C6H6_5710-TS282 CON(29,37).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 11:59 C6H6_5710-TS287 CON(86,123).xyz
# -rw-r--r--  1 guest50 users  13K Jun 26 12:02 C6H6_5710-TS1558 CON(464,100).xyz
# -rw-r--r--  1 guest50 users  13K Jun 26 12:04 C6H6_5710-TS17754 CON(521,425).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 12:07 C6H6_5710-TS2014 CON(555,139).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 12:10 C6H6_5710-TS2996 CON(431,570).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 12:13 C6H6_5710-TS2227 CON(220,416).xyz
# -rw-r--r--  1 guest50 users  13K Jun 26 12:16 C6H6_5710-TS14070 CON(600,237).xyz
# -rw-r--r--  1 guest50 users  13K Jun 26 12:19 C6H6_5710-TS2465 CON(214,547).xyz
# -rw-r--r--  1 guest50 users  13K Jun 26 12:22 C6H6_5710-TS2491 CON(606,486).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 12:25 C6H6_5710-TS2673 CON(529,345).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 12:27 C6H6_5710-TS2935 CON(215,338).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 12:30 C6H6_5710-TS3282 CON(64,198).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 12:33 C6H6_5710-TS3385 CON(550,71).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 12:36 C6H6_5710-TS3430 CON(216,236).xyz
# -rw-r--r--  1 guest50 users  13K Jun 26 12:39 C6H6_5710-TS3434 CON(15,742).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 12:42 C6H6_5710-TS3588 CON(712,766).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 12:45 C6H6_5710-TS4745 CON(418,344).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 12:48 C6H6_5710-TS4906 CON(861,653).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 12:51 C6H6_5710-TS5342 CON(923,23).xyz
# -rw-r--r--  1 guest50 users  13K Jun 26 12:54 C6H6_5710-TS6263 CON(109,136).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 12:56 C6H6_5710-TS6296 CON(2,524).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 12:59 C6H6_5710-TS6409 CON(298,1007).xyz
# -rw-r--r--  1 guest50 users  13K Jun 26 13:02 C6H6_5710-TS6622 CON(328,1029).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 13:05 C6H6_5710-TS6637 CON(804,333).xyz
# -rw-r--r--  1 guest50 users  13K Jun 26 13:08 C6H6_5710-TS7086 CON(1021,804).xyz
# -rw-r--r--  1 guest50 users  13K Jun 26 13:11 C6H6_5710-TS7216 CON(682,68).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 13:14 C6H6_5710-TS7432 CON(541,277).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 13:17 C6H6_5710-TS7926 CON(498,139).xyz
# -rw-r--r--  1 guest50 users  13K Jun 26 13:19 C6H6_5710-TS8132 CON(14,44).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 13:22 C6H6_5710-TS8136 CON(60,246).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 13:25 C6H6_5710-TS8151 CON(183,563).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 13:28 C6H6_5710-TS8594 CON(1130,327).xyz
# -rw-r--r--  1 guest50 users  13K Jun 26 13:31 C6H6_5710-TS8615 CON(82,33).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 13:34 C6H6_5710-TS10080 CON(922,333).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 13:37 C6H6_5710-TS8858 CON(611,302).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 13:40 C6H6_5710-TS8861 CON(177,120).xyz
# -rw-r--r--  1 guest50 users  13K Jun 26 13:43 C6H6_5710-TS8914 CON(284,1161).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 13:46 C6H6_5710-TS9273 CON(649,558).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 13:49 C6H6_5710-TS9312 CON(1184,155).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 13:52 C6H6_5710-TS9346 CON(185,460).xyz
# -rw-r--r--  1 guest50 users  13K Jun 26 13:55 C6H6_5710-TS9416 CON(416,266).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 13:58 C6H6_5710-TS9552 CON(694,120).xyz
# -rw-r--r--  1 guest50 users  13K Jun 26 14:01 C6H6_5710-TS9557 CON(43,655).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 14:05 C6H6_5710-TS9608 CON(1206,18).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 14:08 C6H6_5710-TS9814 CON(93,436).xyz
# -rw-r--r--  1 guest50 users  13K Jun 26 14:11 C6H6_5710-TS10523 CON(197,136).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 14:14 C6H6_5710-TS10542 CON(600,1025).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 14:17 C6H6_5710-TS10628 CON(1243,870).xyz
# -rw-r--r--  1 guest50 users  13K Jun 26 14:20 C6H6_5710-TS10657 CON(341,770).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 14:23 C6H6_5710-TS10824 CON(1264,25).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 14:26 C6H6_5710-TS10845 CON(100,921).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 14:29 C6H6_5710-TS10851 CON(222,493).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 14:32 C6H6_5710-TS11244 CON(238,15).xyz
# -rw-r--r--  1 guest50 users  13K Jun 26 14:35 C6H6_5710-TS11450 CON(687,1012).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 14:38 C6H6_5710-TS11468 CON(974,1002).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 14:41 C6H6_5710-TS11572 CON(200,642).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 14:44 C6H6_5710-TS12017 CON(121,135).xyz
# -rw-r--r--  1 guest50 users  13K Jun 26 14:47 C6H6_5710-TS13356 CON(66,170).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 14:50 C6H6_5710-TS12543 CON(661,246).xyz
# -rw-r--r--  1 guest50 users  13K Jun 26 14:53 C6H6_5710-TS12621 CON(99,1170).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 14:56 C6H6_5710-TS12894 CON(598,104).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 14:59 C6H6_5710-TS13051 CON(472,558).xyz
# -rw-r--r--  1 guest50 users  13K Jun 26 15:02 C6H6_5710-TS15541 CON(382,509).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 15:05 C6H6_5710-TS13458 CON(345,936).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 15:08 C6H6_5710-TS13760 CON(772,1377).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 15:11 C6H6_5710-TS13988 CON(1347,196).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 15:15 C6H6_5710-TS14180 CON(835,1117).xyz
# -rw-r--r--  1 guest50 users  13K Jun 26 15:18 C6H6_5710-TS14261 CON(1391,676).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 15:21 C6H6_5710-TS14275 CON(911,515).xyz
# -rw-r--r--  1 guest50 users  13K Jun 26 15:24 C6H6_5710-TS14308 CON(1391,624).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 15:27 C6H6_5710-TS14463 CON(1062,587).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 15:30 C6H6_5710-TS14662 CON(272,1227).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 15:33 C6H6_5710-TS14869 CON(945,188).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 15:36 C6H6_5710-TS14961 CON(858,1408).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 15:39 C6H6_5710-TS15173 CON(276,210).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 15:42 C6H6_5710-TS15335 CON(1425,59).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 15:45 C6H6_5710-TS15748 CON(1068,344).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 15:48 C6H6_5710-TS15795 CON(870,1232).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 15:51 C6H6_5710-TS15932 CON(1163,1134).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 15:54 C6H6_5710-TS16262 CON(740,178).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 15:57 C6H6_5710-TS16608 CON(1471,76).xyz
# -rw-r--r--  1 guest50 users  13K Jun 26 16:00 C6H6_5710-TS16626 CON(435,183).xyz
# -rw-r--r--  1 guest50 users  13K Jun 26 16:03 C6H6_5710-TS16717 CON(1215,772).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 16:06 C6H6_5710-TS16941 CON(1264,587).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 16:09 C6H6_5710-TS16968 CON(1243,868).xyz
# -rw-r--r--  1 guest50 users  13K Jun 26 16:12 C6H6_5710-TS17252 CON(1099,333).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 16:15 C6H6_5710-TS17269 CON(948,356).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 16:18 C6H6_5710-TS17449 CON(1078,754).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 16:21 C6H6_5710-TS17482 CON(679,639).xyz
# -rw-r--r--  1 guest50 users  13K Jun 26 16:24 C6H6_5710-TS17719 CON(44,1452).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 16:27 C6H6_5710-TS18025 CON(751,945).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 16:30 C6H6_5710-TS18158 CON(1116,417).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 16:33 C6H6_5710-TS18298 CON(1396,356).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 16:36 C6H6_5710-TS18461 CON(188,1519).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 16:39 C6H6_5710-TS18515 CON(597,1522).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 16:42 C6H6_5710-TS18517 CON(182,123).xyz
# -rw-r--r--  1 guest50 users  14K Jun 26 16:45 C6H6_5710-TS18612 CON(113,132).xyz
# drwxr-xr-x  2 guest50 users 8.0K Jun 26 16:48 .
# -rw-r--r--  1 guest50 users  14K Jun 26 16:48 C6H6_5710-TS18622 CON(195,71).xyz

# %%
atoms = read(output_dir+'/C6H6_5710-TS18622 CON(195,71).xyz', format='xyz',index=":")

# %%
atoms[1]
# Out:
# Atoms(symbols='C6H6', pbc=False)

# %%
from io import StringIO

def atoms_to_xyz_str(atoms: ase.Atoms):
    f = StringIO()
    atoms.write(f, format="xyz")
    return f.getvalue()

# %%
xyz_01 = atoms_to_xyz_str(atoms[1])
print(xyz_01)
# Out:
# 12
#
# C      -0.035602720000000     -0.271341740000000     -1.555116400000000
# C      -1.014713900000000     -0.043751570000000     -0.582075830000000
# C       1.242402600000000      0.083484000000000     -1.118013700000000
# C      -0.543343070000000      0.463214960000000      0.712999700000000
# C       1.292699800000000      0.348511100000000      0.279411520000000
# C      -0.586081000000000     -0.486204860000000      1.759923500000000
# H      -2.080608400000000     -0.253364530000000     -0.743110300000000
# H       1.708240200000000      1.300187300000000      0.644045500000000
# H      -0.811805840000000     -1.512702300000000      1.367308500000000
# H       1.745792000000000     -0.490684450000000      0.831248500000000
# H      -0.645127650000000      1.535007800000000      0.949962260000000
# H      -0.271852200000000     -0.672355700000000     -2.546583200000000

# %%
draw_in_3dmol(xyz_01)
# Out:
# <div id="3dmolviewer_178246800434874"  style="position: relative; width: 576px; height: 480px;">
#         <p id="3dmolwarning_178246800434874" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_178246800434874 = null;
# var warn = document.getElementById("3dmolwarning_178246800434874");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_178246800434874 = $3Dmol.createViewer(document.getElementById("3dmolviewer_178246800434874"),{backgroundColor:"white"});
# $3Dmol.download("1024", viewer_178246800434874, {}, function() {
# viewer_178246800434874.zoomTo();
# 	viewer_178246800434874.addModel("12\n\nC      -0.035602720000000     -0.271341740000000     -1.555116400000000\nC      -1.014713900000000     -0.043751570000000     -0.582075830000000\nC       1.242402600000000      0.083484000000000     -1.118013700000000\nC      -0.543343070000000      0.463214960000000      0.712999700000000\nC       1.292699800000000      0.348511100000000      0.279411520000000\nC      -0.586081000000000     -0.486204860000000      1.759923500000000\nH      -2.080608400000000     -0.253364530000000     -0.743110300000000\nH       1.708240200000000      1.300187300000000      0.644045500000000\nH      -0.811805840000000     -1.512702300000000      1.367308500000000\nH       1.745792000000000     -0.490684450000000      0.831248500000000\nH      -0.645127650000000      1.535007800000000      0.949962260000000\nH      -0.271852200000000     -0.672355700000000     -2.546583200000000\n","xyz");
# 	viewer_178246800434874.setStyle({"stick": {}, "sphere": {"radius": 0.36}});
# 	viewer_178246800434874.zoomTo();
# viewer_178246800434874.render();
# })
# });
# </script>

# %%
draw_in_3dmol(atoms_to_xyz_str(atoms[-1]))
# Out:
# <div id="3dmolviewer_1782468034268666"  style="position: relative; width: 576px; height: 480px;">
#         <p id="3dmolwarning_1782468034268666" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_1782468034268666 = null;
# var warn = document.getElementById("3dmolwarning_1782468034268666");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1782468034268666 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1782468034268666"),{backgroundColor:"white"});
# $3Dmol.download("1024", viewer_1782468034268666, {}, function() {
# viewer_1782468034268666.zoomTo();
# 	viewer_1782468034268666.addModel("12\n\nC      -0.138552417236452     -1.289524234235584     -0.760765290175340\nC      -0.574618715978826      1.148561080488454      0.848903484647897\nC      -0.439445565909906     -1.352736986731484      0.505187085052387\nC       0.234280555557058     -0.052968814402213     -1.404325848362128\nC       0.479719601914112      0.892268841321341     -0.054627277359575\nC       0.131728475445108     -0.053832972779655      1.171503824643519\nH      -1.643814414938534      1.340358162813696      0.700959548486339\nH       1.158765535256629     -0.050997884501639     -2.030023589872389\nH      -0.949802199629162     -2.112967528744143      1.108241036124358\nH       0.881048691403234     -0.246864701456812      1.942075259586514\nH       1.441659302798145      1.397399397067585     -0.054568984300193\nH      -0.580968848681407      0.381305641160454     -1.972559248471390\n","xyz");
# 	viewer_1782468034268666.setStyle({"stick": {}, "sphere": {"radius": 0.36}});
# 	viewer_1782468034268666.zoomTo();
# viewer_1782468034268666.render();
# })
# });
# </script>
