# %% [markdown]
# # Apply this code to sample TS from model.

# %%
import os

# Set to '0' for the first GPU, '1' for the second, etc.
# Or use a comma-separated string for multiple visible devices, e.g., '0,1'
os.environ["CUDA_VISIBLE_DEVICES"] = "0" # UPDATE

# Verify the setting (optional)
print(f"CUDA_VISIBLE_DEVICES is set to: {os.environ.get('CUDA_VISIBLE_DEVICES')}")

# Now, when you import your deep learning library, it will only see the specified device(s)
import torch
print(f"PyTorch sees {torch.cuda.device_count()} CUDA device(s).")
if torch.cuda.is_available():
    print(f"Current PyTorch device: {torch.cuda.current_device()}")
    print(f"Device name: {torch.cuda.get_device_name(0)}")

# For TensorFlow
# import tensorflow as tf
# print(f"TensorFlow sees {len(tf.config.list_physical_devices('GPU'))} GPU device(s).")
# Out:
# CUDA_VISIBLE_DEVICES is set to: 0
# PyTorch sees 1 CUDA device(s).
# Current PyTorch device: 0
# Device name: NVIDIA A100-PCIE-40GB

# %%
# --- Importing and defining some functions ----
import os
import torch
import py3Dmol
import numpy as np

from typing import Optional
from torch import tensor
from e3nn import o3
from torch_scatter import scatter_mean

from oa_reactdiff.model import LEFTNet

default_float = torch.float64
torch.set_default_dtype(default_float)  # Use double precision for more accurate testing


def remove_mean_batch(
    x: tensor, 
    indices: Optional[tensor] = None
) -> tensor:
    """Remove the mean from each batch in x

    Args:
        x (tensor): input tensor.
        indices (Optional[tensor], optional): batch indices. Defaults to None.

    Returns:
        tensor: output tensor with batch mean as 0.
    """
    if indices == None:
         return x - torch.mean(x, dim=0)
    mean = scatter_mean(x, indices, dim=0)
    x = x - mean[indices]
    return x


def draw_in_3dmol(mol: str, fmt: str = "xyz") -> py3Dmol.view:
    """Draw the molecule

    Args:
        mol (str): str content of molecule.
        fmt (str, optional): format. Defaults to "xyz".

    Returns:
        py3Dmol.view: output viewer
    """
    viewer = py3Dmol.view(1024, 576)
    viewer.addModel(mol, fmt)
    viewer.setStyle({'stick': {}, "sphere": {"radius": 0.36}})
    viewer.zoomTo()
    return viewer


def assemble_xyz(z: list, pos: tensor) -> str:
    """Assembling atomic numbers and positions into xyz format

    Args:
        z (list): chemical elements
        pos (tensor): 3D coordinates

    Returns:
        str: xyz string
    """
    natoms =len(z)
    xyz = f"{natoms}\n\n"
    for _z, _pos in zip(z, pos): #.numpy()):
        xyz += f"{_z}\t" + "\t".join([str(x) for x in _pos]) + "\n"
    return xyz

# %% [markdown]
# ### Building a LEFTNet model
#
# A simple test is performed to verify SE(3) symmetry. The model here is for testing, so we only need to build a very small model.
#
# Note: [LEFTNet](https://arxiv.org/abs/2304.04757) is a new SOTA-level SE(3) graph neural network. Although we use LEFTNet here, the properties it exhibits are model-independent (other SE(3) models, such as [EGNN](https://arxiv.org/pdf/2102.09844.pdf), will give the same results)
#
# TL: EGNN is not SE$(3)$  equivariant?

# %%
num_layers = 2
hidden_channels = 8
in_hidden_channels = 4
num_radial = 4

model =  LEFTNet(
    num_layers=num_layers,
    hidden_channels=hidden_channels,
    in_hidden_channels=in_hidden_channels,
    num_radial=num_radial,
    object_aware=False,
)

sum(p.numel() for p in model.parameters() if p.requires_grad)
# Out:
# /misc/home/guest50/micromamba/envs/oa_reactdiff_m/lib/python3.10/site-packages/torch_geometric/nn/conv/message_passing.py:972: UserWarning: 'EquiMessage.jittable' is deprecated and a no-op. Please remove its usage.
#   warnings.warn(f"'{self.__class__.__name__}.jittable' is deprecated "
# 7882

# %% [raw]
# xyz = assemble_xyz(z, pos)
# view = draw_in_3dmol(xyz, "xyz")
# view  # Display Molecules

# %% [markdown]
# ### Create an "Object-Aware" LEFTNet

# %% [raw]
# model_oa =  LEFTNet(
#     num_layers=num_layers,
#     hidden_channels=hidden_channels,
#     in_hidden_channels=in_hidden_channels,
#     num_radial=num_radial,
#     object_aware=True,  # Using the object-aware model
# )

# %%
# --- Importing necessary function ---
from torch.utils.data import DataLoader

from oa_reactdiff.trainer.pl_trainer import DDPMModule


from oa_reactdiff.dataset import ProcessedTS1x, ProcessedSCAN
from oa_reactdiff.diffusion._schedule import DiffSchedule, PredefinedNoiseSchedule

from oa_reactdiff.diffusion._normalizer import FEATURE_MAPPING
from oa_reactdiff.analyze.rmsd import batch_rmsd

from oa_reactdiff.utils.sampling_tools import assemble_sample_inputs, write_tmp_xyz

# %%
# !pwd
# Out:
# /home/guest50/OAReactDiff

# %% [markdown]
# ### Import the pre-trained model and redefine the schedule.

# %%
# TL fix: {
from oa_reactdiff.trainer.pl_trainer import DDPMModule
# } fix. Why didn' this carry over from the previous cell import statement?

device = torch.device("cpu") if not torch.cuda.is_available() else torch.device("cuda")
print(device) # TL
print(device.index)
print(device.type)


tspath = os.path.abspath(os.path.join(os.getcwd(), "oa_reactdiff","trainer"))
print(tspath)
# zenodo_pretrained_ckpt
ddpm_trainer = DDPMModule.load_from_checkpoint(
    checkpoint_path="./oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/leftnet-SCAN-6-w_selfoops-lr2.5e-4-rcmconly_passerini-03516f3022c5/ddpm-epoch=1899-val-totloss=736.23.ckpt",    
    #checkpoint_path="./oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/leftnet-SCAN-6-w_selfoops-lr2.5e-4-rcmconly_passerini-03516f3022c5/ddpm-epoch=1799-val-totloss=787.66.ckpt", --
    #
    #checkpoint_path="./pretrained-ts1x-diff.ckpt", # original
    #checkpoint_path=f"{tspath}/checkpoint/OAReactDiff/leftnet-0-f1ff7dc18fa3/ddpm-epoch=1999-val-totloss=509.31.ckpt", # Our recapitulation
    map_location=device,
)
ddpm_trainer = ddpm_trainer.to(device)
# Out:
# cuda
# None
# cuda
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer
# /misc/home/guest50/micromamba/envs/oa_reactdiff_m/lib/python3.10/site-packages/torch_geometric/nn/conv/message_passing.py:972: UserWarning: 'EquiMessage.jittable' is deprecated and a no-op. Please remove its usage.
#   warnings.warn(f"'{self.__class__.__name__}.jittable' is deprecated "

# %% [raw]
# loaded_from_scratch_ckpt = torch.load("./trained_models/pretrained-ts1x-diff-from-scratch.ckpt")
# loaded_from_scratch_ckpt

# %% [raw]
# loaded_zenodo_ckpt = torch.load("./trained_models/pretrained-ts1x-diff-zenodo.ckpt")
# loaded_zenodo_ckpt

# %%
noise_schedule: str = "polynomial_2"
timesteps: int = 150
precision: float = 1e-5

gamma_module = PredefinedNoiseSchedule(
            noise_schedule=noise_schedule,
            timesteps=timesteps,
            precision=precision,
        )
schedule = DiffSchedule(
    gamma_module=gamma_module,
    norm_values=ddpm_trainer.ddpm.norm_values
)
ddpm_trainer.ddpm.schedule = schedule
ddpm_trainer.ddpm.T = timesteps
ddpm_trainer = ddpm_trainer.to(device)

# %%
def prep_ddpm_trainer(ckpt_path: str, device=device):
    ddpm_trainer = DDPMModule.load_from_checkpoint(
        checkpoint_path=ckpt_path,
        map_location=device,
    )
    ddpm_trainer = ddpm_trainer.to(device)

    noise_schedule: str = "polynomial_2"
    timesteps: int = 150
    precision: float = 1e-5
    
    gamma_module = PredefinedNoiseSchedule(
                noise_schedule=noise_schedule,
                timesteps=timesteps,
                precision=precision,
            )
    schedule = DiffSchedule(
        gamma_module=gamma_module,
        norm_values=ddpm_trainer.ddpm.norm_values
    )
    ddpm_trainer.ddpm.schedule = schedule
    ddpm_trainer.ddpm.T = timesteps
    ddpm_trainer = ddpm_trainer.to(device)
    return ddpm_trainer

# %% [raw]
# ddpm_trainer = prep_ddpm_trainer(ckpt_path, device=device)

# %% [markdown]
# ### Prepare dataset and data loader and select a reaction involving multiple molecules

# %%
import pickle

# npz_path = "./oa_reactdiff/data/C6H6_5710-0-wSL-wBL-w3pBC/train.pkl" # w  self-loops after Angstrom correction
# 24/06/2026: update to check filtering results
npz_path = "./oa_reactdiff/data/C6H6_5710-filtered/train.pkl"

train_pkl = pickle.load(open(npz_path, "rb"))

# %%
npz_path_valid = "./oa_reactdiff/data/C6H6_5710-filtered/valid_addprop.pkl"
valid_pkl = pickle.load(open(npz_path_valid, "rb"))

# %%
npz_path_test = "/scr/trond/SCAN/C6H6_5710-filtered-test.pkl"
test_pkl = pickle.load(open(npz_path_test, "rb"))

# %%
pos = np.array(test_pkl['transition_state']['positions'][0])

# %%
z_num = test_pkl['transition_state']['charges'][0]

# %%
num2sym = {1: "H", 6: "C"}

# %%
test_xyz = assemble_xyz([num2sym[num] for num in z_num], pos)
print(test_xyz)
# Out:
# 12
#
# C	-0.516900648343	-0.174294636273	-1.067970800786
# C	-1.8274168923979999	0.281855646809	-0.665555170387
# C	0.7204072213550001	0.3062477260559999	-0.429570871693
# C	-1.5569540082030002	-0.259379067575	0.501820927983
# C	0.746055826415	0.301589139332	0.917287820757
# C	-0.49997865703499994	-0.314533123402	1.535236083393
# H	-2.717388734537	0.6617476993339999	-1.181950702773
# H	1.5862774498539998	0.587394946715	-1.041990254096
# H	-0.312462548756	-1.355347111461	1.8643291315180002
# H	1.5520855533639997	0.7188507795929999	1.5318461719469998
# H	-0.842730787701	0.22958547243399996	2.4369996781390006
# H	-0.42212630402	-0.9837174715619998	-1.81221449399

# %%
test_pkl['transition_state']['rxn'][0]
# Out:
# 'C6H6_5710-TS12 CON(2,6)'

# %%
train_pkl["use_ind"][:10]
# Out:
# [0, 1, 2, 3, 5, 6, 7, 8, 9, 10]

# %%
valid_pkl["use_ind"][:10]
# Out:
# [4, 16, 114, 116, 119, 127, 143, 154, 160, 190]

# %%
test_pkl["use_ind"][:10]
# Out:
# [34, 64, 98, 130, 146, 161, 189, 197, 200, 202]

# %% [raw]
# # 01/7/2025:
# # Something doesn't make sense
# # 957  cp /scr/trond/SCAN/SCAN_train_wo_selfloops-rcmconly_passerini_fix.pkl train_addprop.pkl
# # 958  cp train_addprop.pkl train.pkl
# # 959  cp /scr/trond/SCAN/SCAN-6_valid_wo_selfloops-rcmconly_passerini_fix.pkl valid_addprop.pkl
#
# train_pkl2 = pickle.load(open("/scr/trond/SCAN/SCAN_train_w_selfloops-rcmconly_passerini_fix.pkl", "rb"))
# valid_pkl2 = pickle.load(open("/scr/trond/SCAN/SCAN-6_valid_w_selfloops-rcmconly_passerini_fix.pkl", "rb"))

# %%
#assert sorted(list(set(train_pkl2["use_ind"] + valid_pkl2["use_ind"]))) == list(range(len(train_pkl2["transition_state"]["rxn"])))

# %% [raw]
# train_pkl2["use_ind"] == valid_pkl2["use_ind"]

# %%
train_pkl["reactant"]["rxn"][177]
# Out:
# 'C6H6_5710-TS446 CON(114,174)'

# %%
len(test_pkl["use_ind"])
# Out:
# 331

# %%
train_pkl["reactant"]['num_atoms'][177]
# Out:
# 12

# %% [raw]
# selected_rxns = {'WL1-TS784',
#                  'WL1-TS63029',
#                  'WL1-TS11193',
#                  'rcmconly_passerini-TS1206',
#                  'rcmconly_passerini-TS5435',
#                  'rcmconly_passerini-TS7394',
#                  'rcmconly_passerini-TS13605',
#                  'rcmconly_passerini-TS15965',
#                  'rcmconly_passerini-TS17328',
#                  'rcmconly_passerini-TS17605',
#                  'rcmconly_strecker-TS3978',
#                  'rcmconly_strecker-TS5528',
#                  'rcmconly_strecker-TS7950'}

# %%
selected_passerini_rcmconly_pts = [13605, 17605, 1206, 7394, 15965, 5435, 17328]
selected_strecker_rcmconly_pts = [3978, 5528, 7950]
selected_wl2_pts = [6029, 784, 11193]

# %%
from parse import parse
from pprint import pprint

# %%
set(selected_passerini_rcmconly_pts+selected_strecker_rcmconly_pts+selected_wl2_pts)
# Out:
# {784,
#  1206,
#  3978,
#  5435,
#  5528,
#  6029,
#  7394,
#  7950,
#  11193,
#  13605,
#  15965,
#  17328,
#  17605}

# %%
prefixes = {'ALD1',
 'EN1',
 'HDF1',
 'WL1',
 'f260_DFG1',
 'rcmconly_passerini',
 'rcmconly_strecker'}

select_prefixes = {'WL1', 'rcmconly_passerini', 'rcmconly_strecker'}
rxn_pattern = "{prefix}-TS{id_num}"

for i, rxn in enumerate(test_pkl["transition_state"]["rxn"]): # valid, not train
    parsed = parse(rxn_pattern, rxn)
    prefix = parsed["prefix"]
    id_num = parsed["id_num"]
    #prefixes.add(prefix)
    if prefix not in select_prefixes: 
        continue
    if int(id_num) in set(selected_passerini_rcmconly_pts+selected_strecker_rcmconly_pts+selected_wl2_pts):
        print(rxn)
        print(i)
        print(i in test_pkl["use_ind"]) # valid, not train
        print("")

# %%
select_rxns = []

selection = {'WL1': selected_wl2_pts, 'rcmconly_strecker': selected_strecker_rcmconly_pts, 'rcmconly_passerini': selected_passerini_rcmconly_pts}

for prefix, id_list in selection.items():
    for id_num in id_list:
        select_rxns.append(f"{prefix}-TS{id_num}")

print(select_rxns)
# Out:
# ['WL1-TS6029', 'WL1-TS784', 'WL1-TS11193', 'rcmconly_strecker-TS3978', 'rcmconly_strecker-TS5528', 'rcmconly_strecker-TS7950', 'rcmconly_passerini-TS13605', 'rcmconly_passerini-TS17605', 'rcmconly_passerini-TS1206', 'rcmconly_passerini-TS7394', 'rcmconly_passerini-TS15965', 'rcmconly_passerini-TS5435', 'rcmconly_passerini-TS17328']

# %%
# assert sorted(list(set(train_pkl["use_ind"] + valid_pkl["use_ind"]))) == list(range(len(train_pkl["transition_state"]["rxn"])))

# %%
len(train_pkl["transition_state"]["rxn"])
# Out:
# 6603

# %%
len(test_pkl["transition_state"]["rxn"])
# Out:
# 6603

# %%
train_pkl["use_ind"] == test_pkl["use_ind"]
# Out:
# False

# %%
selected_train_indices = []
selected_test_indices = []
selected_rxns_dict = {}
for i, rxn in enumerate(train_pkl["transition_state"]["rxn"]):
    if rxn in select_rxns:
        print(rxn)
        print(i)
        print(i in train_pkl["use_ind"])
        if i in train_pkl["use_ind"]:
            selected_train_indices.append(train_pkl["use_ind"].index(i))
        elif i in test_pkl["use_ind"]:
            selected_test_indices.append(test_pkl["use_ind"].index(i))
        selected_rxns_dict[i] = rxn
        print("")

# %%
selected_train_indices
# Out:
# []

# %%
selected_test_indices
# Out:
# []

# %%
# update, just selecting some random validation TSes for C6H6 for now
import random

random.seed(33)
#selected_valid_pre_indices = sorted(list(random.sample(valid_pkl["use_ind"], 10)))
#selected_valid_pre_indices = sorted(list(random.sample(valid_pkl["use_ind"], 100)))
selected_test_pre_indices = sorted(list(random.sample(test_pkl["use_ind"], 100)))

selected_test_indices = []
for i in selected_test_pre_indices:
    selected_test_indices.append(test_pkl["use_ind"].index(i))
print(selected_test_indices)
# Out:
# [1, 3, 4, 16, 26, 28, 29, 32, 33, 35, 36, 41, 47, 56, 60, 61, 62, 63, 76, 80, 85, 92, 94, 95, 97, 98, 103, 109, 113, 119, 124, 125, 126, 138, 139, 141, 143, 144, 145, 154, 155, 157, 158, 162, 163, 164, 170, 178, 179, 181, 183, 185, 186, 187, 194, 198, 199, 201, 209, 211, 215, 218, 220, 223, 227, 232, 234, 239, 242, 245, 246, 248, 254, 255, 257, 259, 261, 262, 265, 268, 270, 272, 273, 279, 283, 284, 289, 292, 295, 300, 301, 304, 305, 315, 316, 317, 319, 323, 326, 328]

# %% [raw]
# dataset = ProcessedSCAN(
#     npz_path=npz_path,
#     center=True,
#     pad_fragments=0,
#     device=device,
#     zero_charge=False,
#     remove_h=False,
#     single_frag_only=False,
#     swapping_react_prod=False,
#     use_by_ind=True,
# )
# loader = DataLoader(
#     dataset,
#     batch_size=1,
#     shuffle=False,
#     num_workers=0,
#     collate_fn=dataset.collate_fn
# )
# itl = iter(loader)
# idx = -1 # TL: why?
#
# len(dataset)

# %% [raw]
# # train dataset size, SCAN-9w:
# 97866

# %%
# valid dataset to test against:
dataset = ProcessedSCAN(
    npz_path=npz_path_test, #valid,
    center=True,
    pad_fragments=0,
    device=device,
    zero_charge=False,
    remove_h=False,
    single_frag_only=False,
    swapping_react_prod=False,
    use_by_ind=True,
    keep_use_by_ind_ordered=True, # Used for analysis but not training? 18/07/2025
)
loader = DataLoader(
    dataset, 
    batch_size=1,
    shuffle=False,
    num_workers=0,
    collate_fn=dataset.collate_fn
)
itl = iter(loader)
idx = -1 # TL: why?

len(dataset)
# Out:
# 331

# %%
len(test_pkl["use_ind"])
# Out:
# 331

# %%
dataset.raw_dataset["use_ind"] == test_pkl["use_ind"]
# Out:
# True

# %% [raw]
# num_indices_to_select = 20
# SEED = 747
# np.random.default_rng(seed=SEED)
# np.random.seed(SEED)
# random_indices = np.random.choice(len(dataset), size=num_indices_to_select, replace=False)
# random_indices = sorted(random_indices)
# random_indices

# %% [raw]
# for _ in range(4):  # The 4th sample happens to be a multimolecular reaction
#     representations, res = next(itl)
# idx += 1
# n_samples = representations[0]["size"].size(0)
# if n_samples != 1: #
#     print(n_samples)#
# fragments_nodes = [
#     repre["size"] for repre in representations
# ]
# conditions = torch.tensor([[0] for _ in range(n_samples)], device=device)

# %%
# TL visualize each state:
atomic_num2sym = {
    1: 'H',    2: 'He',   3: 'Li',   4: 'Be',   5: 'B',    6: 'C',    7: 'N',    8: 'O',    9: 'F',    10: 'Ne',
    11: 'Na',  12: 'Mg',  13: 'Al',  14: 'Si',  15: 'P',   16: 'S',   17: 'Cl',  18: 'Ar',  19: 'K',   20: 'Ca',
    21: 'Sc',  22: 'Ti',  23: 'V',   24: 'Cr',  25: 'Mn',  26: 'Fe',  27: 'Co',  28: 'Ni',  29: 'Cu',  30: 'Zn',
    31: 'Ga',  32: 'Ge',  33: 'As',  34: 'Se',  35: 'Br',  36: 'Kr',  37: 'Rb',  38: 'Sr',  39: 'Y',   40: 'Zr',
    41: 'Nb',  42: 'Mo',  43: 'Tc',  44: 'Ru',  45: 'Rh',  46: 'Pd',  47: 'Ag',  48: 'Cd',  49: 'In',  50: 'Sn',
    51: 'Sb',  52: 'Te',  53: 'I',   54: 'Xe',  55: 'Cs',  56: 'Ba',  57: 'La',  58: 'Ce',  59: 'Pr',  60: 'Nd',
    61: 'Pm',  62: 'Sm',  63: 'Eu',  64: 'Gd', 65: 'Tb',  66: 'Dy',  67: 'Ho',  68: 'Er',  69: 'Tm',  70: 'Yb',
    71: 'Lu',  72: 'Hf',  73: 'Ta',  74: 'W',   75: 'Re',  76: 'Os',  77: 'Ir',  78: 'Pt',  79: 'Au',  80: 'Hg',
    81: 'Tl',  82: 'Pb',  83: 'Bi',  84: 'Po',  85: 'At',  86: 'Rn',  87: 'Fr',  88: 'Ra',  89: 'Ac',  90: 'Th',
    91: 'Pa',  92: 'U',   93: 'Np',  94: 'Pu',  95: 'Am',  96: 'Cm',  97: 'Bk',  98: 'Cf',  99: 'Es', 100: 'Fm',
    101: 'Md', 102: 'No', 103: 'Lr', 104: 'Rf', 105: 'Db', 106: 'Sg', 107: 'Bh', 108: 'Hs', 109: 'Mt', 110: 'Ds',
    111: 'Rg', 112: 'Cn', 113: 'Nh', 114: 'Fl', 115: 'Mc', 116: 'Lv', 117: 'Ts', 118: 'Og'
}

# %%
def xyz_block_from_node_features(xh: torch.tensor, comment: str="", c2a: dict=atomic_num2sym) -> str:
    num_atoms = xh.shape[0]
    xyz_lines = [str(num_atoms), comment]
    for row in xh:
        position = row[:3].cpu().numpy()
        z = c2a[row[-1].long().item()]
        xyz_lines.append(f"{z}\t" + "\t".join([str(x) for x in position]))
    return "\n".join(xyz_lines)

# %%
output_dir_basename = "sample_random_TS-20260703-C6H6-filtered_new-w_wo-w_wo-w_wo-vs_www_test" # UPDATE
output_dir = os.path.abspath(os.path.join("results/", output_dir_basename))
os.makedirs(output_dir, exist_ok=True)

# %% [raw]
# ddpm_trainer = prep_ddpm_trainer(ckpt_path, device=device)

# %%
# !ls -haltr oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/ | grep C6H6 | grep bz64
# Out:
# drwxr-xr-x   2 guest50 users 4.0K Aug 22  2025 C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5
# drwxr-xr-x   2 guest50 users 4.0K Aug 22  2025 C6H6_5710-0-wSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet0c6a5355a394
# drwxr-xr-x   2 guest50 users 4.0K Aug 22  2025 C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93
# drwxr-xr-x   2 guest50 users 4.0K Aug 23  2025 C6H6_5710-0-wSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnetd095e07080e3
# drwxr-xr-x   2 guest50 users 4.0K Aug 23  2025 C6H6_5710-0-woSL-wBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet22b35e509597
# drwxr-xr-x   2 guest50 users 4.0K Aug 23  2025 C6H6_5710-0-wSL-wBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnetad3824c569fd
# drwxr-xr-x   2 guest50 users 4.0K Aug 23  2025 C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9
# drwxr-xr-x   2 guest50 users 4.0K Aug 23  2025 C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211

# %% [raw]
# C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5
# C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93
# C6H6_5710-0-woSL-wBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet22b35e509597
# C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211
# C6H6_5710-0-wSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet0c6a5355a394
# C6H6_5710-0-wSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnetd095e07080e3
# C6H6_5710-0-wSL-wBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnetad3824c569fd
# C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9

# %%
# !ls -haltr oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5
# Out:
# total 1.6G
# -rw-r--r--   1 guest50 users  29K Aug 16  2025 leftnet.py
# -rw-r--r--   1 guest50 users 163M Aug 19  2025 ddpm-epoch=1053-val-totloss=474.38.ckpt
# -rw-r--r--   1 guest50 users 163M Aug 19  2025 ddpm-epoch=1078-val-totloss=479.92.ckpt
# -rw-r--r--   1 guest50 users 163M Aug 19  2025 ddpm-epoch=1411-val-totloss=474.10.ckpt
# -rw-r--r--   1 guest50 users 163M Aug 20  2025 ddpm-epoch=1824-val-totloss=483.62.ckpt
# -rw-r--r--   1 guest50 users 163M Aug 20  2025 ddpm-epoch=1932-val-totloss=485.03.ckpt
# -rw-r--r--   1 guest50 users 163M Aug 21  2025 ddpm-epoch=2184-val-totloss=483.80.ckpt
# -rw-r--r--   1 guest50 users 163M Aug 21  2025 ddpm-epoch=2368-val-totloss=481.17.ckpt
# -rw-r--r--   1 guest50 users 163M Aug 21  2025 ddpm-epoch=2370-val-totloss=480.35.ckpt
# -rw-r--r--   1 guest50 users 163M Aug 22  2025 ddpm-epoch=2501-val-totloss=483.48.ckpt
# -rw-r--r--   1 guest50 users 163M Aug 22  2025 ddpm-epoch=2512-val-totloss=482.90.ckpt
# drwxr-xr-x   2 guest50 users 4.0K Aug 22  2025 .
# drwxr-xr-x 173 guest50 users  16K Jun 24 15:22 ..

# %%
#checkpoints_to_try = ["./oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/leftnet-SCAN-6-w_selfoops-lr2.5e-4-rcmconly_passerini-03516f3022c5/ddpm-epoch=1899-val-totloss=736.23.ckpt"]

# %%
from collections import defaultdict
per_checkpoint_ts_rmsds = defaultdict(list)

# %%
from parse import parse

# %%
import os

basedir = os.path.abspath("oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN")
# UPDATE :
run_names = [ #"C6H6_5710-0-woSL-wBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet22b35e509597", 
             #"C6H6_5710-0-wSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet0c6a5355a394", 
             #"C6H6_5710-0-wSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnetd095e07080e3", 
             #"C6H6_5710-0-wSL-wBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnetad3824c569fd", 
             #"C6H6_5710-0-wSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet53efbe37f1d9",
             #"C6H6_5710-0-woSL-wBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet572fb8db0211",
             #"C6H6_5710-0-woSL-woBL-w3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet369b4311ee93",
             #"C6H6_5710-0-woSL-woBL-wo3pBC-StepLR-cutoff_12-bz64-rep0-SCAN-leftnet147859ed46b5",
             "C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0",
            ]

selected_checkpoint_paths = {}
self_loops=True
lr = "5e-4"
for run_name in run_names:
    print(run_name)
    runpath = os.path.join(basedir, run_name)
    #parsed = parse("9{self_loops}-{lr}e-4-{etc}", run_name)
    #self_loops = parsed["self_loops"]+"_self_loops"
    name_parts = run_name.split("-")
    lrs = None
    if "StepLR" in name_parts:
        lrs = "StepLR"
    elif "CosAnnl" in name_parts:
        lrs = "CosineAnnealing"
    #lr = parsed["lr"]+"e-4"
 
    # Let's select only the latest saved checkpoint and those among the top-k older checkpoints that have better val-totloss.
    checkpoints = []
    for file in os.listdir(runpath):
         if file.endswith(".ckpt"):
             ckpt_path = os.path.join(runpath, file)
             mod_time = os.path.getmtime(ckpt_path)
             checkpoints.append(tuple([file, mod_time]))
    checkpoints.sort(key=lambda x: x[1], reverse=True) # Most recent first.
    
    selected_checkpoints = []
    seen_val_totloss = set()
    for ckpt, _ in checkpoints:
        parsed2 = parse("ddpm-epoch={epoch}-val-totloss={val-totloss}.ckpt", ckpt)
        val_totloss = float(parsed2["val-totloss"])
        epoch = int(parsed2["epoch"])
        if all(val_totloss < value for value in seen_val_totloss):
            seen_val_totloss.add(val_totloss)
            selected_checkpoints.append(ckpt)
            ckpt_path = os.path.join(runpath, ckpt)
            selected_checkpoint_paths[ckpt_path] = {"self_loops":self_loops, "lr":lr, "lr_scheduler":lrs, "epoch":epoch, "val-totloss":val_totloss} # , "rmsds":{}
    print(list(reversed(selected_checkpoints)))
    print(len(selected_checkpoints))
    print("")
# Out:
# C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0
# ['ddpm-epoch=2932-val-totloss=457.68.ckpt', 'ddpm-epoch=2947-val-totloss=465.87.ckpt']
# 2

# %%
all([x==1 for x in dataset.raw_dataset["single_fragment"]])
# Out:
# True

# %% [raw]
# # No longer required with sort in SCAN.py working correctly.
#
# # Valid indexing different from train?
#
# for i in range(len(dataset)):
#     representations, res = next(itl)
#     if i % 500 == 0:
#         print(i)
#     #valid_idx = single_frag_inds[i] #valid_pkl["use_ind"][i] ## THIS IS WHERE THE UNSORTED SET IN SCAN.py CAUSED ISSUES.
#     valid_idx = valid_pkl["use_ind"][i]
#     #print(valid_idx)
#     rxn_id = valid_pkl["reactant"]["rxn"][valid_idx]
#     #print(rxn_id)
#     n_samples = representations[0]["size"].size(0)
#     fragments_nodes = [
#         repre["size"] for repre in representations
#     ]
#     conditions = torch.tensor([[0] for _ in range(n_samples)], device=device)
#     # skipping permutation of indices in reactant state
#     xh_fixed = [
#         torch.cat(
#             [repre[feature_type] for feature_type in FEATURE_MAPPING],
#             dim=1,
#         )
#         for repre in representations
#     ]
#     #print(xh_fixed[2].shape[0])
#     #print(valid_pkl["reactant"]['num_atoms'][valid_idx])
#     #print("")
#     #continue
#     assert xh_fixed[2].shape[0] == valid_pkl["reactant"]['num_atoms'][valid_idx]

# %%
corr_plot_data = {"val-totloss":[], "rmsd":[], "rxn_id":[], "epoch":[], "checkpoint":[], "num_atoms":[]}
per_rxn_rmsds = defaultdict(list)

# %%
selected_representation_triples = {}
rs_rmsdsx = []
ts_rmsdsx = []
ps_rmsdsx = []

selected_indices = selected_test_indices # valid, not train

for i in range(len(dataset)): 
    representations, res = next(itl)
    if i in selected_indices: #random_indices:
        xyz_blocks = []
        print(i)
        test_idx = test_pkl["use_ind"][i]
        print(test_idx)
        rxn_id = test_pkl["reactant"]["rxn"][test_idx]
        print(rxn_id)
        n_samples = representations[0]["size"].size(0)
        fragments_nodes = [
            repre["size"] for repre in representations
        ]
        conditions = torch.tensor([[0] for _ in range(n_samples)], device=device)
        # skipping permutation of indices in reactant state
        xh_fixed = [
            torch.cat(
                [repre[feature_type] for feature_type in FEATURE_MAPPING],
                dim=1,
            )
            for repre in representations
        ]
        print(xh_fixed[2].shape[0])
        print(test_pkl["reactant"]['num_atoms'][test_idx])
        assert xh_fixed[2].shape[0] == test_pkl["reactant"]['num_atoms'][test_idx]
        #ground_truth_ts = xh_fixed[1]

        if output_dir is not None:            
            # Now wrap up XYZs into an output file with informative comments.
            file_name = f"{rxn_id}.xyz"
            # Reactant state, two versions
            rs_ref_xyz = xyz_block_from_node_features(xh_fixed[0], comment=f"True/calculated reference reactant state.")
            xyz_blocks.append(rs_ref_xyz)
            #rs_rec_xyz = xyz_block_from_node_features(out_samples[0][0], comment=f"Reconstructed reactant state. RMSD: {str(round(rs_rmsds[0],6))} Å.")
            #xyz_blocks.append(rs_rec_xyz)
            
            # Transition state, two versions
            ts_ref_xyz = xyz_block_from_node_features(xh_fixed[1], comment=f"True/calculated reference transition state.")
            xyz_blocks.append(ts_ref_xyz)
            #ts_gen_xyz = xyz_block_from_node_features(out_samples[0][1], comment=f"Generated/inpainted transition state. RMSD: {str(round(ts_rmsds[0],6))} Å.")
            #xyz_blocks.append(ts_gen_xyz)
    
            # Product state, two versions
            ps_ref_xyz = xyz_block_from_node_features(xh_fixed[2], comment=f"True/calculated reference product state.")
            xyz_blocks.append(ps_ref_xyz)
            #ps_rec_xyz = xyz_block_from_node_feattotures(out_samples[0][2], comment=f"Reconstructed product state. RMSD: {str(round(ps_rmsds[0],6))} Å.")
            #xyz_blocks.append(ps_rec_xyz)

        for checkpoint_path, ckpt_vals in selected_checkpoint_paths.items():
            checkpoint_name = f"{os.path.dirname(checkpoint_path)}/{os.path.basename(checkpoint_path)}" 
            ddpm_trainer = prep_ddpm_trainer(checkpoint_path, device=device)
            out_samples, out_masks = ddpm_trainer.ddpm.inpaint(
                n_samples=n_samples,
                fragments_nodes=fragments_nodes,
                conditions=conditions,
                return_frames=1,
                resamplings=5,
                jump_length=5,
                timesteps=None,
                xh_fixed=xh_fixed,
                frag_fixed=[0, 2],
            )
            
            # # reactant state (ts_..):
            # rs_rmsds = batch_rmsd(
            #     fragments_nodes, 
            #     out_samples[0],
            #     xh_fixed,
            #     idx=0,
            # )
            # print(rs_rmsds)
            # rs_rmsdsx.append(rs_rmsds[0])
    
            # transition state (ts_..):
            ts_rmsds = batch_rmsd(
                fragments_nodes, 
                out_samples[0],
                xh_fixed,
                idx=1,
            )
            print(f"{checkpoint_name}: {ts_rmsds[0]}")
            per_checkpoint_ts_rmsds[checkpoint_name].append(ts_rmsds[0])
            corr_plot_data["val-totloss"].append(ckpt_vals["val-totloss"])
            corr_plot_data["rmsd"].append(ts_rmsds[0])
            corr_plot_data["rxn_id"].append(rxn_id)
            corr_plot_data["checkpoint"].append(checkpoint_name)
            corr_plot_data["num_atoms"].append(test_pkl["reactant"]['num_atoms'][test_idx])
            corr_plot_data["epoch"].append(ckpt_vals["epoch"])

            if output_dir is not None:
                ts_gen_xyz = xyz_block_from_node_features(out_samples[0][1], comment=f"Generated/inpainted transition state. RMSD: {str(round(ts_rmsds[0],6))} Å. By model {checkpoint_name}.")
                xyz_blocks.append(ts_gen_xyz)
        
            # # product state (ps_..):
            # ps_rmsds = batch_rmsd(
            #     fragments_nodes, 
            #     out_samples[0],
            #     xh_fixed,
            #     idx=2,
            # )
            # print(ps_rmsds)
            # ps_rmsdsx.append(ps_rmsds[0])
            #assert len(rmsds) == 1
        print("")

        if output_dir is not None:
            with open(os.path.join(output_dir, file_name), "w") as f_out:
                f_out.write("\n".join(xyz_blocks))
            
        if i == selected_indices[-1]: # no need to keep iterating.
            break
# Out:
# 1
# 64
# C6H6_5710-TS142 CON(17,23)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.2946347171171559
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.3359064333592121
#
# 3
# 130
# C6H6_5710-TS311 CON(130,131)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.48275669955675693
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.5991427856897483
#
# 4
# 146
# C6H6_5710-TS340 CON(44,3)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.41524494840464327
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.3847506263880585
#
# 16
# 391
# C6H6_5710-TS1133 CON(214,379)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.4928072537000019
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.4719095753607469
#
# 26
# 646
# C6H6_5710-TS1933 CON(65,547)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.07283216146885031
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.033214183827160945
#
# 28
# 663
# C6H6_5710-TS1966 CON(538,119)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.3865017101521086
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.36880589492012034
#
# 29
# 698
# C6H6_5710-TS2088 CON(492,138)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.46648742154958495
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.42989604104451656
#
# 32
# 769
# C6H6_5710-TS2290 CON(605,157)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.5895804069928826
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.33294824966322867
#
# 33
# 775
# C6H6_5710-TS2312 CON(190,139)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.4793394906711551
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.428981849285102
#
# 35
# 854
# C6H6_5710-TS2564 CON(614,378)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.5537910404572072
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.25615046507829825
#
# 36
# 860
# C6H6_5710-TS2578 CON(120,527)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.4489655551907176
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.35896461929808643
#
# 41
# 995
# C6H6_5710-TS2944 CON(133,227)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.3117071802551613
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.531614195667419
#
# 47
# 1082
# C6H6_5710-TS3164 CON(253,717)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.4289292375028047
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.4127980674336245
#
# 56
# 1363
# C6H6_5710-TS3979 CON(185,806)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.4449721017086331
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.4478079364754852
#
# 60
# 1484
# C6H6_5710-TS4302 CON(833,36)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.04312825943064626
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.46699953974000025
#
# 61
# 1495
# C6H6_5710-TS5356 CON(553,548)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.34580026360417165
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.24841028965175707
#
# 62
# 1500
# C6H6_5710-TS4346 CON(376,201)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.8107972135659849
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.4328996438133598
#
# 63
# 1528
# C6H6_5710-TS4418 CON(773,299)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.2848335904165233
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.16291263033658107
#
# 76
# 1722
# C6H6_5710-TS4988 CON(903,847)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.21307229840800884
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.3819479829010886
#
# 80
# 1794
# C6H6_5710-TS5211 CON(926,908)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.09490908091163201
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.3677857396089054
#
# 85
# 1899
# C6H6_5710-TS5550 CON(902,178)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.47677030876409876
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.470276604857509
#
# 92
# 2027
# C6H6_5710-TS5946 CON(898,577)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.5453241812391637
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.7537685749769097
#
# 94
# 2041
# C6H6_5710-TS5984 CON(137,262)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.28037542154755807
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.5693726054115327
#
# 95
# 2047
# C6H6_5710-TS6004 CON(32,979)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.3942953672489593
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.22639733376098997
#
# 97
# 2056
# C6H6_5710-TS6040 CON(219,777)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.39743595618416283
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.44193210582798775
#
# 98
# 2061
# C6H6_5710-TS6049 CON(541,48)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.44352921960363073
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.4370332693959204
#
# 103
# 2255
# C6H6_5710-TS6524 CON(102,433)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.362158497538879
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.019840260745197576
#
# 109
# 2433
# C6H6_5710-TS7004 CON(1032,1054)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.3987307618771438
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.31195438026947425
#
# 113
# 2556
# C6H6_5710-TS8100 CON(617,545)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.21874825324521222
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.9772608482538442
#
# 119
# 2625
# C6H6_5710-TS7603 CON(132,22)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.47170193993265325
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.327587752381295
#
# 124
# 2729
# C6H6_5710-TS12907 CON(198,114)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.22492799278415215
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.2899974402432414
#
# 125
# 2731
# C6H6_5710-TS7912 CON(1083,268)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.29590342853974727
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.24253983502124277
#
# 126
# 2734
# C6H6_5710-TS7916 CON(650,20)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 1.0
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.5916730186052421
#
# 138
# 2961
# C6H6_5710-TS8562 CON(142,557)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.3515803987841152
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.21520193671321533
#
# 139
# 2976
# C6H6_5710-TS16290 CON(676,761)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.08080469149825156
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.35691938343977225
#
# 141
# 3005
# C6H6_5710-TS16410 CON(140,571)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.21059261667038004
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.454614957920089
#
# 143
# 3073
# C6H6_5710-TS8875 CON(398,975)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.38969874000601473
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.31149686591339254
#
# 144
# 3092
# C6H6_5710-TS8926 CON(314,952)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.28367702242834225
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.274201627436085
#
# 145
# 3099
# C6H6_5710-TS8947 CON(939,846)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.4103114550859967
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.2866429606143644
#
# 154
# 3202
# C6H6_5710-TS9205 CON(121,607)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.3678169738730322
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.31811440425618387
#
# 155
# 3219
# C6H6_5710-TS9247 CON(1184,381)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.3912722838652085
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.45825659420054937
#
# 157
# 3255
# C6H6_5710-TS9319 CON(1013,775)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.10658380526012484
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.5700936070500783
#
# 158
# 3272
# C6H6_5710-TS9359 CON(903,1194)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.2878108066498467
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.04190421237218306
#
# 162
# 3342
# C6H6_5710-TS18413 CON(948,727)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.35849210572739065
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.3828797976698939
#
# 163
# 3369
# C6H6_5710-TS9591 CON(159,162)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.6879378481397425
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.35978738600365134
#
# 164
# 3385
# C6H6_5710-TS9629 CON(1212,333)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.26506821255302404
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.4653714654369721
#
# 170
# 3474
# C6H6_5710-TS9844 CON(486,572)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.4356459631665292
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.44169586239761455
#
# 178
# 3645
# C6H6_5710-TS10302 CON(110,1241)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.30192827233814334
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.376967902930783
#
# 179
# 3696
# C6H6_5710-TS10433 CON(67,22)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.4367349652583016
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.05290187361401997
#
# 181
# 3743
# C6H6_5710-TS10557 CON(499,856)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.30467147526140836
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.7482435340464364
#
# 183
# 3763
# C6H6_5710-TS15764 CON(1245,365)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.3702503739556956
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.2635783751793554
#
# 185
# 3798
# C6H6_5710-TS10708 CON(164,177)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.12450255359148295
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.40089349525024504
#
# 186
# 3840
# C6H6_5710-TS10805 CON(1181,446)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.4419807888644597
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.36117756454901173
#
# 187
# 3843
# C6H6_5710-TS10809 CON(253,110)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.3364198854702262
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.36782124639792446
#
# 194
# 4014
# C6H6_5710-TS11276 CON(63,547)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.6757840692832083
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.7176511160524092
#
# 198
# 4097
# C6H6_5710-TS11511 CON(220,343)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.15840142964013793
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.3111564022184829
#
# 199
# 4117
# C6H6_5710-TS11574 CON(178,370)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.46816652935147307
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.4218224050911057
#
# 201
# 4199
# C6H6_5710-TS11807 CON(289,1155)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.2553471803744817
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.5764997713730521
#
# 209
# 4474
# C6H6_5710-TS12566 CON(974,71)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.657658975930473
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.1525679917113538
#
# 211
# 4493
# C6H6_5710-TS12614 CON(1056,430)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.3569800623643609
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.2602907014069949
#
# 215
# 4548
# C6H6_5710-TS12787 CON(243,139)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.3561402944860228
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.17158848089603781
#
# 218
# 4598
# C6H6_5710-TS12931 CON(606,1347)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.08968692818083634
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.3292068157016014
#
# 220
# 4658
# C6H6_5710-TS13097 CON(389,157)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.46807658762449805
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.5527134375525677
#
# 223
# 4723
# C6H6_5710-TS13273 CON(249,808)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.4472694869419069
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.4222166626531002
#
# 227
# 4779
# C6H6_5710-TS13411 CON(62,427)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.31362550058572725
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.4779499607692386
#
# 232
# 4887
# C6H6_5710-TS13743 CON(503,630)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.18902545274391905
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.10032216303985095
#
# 234
# 4911
# C6H6_5710-TS13811 CON(1002,1050)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.6259658843707859
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.18079642608722196
#
# 239
# 5056
# C6H6_5710-TS14184 CON(142,902)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.495554893213078
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.4672409033733169
#
# 242
# 5134
# C6H6_5710-TS14400 CON(1394,535)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.3243591571769126
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.3047469201151297
#
# 245
# 5191
# C6H6_5710-TS14547 CON(98,3)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.45320492220055797
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.38480005091373265
#
# 246
# 5225
# C6H6_5710-TS14666 CON(1125,386)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.39055106428061803
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.3980505614875617
#
# 248
# 5232
# C6H6_5710-TS14690 CON(1274,1125)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.6794774558751193
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.15038147132848784
#
# 254
# 5311
# C6H6_5710-TS14954 CON(1307,1211)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.254703302689199
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.2651565264736908
#
# 255
# 5334
# C6H6_5710-TS15016 CON(95,1419)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.5389939768156781
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.6144292001487092
#
# 257
# 5390
# C6H6_5710-TS15178 CON(168,1024)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.29679344738954966
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.37162876745441453
#
# 259
# 5423
# C6H6_5710-TS15285 CON(601,1426)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.04652686687577732
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.38345493850569456
#
# 261
# 5463
# C6H6_5710-TS15397 CON(1198,822)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.36801032749898777
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.30165959652564506
#
# 262
# 5486
# C6H6_5710-TS15459 CON(286,415)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.40460353556797407
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.4222057408608235
#
# 265
# 5530
# C6H6_5710-TS15573 CON(998,1441)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 1.0
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.14070870304957342
#
# 268
# 5539
# C6H6_5710-TS15587 CON(277,921)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.3905988211884946
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.31255693730900824
#
# 270
# 5578
# C6H6_5710-TS15699 CON(615,939)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.6672510022495761
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.3808930108021648
#
# 272
# 5592
# C6H6_5710-TS15759 CON(255,99)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.46449749292331743
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.289367578693555
#
# 273
# 5611
# C6H6_5710-TS15826 CON(384,332)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.41847584174519503
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.4074370023411832
#
# 279
# 5727
# C6H6_5710-TS16198 CON(565,400)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.35732577073552585
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.3582803642530965
#
# 283
# 5757
# C6H6_5710-TS16282 CON(106,12)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.1961690558304109
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.6988381385832375
#
# 284
# 5759
# C6H6_5710-TS16287 CON(103,39)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.35703200834492027
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.3740810217457471
#
# 289
# 5864
# C6H6_5710-TS18222 CON(74,853)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.5774756869375132
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.4889016475896035
#
# 292
# 5915
# C6H6_5710-TS16713 CON(372,741)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.43315889886449754
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.41348017001162884
#
# 295
# 5980
# C6H6_5710-TS16905 CON(1015,289)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.6323914585085247
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.3943002465495326
#
# 300
# 6065
# C6H6_5710-TS17166 CON(322,176)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.47089013418386083
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.2409264312429373
#
# 301
# 6164
# C6H6_5710-TS17434 CON(185,1180)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.3222174114475026
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.3800427912627448
#
# 304
# 6231
# C6H6_5710-TS17607 CON(336,856)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.7556583914606924
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.859213425154083
#
# 305
# 6235
# C6H6_5710-TS17622 CON(669,1422)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.6111335508802733
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.7450686619968901
#
# 315
# 6360
# C6H6_5710-TS17973 CON(27,447)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.3156083169500828
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.48207687285277556
#
# 316
# 6363
# C6H6_5710-TS17985 CON(379,727)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.7271699688262562
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.49928290633673383
#
# 317
# 6374
# C6H6_5710-TS18020 CON(365,1509)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.4520078563970953
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.4237800682265151
#
# 319
# 6413
# C6H6_5710-TS18187 CON(558,316)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.3545433190602715
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.4582472348406076
#
# 323
# 6434
# C6H6_5710-TS18250 CON(1371,497)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.19137802623383232
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.34006571422421544
#
# 326
# 6508
# C6H6_5710-TS18452 CON(819,794)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.28997273722880884
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.3413605125424579
#
# 328
# 6531
# C6H6_5710-TS18506 CON(1516,1193)
# 12
# 12
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt: 0.36124484645437555
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt: 0.3618735453966976

# %%
selected_rxns_dict
# Out:
# {}

# %%
1-3/13
# Out:
# 0.7692307692307692

# %%
#select_rxns
pprint(dict(sorted(selected_rxns_dict.items())))
# Out:
# {}

# %%
# Report/analysis of RMSDs seen:

#rs_mean = round(np.mean(rs_rmsdsx), 6)
#rs_std = round(np.std(rs_rmsdsx), 6)
#print(f"Reactant state reconstruction RMSD was mean ± std.dev.: \t{rs_mean} \t± {rs_std} Å.")
ts_mean = round(np.mean(ts_rmsds), 6)
ts_std = round(np.std(ts_rmsds), 6)
print(f"Transition state inpainting RMSD was mean ± std.dev.: \t\t{ts_mean} \t± {ts_std} Å.")
#ps_mean = round(np.mean(ps_rmsdsx), 6)
#ps_std = round(np.std(ps_rmsdsx), 6)
#print(f"Product state reconstruction RMSD was mean ± std.dev.: \t\t{ps_mean} \t± {ps_std} Å.")
# Out:
# Transition state inpainting RMSD was mean ± std.dev.: 		0.361874 	± 0.0 Å.

# %% [markdown]
# Tried checkpoints, fraction of RMSD==1.0, and mean RMSD:
#
# `checkpoint_path="./oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/leftnet-SCAN-6-w_selfoops-lr2.5e-4-rcmconly_passerini-03516f3022c5/...`
#
# `ddpm-epoch=999-val-totloss=770.24.ckpt`: ...
#
# `ddpm-epoch=1799-val-totloss=787.66.ckpt`: 12/20, 0.819974 	± 0.273995 Å.

# %%
for checkpoint_name, ts_rmsds in per_checkpoint_ts_rmsds.items():
    print(checkpoint_name)
    ts_mean = round(np.mean(ts_rmsds), 6)
    ts_std = round(np.std(ts_rmsds), 6)
    failures = len([x for x in ts_rmsds if x == 1.0])
    print(f"    Transition state inpainting RMSD was mean ± std.dev.: \t\t{ts_mean} \t± {ts_std} Å.")
    print(f"    Number of 1.0 RMSD indicating complete failure: {failures} out of {len(ts_rmsds)}.")
    print("")
# Out:
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2947-val-totloss=465.87.ckpt
#     Transition state inpainting RMSD was mean ± std.dev.: 		0.397759 	± 0.17992 Å.
#     Number of 1.0 RMSD indicating complete failure: 2 out of 100.
#
# /misc/home/guest50/OAReactDiff/oa_reactdiff/trainer/checkpoint/OAReactDiff-SCAN/C6H6_5710-filtered-LBS_32x8-StepLR-cutoff_21-rep0-SCAN-leftnet8ff8f5a1c6d0/ddpm-epoch=2932-val-totloss=457.68.ckpt
#     Transition state inpainting RMSD was mean ± std.dev.: 		0.387516 	± 0.165645 Å.
#     Number of 1.0 RMSD indicating complete failure: 0 out of 100.

# %%
output_dir
# Out:
# '/misc/home/guest50/OAReactDiff/results/sample_random_TS-20260703-C6H6-filtered_new-w_wo-w_wo-w_wo-vs_www_test'

# %%
import pandas as pd

# %%
for key, val in corr_plot_data.items():
    print(f"{key}: {len(val)}")
# Out:
# val-totloss: 200
# rmsd: 200
# rxn_id: 200
# epoch: 200
# checkpoint: 200
# num_atoms: 200

# %%
if len(corr_plot_data["epoch"]) == 0:
    fix_epochs = []
    for checkpoint_name in corr_plot_data["checkpoint"]:
        parts = checkpoint_name.split("-")
        for part in parts:
            if part[:6] == "epoch=":
                epoch = int(part[6:])
                fix_epochs.append(epoch)
    corr_plot_data["epoch"] = fix_epochs

# %%
df = pd.DataFrame(data=corr_plot_data)
df
# Out:
#      val-totloss      rmsd                            rxn_id  epoch  \
# 0         465.87  0.294635        C6H6_5710-TS142 CON(17,23)   2947
# 1         457.68  0.335906        C6H6_5710-TS142 CON(17,23)   2932
# 2         465.87  0.482757      C6H6_5710-TS311 CON(130,131)   2947
# 3         457.68  0.599143      C6H6_5710-TS311 CON(130,131)   2932
# 4         465.87  0.415245         C6H6_5710-TS340 CON(44,3)   2947
# ..           ...       ...                               ...    ...
# 195       457.68  0.340066   C6H6_5710-TS18250 CON(1371,497)   2932
# 196       465.87  0.289973    C6H6_5710-TS18452 CON(819,794)   2947
# 197       457.68  0.341361    C6H6_5710-TS18452 CON(819,794)   2932
# 198       465.87  0.361245  C6H6_5710-TS18506 CON(1516,1193)   2947
# 199       457.68  0.361874  C6H6_5710-TS18506 CON(1516,1193)   2932
#
#                                             checkpoint  num_atoms
# 0    /misc/home/guest50/OAReactDiff/oa_reactdiff/tr...         12
# 1    /misc/home/guest50/OAReactDiff/oa_reactdiff/tr...         12
# 2    /misc/home/guest50/OAReactDiff/oa_reactdiff/tr...         12
# 3    /misc/home/guest50/OAReactDiff/oa_reactdiff/tr...         12
# 4    /misc/home/guest50/OAReactDiff/oa_reactdiff/tr...         12
# ..                                                 ...        ...
# 195  /misc/home/guest50/OAReactDiff/oa_reactdiff/tr...         12
# 196  /misc/home/guest50/OAReactDiff/oa_reactdiff/tr...         12
# 197  /misc/home/guest50/OAReactDiff/oa_reactdiff/tr...         12
# 198  /misc/home/guest50/OAReactDiff/oa_reactdiff/tr...         12
# 199  /misc/home/guest50/OAReactDiff/oa_reactdiff/tr...         12
#
# [200 rows x 6 columns]

# %%
df.plot(x="val-totloss", y="rmsd", kind="scatter")
# Out:
# <Axes: xlabel='val-totloss', ylabel='rmsd'>

# %%
df.plot(x="epoch", y="val-totloss", kind="scatter")
# Out:
# <Axes: xlabel='epoch', ylabel='val-totloss'>

# %%
df.plot(x="epoch", y="rmsd", kind="scatter")
# Out:
# <Axes: xlabel='epoch', ylabel='rmsd'>

# %%
import ase
from ase.io import read, write

# %%
output_dir
# Out:
# '/misc/home/guest50/OAReactDiff/results/sample_random_TS-20260703-C6H6-filtered_new-w_wo-w_wo-w_wo-vs_www_test'

# %%
# !ls -haltr /misc/home/guest50/OAReactDiff/results/sample_random_TS-20260703-C6H6-filtered_new-w_wo-w_wo-w_wo-vs_www_test
# Out:
# total 416K
# drwxr-xr-x 33 guest50 users 4.0K Jul  3 13:02 ..
# -rw-r--r--  1 guest50 users 3.4K Jul  3 18:23 C6H6_5710-TS142 CON(17,23).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:24 C6H6_5710-TS311 CON(130,131).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:24 C6H6_5710-TS340 CON(44,3).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:25 C6H6_5710-TS1133 CON(214,379).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:25 C6H6_5710-TS1933 CON(65,547).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:26 C6H6_5710-TS1966 CON(538,119).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:27 C6H6_5710-TS2088 CON(492,138).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:27 C6H6_5710-TS2290 CON(605,157).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:28 C6H6_5710-TS2312 CON(190,139).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:28 C6H6_5710-TS2564 CON(614,378).xyz
# -rw-r--r--  1 guest50 users 3.4K Jul  3 18:29 C6H6_5710-TS2578 CON(120,527).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:30 C6H6_5710-TS2944 CON(133,227).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:30 C6H6_5710-TS3164 CON(253,717).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:31 C6H6_5710-TS3979 CON(185,806).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:31 C6H6_5710-TS4302 CON(833,36).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:32 C6H6_5710-TS5356 CON(553,548).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:32 C6H6_5710-TS4346 CON(376,201).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:33 C6H6_5710-TS4418 CON(773,299).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:34 C6H6_5710-TS4988 CON(903,847).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:34 C6H6_5710-TS5211 CON(926,908).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:35 C6H6_5710-TS5550 CON(902,178).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:35 C6H6_5710-TS5946 CON(898,577).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:36 C6H6_5710-TS5984 CON(137,262).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:36 C6H6_5710-TS6004 CON(32,979).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:37 C6H6_5710-TS6040 CON(219,777).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:38 C6H6_5710-TS6049 CON(541,48).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:38 C6H6_5710-TS6524 CON(102,433).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:39 C6H6_5710-TS7004 CON(1032,1054).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:39 C6H6_5710-TS8100 CON(617,545).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:40 C6H6_5710-TS7603 CON(132,22).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:41 C6H6_5710-TS12907 CON(198,114).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:41 C6H6_5710-TS7912 CON(1083,268).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:42 C6H6_5710-TS7916 CON(650,20).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:42 C6H6_5710-TS8562 CON(142,557).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:43 C6H6_5710-TS16290 CON(676,761).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:44 C6H6_5710-TS16410 CON(140,571).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:44 C6H6_5710-TS8875 CON(398,975).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:45 C6H6_5710-TS8926 CON(314,952).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:45 C6H6_5710-TS8947 CON(939,846).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:46 C6H6_5710-TS9205 CON(121,607).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:46 C6H6_5710-TS9247 CON(1184,381).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:47 C6H6_5710-TS9319 CON(1013,775).xyz
# -rw-r--r--  1 guest50 users 3.4K Jul  3 18:48 C6H6_5710-TS9359 CON(903,1194).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:48 C6H6_5710-TS18413 CON(948,727).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:49 C6H6_5710-TS9591 CON(159,162).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:49 C6H6_5710-TS9629 CON(1212,333).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:50 C6H6_5710-TS9844 CON(486,572).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:50 C6H6_5710-TS10302 CON(110,1241).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:51 C6H6_5710-TS10433 CON(67,22).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:51 C6H6_5710-TS10557 CON(499,856).xyz
# -rw-r--r--  1 guest50 users 3.4K Jul  3 18:52 C6H6_5710-TS15764 CON(1245,365).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:53 C6H6_5710-TS10708 CON(164,177).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:53 C6H6_5710-TS10805 CON(1181,446).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:54 C6H6_5710-TS10809 CON(253,110).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:54 C6H6_5710-TS11276 CON(63,547).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:55 C6H6_5710-TS11511 CON(220,343).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:56 C6H6_5710-TS11574 CON(178,370).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:56 C6H6_5710-TS11807 CON(289,1155).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:57 C6H6_5710-TS12566 CON(974,71).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:57 C6H6_5710-TS12614 CON(1056,430).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:58 C6H6_5710-TS12787 CON(243,139).xyz
# -rw-r--r--  1 guest50 users 3.4K Jul  3 18:58 C6H6_5710-TS12931 CON(606,1347).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 18:59 C6H6_5710-TS13097 CON(389,157).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 19:00 C6H6_5710-TS13273 CON(249,808).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 19:00 C6H6_5710-TS13411 CON(62,427).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 19:01 C6H6_5710-TS13743 CON(503,630).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 19:01 C6H6_5710-TS13811 CON(1002,1050).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 19:02 C6H6_5710-TS14184 CON(142,902).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 19:02 C6H6_5710-TS14400 CON(1394,535).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 19:03 C6H6_5710-TS14547 CON(98,3).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 19:04 C6H6_5710-TS14666 CON(1125,386).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 19:04 C6H6_5710-TS14690 CON(1274,1125).xyz
# -rw-r--r--  1 guest50 users 3.4K Jul  3 19:05 C6H6_5710-TS14954 CON(1307,1211).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 19:05 C6H6_5710-TS15016 CON(95,1419).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 19:06 C6H6_5710-TS15178 CON(168,1024).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 19:06 C6H6_5710-TS15285 CON(601,1426).xyz
# -rw-r--r--  1 guest50 users 3.4K Jul  3 19:07 C6H6_5710-TS15397 CON(1198,822).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 19:07 C6H6_5710-TS15459 CON(286,415).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 19:08 C6H6_5710-TS15573 CON(998,1441).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 19:09 C6H6_5710-TS15587 CON(277,921).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 19:09 C6H6_5710-TS15699 CON(615,939).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 19:10 C6H6_5710-TS15759 CON(255,99).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 19:10 C6H6_5710-TS15826 CON(384,332).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 19:11 C6H6_5710-TS16198 CON(565,400).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 19:11 C6H6_5710-TS16282 CON(106,12).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 19:12 C6H6_5710-TS16287 CON(103,39).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 19:13 C6H6_5710-TS18222 CON(74,853).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 19:13 C6H6_5710-TS16713 CON(372,741).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 19:14 C6H6_5710-TS16905 CON(1015,289).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 19:14 C6H6_5710-TS17166 CON(322,176).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 19:15 C6H6_5710-TS17434 CON(185,1180).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 19:16 C6H6_5710-TS17607 CON(336,856).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 19:16 C6H6_5710-TS17622 CON(669,1422).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 19:17 C6H6_5710-TS17973 CON(27,447).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 19:17 C6H6_5710-TS17985 CON(379,727).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 19:18 C6H6_5710-TS18020 CON(365,1509).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 19:18 C6H6_5710-TS18187 CON(558,316).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 19:19 C6H6_5710-TS18250 CON(1371,497).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 19:20 C6H6_5710-TS18452 CON(819,794).xyz
# -rw-r--r--  1 guest50 users 3.3K Jul  3 19:20 C6H6_5710-TS18506 CON(1516,1193).xyz
# drwxr-xr-x  2 guest50 users 8.0K Jul  3 19:20 .

# %%
atoms = read(output_dir+'/C6H6_5710-TS18506 CON(1516,1193).xyz', format='xyz',index=":")

# %%
atoms[1]
# Out:
# Atoms(symbols='C6H6', pbc=False)

# %%
from io import StringIO

def atoms_to_xyz_str(atoms: ase.Atoms):
    f = StringIO()
    atoms.write(f, format="xyz")
    return f.getvalue()

# %%
xyz_01 = atoms_to_xyz_str(atoms[1])
print(xyz_01)
# Out:
# 12
#
# C      -0.054443657000000     -0.316673520000000     -1.075403700000000
# C      -0.972436300000000      0.500757000000000     -0.133349730000000
# C       1.241276500000000     -0.243651120000000     -0.264512750000000
# C      -0.872122760000000     -0.915177900000000      0.065624654000000
# C       0.195638780000000     -0.147683130000000      0.874685300000000
# C      -0.251620100000000      0.910428400000000      1.659655000000000
# H      -1.766844900000000      1.233053900000000     -0.259255020000000
# H       1.884471800000000      0.643204570000000     -0.403276980000000
# H       0.551592100000000      1.680824000000000      1.703540200000000
# H       1.828601000000000     -1.177729000000000     -0.265794130000000
# H      -1.575790600000000     -1.724579500000000      0.251787840000000
# H      -0.208321690000000     -0.442773800000000     -2.153700400000000

# %%
draw_in_3dmol(xyz_01)
# Out:
# <div id="3dmolviewer_17830826120047963"  style="position: relative; width: 576px; height: 480px;">
#         <p id="3dmolwarning_17830826120047963" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.4.2/3Dmol-min.js');
# }
#
# var viewer_17830826120047963 = null;
# var warn = document.getElementById("3dmolwarning_17830826120047963");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17830826120047963 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17830826120047963"),{backgroundColor:"white"});
# $3Dmol.download("1024", viewer_17830826120047963, {}, function() {
# viewer_17830826120047963.zoomTo();
# 	viewer_17830826120047963.addModel("12\n\nC      -0.054443657000000     -0.316673520000000     -1.075403700000000\nC      -0.972436300000000      0.500757000000000     -0.133349730000000\nC       1.241276500000000     -0.243651120000000     -0.264512750000000\nC      -0.872122760000000     -0.915177900000000      0.065624654000000\nC       0.195638780000000     -0.147683130000000      0.874685300000000\nC      -0.251620100000000      0.910428400000000      1.659655000000000\nH      -1.766844900000000      1.233053900000000     -0.259255020000000\nH       1.884471800000000      0.643204570000000     -0.403276980000000\nH       0.551592100000000      1.680824000000000      1.703540200000000\nH       1.828601000000000     -1.177729000000000     -0.265794130000000\nH      -1.575790600000000     -1.724579500000000      0.251787840000000\nH      -0.208321690000000     -0.442773800000000     -2.153700400000000\n","xyz");
# 	viewer_17830826120047963.setStyle({"stick": {}, "sphere": {"radius": 0.36}});
# 	viewer_17830826120047963.zoomTo();
# viewer_17830826120047963.render();
# })
# });
# </script>

# %%
draw_in_3dmol(atoms_to_xyz_str(atoms[-1]))
