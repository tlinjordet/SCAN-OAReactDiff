# %% [markdown]
# # Helper functions (and examples) to align (and view) molecules

# %%
from pymatgen.core import Molecule
from pymatgen.analysis import molecule_matcher

def align(base_atoms, target_atoms, threshold=0.5, allow_inversion=True, verbose=False):
    if verbose: print('Generating Pymatgen molecules from ASE atoms')
    target = Molecule.from_ase_atoms(target_atoms)
    base = Molecule.from_ase_atoms(base_atoms)
    if allow_inversion:
        inverted_base_atoms = base_atoms.copy()
        inverted_base_atoms.positions *= -1
        inverted_base = Molecule.from_ase_atoms(inverted_base_atoms)
    
    # Get initial guess
    if verbose: print('Computing initial guess via cheap and naive alignment')
    matcher_guess = molecule_matcher.HungarianOrderMatcher(target)
    aligned_guess, rmsd_guess = matcher_guess.fit(base)
    if allow_inversion:
        alt_aligned_guess, alt_rmsd_guess = matcher_guess.fit(inverted_base)
        # Swap structures if inversion yields better RMSD
        swap = (alt_rmsd_guess < rmsd_guess)
        if swap:
            rmsd_guess, alt_rmsd_guess = alt_rmsd_guess, rmsd_guess
            aligned_guess, alt_aligned_guess = alt_aligned_guess, aligned_guess
    if verbose: print(f'Hungarian-based alignment yielded: iRMSD={rmsd_guess}') 
    
    # Exact matcher
    effective_threshold = min(rmsd_guess+1e-3, threshold)
    if verbose: print(f'Attempting exact match with iRMSD threshold: {effective_threshold}')
    matcher = molecule_matcher.GeneticOrderMatcher(target, threshold=effective_threshold)
    results = matcher.fit(aligned_guess)
    
    # Extract best result
    if not results:
        results = [(aligned_guess, rmsd_guess)]
    aligned, rmsd = min(results, key=lambda x:x[-1])

    # Try alignment with alternative structure
    if allow_inversion:
        effective_threshold = min(rmsd+1e-3, threshold)
        if verbose: print(f'Re-attempting exact match w/wo inversion with iRMSD threshold: {effective_threshold}')
        matcher.threshold = effective_threshold
        alt_results = matcher.fit(alt_aligned_guess)
        if not alt_results:
            alt_results = [(alt_aligned_guess, alt_rmsd_guess)]
        alt_aligned, alt_rmsd = min(alt_results, key=lambda x:x[-1])
        # Report w/wo inversion
        if (alt_rmsd < rmsd) ^ swap:
            print('Info: Best alignment requires inversion/reflection')
        # Swap results if alternative yields better RMSD
        if alt_rmsd < rmsd:
            rmsd, alt_rmsd = alt_rmsd, rmsd
            aligned, alt_aligned = alt_aligned, aligned
    
    if rmsd <= threshold:
        if verbose: print(f'Best alignment found with iRMSD={rmsd}')
    else:
        if verbose: print(f'Could not find alignment below iRMSD threshold {threshold}')
        rmsd = None
    return(aligned.to_ase_atoms(), rmsd)

# %%
def get_baseline_threshold(ts_ref, reactant_ref, product_ref, threshold=float('inf'), verbose=False, strict=True):
    # Align reactants with TS
    aligned_reactants, rmsd_reactants = align(reactant_ref, ts_ref, threshold=threshold, verbose=verbose)

    # Align products with TS, using improved threshold guess
    if strict:
        effective_threshold = min(threshold, rmsd_reactants+1e-3) if rmsd_reactants is not None else threshold
    else:
        effective_threshold = threshold
    aligned_products, rmsd_products = align(product_ref, ts_ref, threshold=effective_threshold, verbose=verbose)

    # Compile adapted threshold
    all_baseline_thresholds = [rmsd+1e-3 for rmsd in [rmsd_reactants, rmsd_products] if rmsd is not None]
    if len(all_baseline_thresholds) == 0:
        baseline_threshold = None
    else:
        baseline_threshold = min(all_baseline_thresholds) if strict else max(all_baseline_thresholds) 
    return(baseline_threshold, aligned_reactants, aligned_products)

# %%
def extract_comments(atoms):
    comments = ' '.join(key if value is True else key+'='+value for key, value in atoms.info.items())
    return(comments)

# %%
import ase.io

def write_all_aligned(input_path, output_path, index_target=0, threshold=0.5, allow_inversion=True, verbose=False):
    if verbose: print(f'Reading geometries from {input_path}')
    all_atoms = ase.io.read(input_path, index=':')

    if verbose: print(f'Aligning all {len(all_atoms)} geometries found, w.r.t. to geometry {index_target}, using threshold {threshold}')
    target = all_atoms[index_target]
    all_comments = []
    for current_index, atoms in enumerate(all_atoms):
        # Extract comments
        comments = extract_comments(atoms)
        
        # Skip if reference geometry
        if current_index == index_target:
            all_comments.append(comments)
            continue

        # Compute and save aligned geometry
        aligned, rmsd = align(atoms, target, threshold=threshold, allow_inversion=allow_inversion, verbose=verbose)
        all_atoms[current_index] = aligned
        all_comments.append(f'{comments} (iRMSD={rmsd})')

    if verbose: print(f'Writing all {len(all_atoms)} aligned geometries to {output_path}')
    for current_index, (atoms, comment) in enumerate(zip(all_atoms, all_comments)):
        ase.io.write(output_path, atoms, comment=comment, append=(current_index > 0))

def write_all_aligned_opt(input_path, output_path, index_ts=1, index_reactants=0, index_products=2, threshold=float('inf'), strict_baseline=True, allow_inversion=True, verbose=False):
    if verbose: print(f'Reading geometries from {input_path}')
    all_atoms = ase.io.read(input_path, index=':')
    if verbose: print(f'Found {len(all_atoms)} geometries')

    if verbose: print(f'Estimate optimal threshold from EQ endpoints: {index_reactants} ← {index_ts} → {index_products}')
    ts = all_atoms[index_ts]
    reactants = all_atoms[index_reactants]
    products = all_atoms[index_products]
    baseline_threshold, aligned_reactants, aligned_products = get_baseline_threshold(ts, reactants, products, threshold=threshold, strict=strict_baseline, verbose=verbose)
    if baseline_threshold is None:
        print(f'Could not find EQ/TS alignment below given threshold {threshold}, using this threshold instead')
        baseline_threshold = threshold

    if verbose: print(f'Aligning all remaining geometries found, w.r.t. to geometry {index_ts}, using optimal threshold {baseline_threshold}')
    all_atoms[index_reactants] = aligned_reactants
    all_atoms[index_products] = aligned_products
    pre_aligned_idx = set([index_ts, index_reactants, index_products])
    all_comments = []
    for current_index, atoms in enumerate(all_atoms):
        # Extract comments
        comments = extract_comments(atoms)
        if verbose:
            print(f'Processing structure n°{current_index}')
        
        # Skip if pre-aligned geometry
        if current_index in pre_aligned_idx:
            all_comments.append(comments)
            continue

        # Compute and save aligned geometry
        aligned, rmsd = align(atoms, ts, threshold=baseline_threshold, allow_inversion=allow_inversion, verbose=verbose)
        all_atoms[current_index] = aligned
        all_comments.append(f'{comments} (iRMSD={rmsd})')

    output_path = output_path.replace('{baseline}', f'{baseline_threshold:.2f}')
    if verbose: print(f'Writing all {len(all_atoms)} aligned geometries to {output_path}')
    for current_index, (atoms, comment) in enumerate(zip(all_atoms, all_comments)):
        ase.io.write(output_path, atoms, comment=comment, append=(current_index > 0))

# %%
# conda install -c conda-forge ipywidgets nglview
from ase.visualize import view

def view_aligned(aligned, target):
    v = view(aligned+target, viewer='ngl')
    v.view.remove_spacefill()
    v.view.add_ball_and_stick(selection=range(len(aligned)), cylinderOnly=False, aspectRatio=3.0, radiusScale=0.2, radiusType='covalent')
    v.view.add_ball_and_stick(selection=range(len(aligned),len(aligned)+len(target)), cylinderOnly=False, aspectRatio=3.0, radiusScale=0.1, radiusType='covalent')
    return(v)

# %% [markdown]
# # Example on single pair for molecules to align and view

# %%
import ase.io

all_atoms = ase.io.read('results/sample_random_TS-20250903-C6H6-w_wo-w_wo-w_wo-vs_www_valid/10-TS11525.xyz', index=':')
target = all_atoms[1]
base = all_atoms[0]
base.positions *= 1
extract_comments(base)
# Out:
# 'True/calculated reference reactant state.'

# %%
aligned_base, rmsd = align(base, target, threshold=0.4, allow_inversion=False, verbose=True)
print(f'iRSMD={rmsd}')
# Out:
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7677818809076853
# Attempting exact match with iRMSD threshold: 0.4
# Best alignment found with iRMSD=0.28626536991733414
# iRSMD=0.28626536991733414

# %%
view_aligned(aligned_base, target)
# Out:
# HBox(children=(NGLWidget(), VBox(children=(Dropdown(description='Show', options=('All', 'H', 'C'), value='All'…

# %% [markdown]
# # Example to produce aligned XYZs

# %%
input_path = 'results/sample_random_TS-20250903-C6H6-w_wo-w_wo-w_wo-vs_www_valid/10-TS11525.xyz' # update
output_path = input_path.removesuffix('.xyz') + '_aligned.xyz'

write_all_aligned(input_path, output_path, index_target=1, threshold=0.5, verbose=True)
# Out:
# Reading geometries from results/sample_random_TS-20250903-C6H6-w_wo-w_wo-w_wo-vs_www_valid/10-TS11525.xyz
# Aligning all 21 geometries found, w.r.t. to geometry 1, using threshold 0.5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.4925647121407822
# Attempting exact match with iRMSD threshold: 0.4935647121407822
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.47271635704785103
# Best alignment found with iRMSD=0.28626536991733414
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.43926319165991967
# Attempting exact match with iRMSD threshold: 0.4402631916599197
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.4249364811169003
# Best alignment found with iRMSD=0.14430469554348968
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5986367736218337
# Attempting exact match with iRMSD threshold: 0.5
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.4079595483279604
# Best alignment found with iRMSD=0.4069595483279604
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.4142786483167965
# Attempting exact match with iRMSD threshold: 0.4152786483167965
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.40082835704410813
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.03265691318997912
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.4257197823468693
# Attempting exact match with iRMSD threshold: 0.4267197823468693
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.4146981719606257
# Best alignment found with iRMSD=0.058039755181258805
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.0325783299487666
# Attempting exact match with iRMSD threshold: 0.033578329948766604
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.03278321259977117
# Best alignment found with iRMSD=0.03178321259977117
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.06616318199632275
# Attempting exact match with iRMSD threshold: 0.06716318199632275
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.06437092299719574
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.06337092299719574
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.039641985859946785
# Attempting exact match with iRMSD threshold: 0.040641985859946786
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.04000885945354397
# Best alignment found with iRMSD=0.039008859453543966
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.03112834847214157
# Attempting exact match with iRMSD threshold: 0.03212834847214157
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.031043888716639947
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.030043888716639947
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.441706588674477
# Attempting exact match with iRMSD threshold: 0.442706588674477
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.42903187149584837
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.0824981723125266
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.040775806830760805
# Attempting exact match with iRMSD threshold: 0.041775806830760806
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.041189730102463226
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.040189730102463225
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.8368120952007781
# Attempting exact match with iRMSD threshold: 0.5
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.410364181680274
# Best alignment found with iRMSD=0.03714274354960966
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5630096538361045
# Attempting exact match with iRMSD threshold: 0.5
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3911184884514674
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.02440730594263365
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.058032196778789735
# Attempting exact match with iRMSD threshold: 0.059032196778789736
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.05604325318294215
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.05504325318294215
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.03876773365886172
# Attempting exact match with iRMSD threshold: 0.03976773365886172
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.03725188285923489
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.03625188285923489
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.42727673290697493
# Attempting exact match with iRMSD threshold: 0.42827673290697493
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.41425470415635546
# Best alignment found with iRMSD=0.03162580919002697
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5853162561637403
# Attempting exact match with iRMSD threshold: 0.5
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.4004712233512618
# Best alignment found with iRMSD=0.020356131095108972
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.41270044063913297
# Attempting exact match with iRMSD threshold: 0.41370044063913297
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.40294691977016334
# Best alignment found with iRMSD=0.02714915283609557
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5304634713297578
# Attempting exact match with iRMSD threshold: 0.5
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.46057443801753783
# Best alignment found with iRMSD=0.42489753174627315
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6658873397650416
# Attempting exact match with iRMSD threshold: 0.5
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.42860943971332377
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.10520891995205169
# Writing all 21 aligned geometries to results/sample_random_TS-20250903-C6H6-w_wo-w_wo-w_wo-vs_www_valid/10-TS11525_aligned.xyz

# %%
v = view_aligned(aligned_base, target)
v
# Out:
# HBox(children=(NGLWidget(), VBox(children=(Dropdown(description='Show', options=('All', 'H', 'C'), value='All'…

# %% [markdown]
# # Example to produce/view aligned XYZs (optimized)

# %%
import glob

for input_path in glob.glob('results/sample_random_TS-20250903-C6H6-w_wo-w_wo-w_wo-vs_www_valid/*[0-9].xyz'): # update
    # Use strict baseline
    output_path = input_path.removesuffix('.xyz') + '_aligned_baseline{baseline}_strict.xyz'
    write_all_aligned_opt(input_path, output_path, index_ts=1, index_reactants=0, index_products=2, threshold=1.0, strict_baseline=True, verbose=True)
    # Use loose baseline
    output_path = input_path.removesuffix('.xyz') + '_aligned_baseline{baseline}_loose.xyz'
    write_all_aligned_opt(input_path, output_path, index_ts=1, index_reactants=0, index_products=2, threshold=1.0, strict_baseline=False, verbose=True)
# Out:
# Reading geometries from results/sample_random_TS-20250903-C6H6-w_wo-w_wo-w_wo-vs_www_valid/10-TS3123.xyz
# Found 21 geometries
# Estimate optimal threshold from EQ endpoints: 0 ← 1 → 2
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6398661311500125
# Attempting exact match with iRMSD threshold: 0.6408661311500125
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.5245132284747197
# Best alignment found with iRMSD=0.23983321903856786
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.4507758728072866
# Attempting exact match with iRMSD threshold: 0.24083321903856786
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.24083321903856786
# Could not find alignment below iRMSD threshold 0.24083321903856786
# Aligning all remaining geometries found, w.r.t. to geometry 1, using optimal threshold 0.24083321903856786
# Processing structure n°0
# Processing structure n°1
# Processing structure n°2
# Processing structure n°3
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6481635482320395
# Attempting exact match with iRMSD threshold: 0.24083321903856786
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.24083321903856786
# Could not find alignment below iRMSD threshold 0.24083321903856786
# Processing structure n°4
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.32449667895289
# Attempting exact match with iRMSD threshold: 0.24083321903856786
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.24083321903856786
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.24083321903856786
# Processing structure n°5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6065089884532481
# Attempting exact match with iRMSD threshold: 0.24083321903856786
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.11654709443751936
# Best alignment found with iRMSD=0.11554709443751936
# Processing structure n°6
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7682772711821332
# Attempting exact match with iRMSD threshold: 0.24083321903856786
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.24083321903856786
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.24083321903856786
# Processing structure n°7
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.8404460486579778
# Attempting exact match with iRMSD threshold: 0.24083321903856786
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.24083321903856786
# Could not find alignment below iRMSD threshold 0.24083321903856786
# Processing structure n°8
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6474449237355258
# Attempting exact match with iRMSD threshold: 0.24083321903856786
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.24083321903856786
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.24083321903856786
# Processing structure n°9
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7774411760750789
# Attempting exact match with iRMSD threshold: 0.24083321903856786
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.24083321903856786
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.115370180983166
# Processing structure n°10
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7377607558584731
# Attempting exact match with iRMSD threshold: 0.24083321903856786
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.19469175178303216
# Best alignment found with iRMSD=0.19369175178303216
# Processing structure n°11
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.33712892453084986
# Attempting exact match with iRMSD threshold: 0.24083321903856786
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.24083321903856786
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.24083321903856786
# Processing structure n°12
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5120859442165053
# Attempting exact match with iRMSD threshold: 0.24083321903856786
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.24083321903856786
# Could not find alignment below iRMSD threshold 0.24083321903856786
# Processing structure n°13
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6772827995626123
# Attempting exact match with iRMSD threshold: 0.24083321903856786
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.10512273173421012
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.10412273173421012
# Processing structure n°14
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.33351369275474096
# Attempting exact match with iRMSD threshold: 0.24083321903856786
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.24083321903856786
# Could not find alignment below iRMSD threshold 0.24083321903856786
# Processing structure n°15
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7303366046097337
# Attempting exact match with iRMSD threshold: 0.24083321903856786
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.24083321903856786
# Could not find alignment below iRMSD threshold 0.24083321903856786
# Processing structure n°16
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.17642956595604425
# Attempting exact match with iRMSD threshold: 0.17742956595604426
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.1711131530612093
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.1701131530612093
# Processing structure n°17
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7811599960634764
# Attempting exact match with iRMSD threshold: 0.24083321903856786
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.24083321903856786
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.19672720454515685
# Processing structure n°18
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7021552966896488
# Attempting exact match with iRMSD threshold: 0.24083321903856786
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.24083321903856786
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.15707320622820295
# Processing structure n°19
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6565757114687291
# Attempting exact match with iRMSD threshold: 0.24083321903856786
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.24083321903856786
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.24083321903856786
# Processing structure n°20
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.35122177899550794
# Attempting exact match with iRMSD threshold: 0.24083321903856786
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.24083321903856786
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.24083321903856786
# Writing all 21 aligned geometries to results/sample_random_TS-20250903-C6H6-w_wo-w_wo-w_wo-vs_www_valid/10-TS3123_aligned_baseline0.24_strict.xyz
# Reading geometries from results/sample_random_TS-20250903-C6H6-w_wo-w_wo-w_wo-vs_www_valid/10-TS3123.xyz
# Found 21 geometries
# Estimate optimal threshold from EQ endpoints: 0 ← 1 → 2
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6398661311500125
# Attempting exact match with iRMSD threshold: 0.6408661311500125
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.5245132284747197
# Best alignment found with iRMSD=0.23983321903856786
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.4507758728072866
# Attempting exact match with iRMSD threshold: 0.4517758728072866
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3946201134103617
# Best alignment found with iRMSD=0.3936201134103617
# Aligning all remaining geometries found, w.r.t. to geometry 1, using optimal threshold 0.3946201134103617
# Processing structure n°0
# Processing structure n°1
# Processing structure n°2
# Processing structure n°3
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6481635482320395
# Attempting exact match with iRMSD threshold: 0.3946201134103617
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3946201134103617
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.3297668765393746
# Processing structure n°4
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.32449667895289
# Attempting exact match with iRMSD threshold: 0.32549667895289003
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3244919435701656
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.3234919435701656
# Processing structure n°5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6065089884532481
# Attempting exact match with iRMSD threshold: 0.3946201134103617
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.11654709443751936
# Best alignment found with iRMSD=0.11554709443751936
# Processing structure n°6
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7682772711821332
# Attempting exact match with iRMSD threshold: 0.3946201134103617
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3946201134103617
# Best alignment found with iRMSD=0.29489850284548225
# Processing structure n°7
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.8404460486579778
# Attempting exact match with iRMSD threshold: 0.3946201134103617
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3946201134103617
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.32940334002022287
# Processing structure n°8
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6474449237355258
# Attempting exact match with iRMSD threshold: 0.3946201134103617
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.33524425327853774
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.33424425327853774
# Processing structure n°9
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7774411760750789
# Attempting exact match with iRMSD threshold: 0.3946201134103617
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3946201134103617
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.115370180983166
# Processing structure n°10
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7377607558584731
# Attempting exact match with iRMSD threshold: 0.3946201134103617
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.19469175178303216
# Best alignment found with iRMSD=0.19369175178303216
# Processing structure n°11
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.33712892453084986
# Attempting exact match with iRMSD threshold: 0.33812892453084986
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3298708520312351
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.3288708520312351
# Processing structure n°12
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5120859442165053
# Attempting exact match with iRMSD threshold: 0.3946201134103617
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3946201134103617
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.3239293469762245
# Processing structure n°13
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6772827995626123
# Attempting exact match with iRMSD threshold: 0.3946201134103617
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.10512273173421012
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.10412273173421012
# Processing structure n°14
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.33351369275474096
# Attempting exact match with iRMSD threshold: 0.33451369275474097
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3335624933012948
# Best alignment found with iRMSD=0.3325624933012948
# Processing structure n°15
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7303366046097337
# Attempting exact match with iRMSD threshold: 0.3946201134103617
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3946201134103617
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.3355638308741669
# Processing structure n°16
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.17642956595604425
# Attempting exact match with iRMSD threshold: 0.17742956595604426
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.1711131530612093
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.1701131530612093
# Processing structure n°17
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7811599960634764
# Attempting exact match with iRMSD threshold: 0.3946201134103617
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3946201134103617
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.19672720454515685
# Processing structure n°18
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7021552966896488
# Attempting exact match with iRMSD threshold: 0.3946201134103617
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3946201134103617
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.15707320622820295
# Processing structure n°19
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6565757114687291
# Attempting exact match with iRMSD threshold: 0.3946201134103617
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3946201134103617
# Best alignment found with iRMSD=0.33588795130410615
# Processing structure n°20
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.35122177899550794
# Attempting exact match with iRMSD threshold: 0.35222177899550794
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.34320914818983644
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.34220914818983644
# Writing all 21 aligned geometries to results/sample_random_TS-20250903-C6H6-w_wo-w_wo-w_wo-vs_www_valid/10-TS3123_aligned_baseline0.39_loose.xyz
# Reading geometries from results/sample_random_TS-20250903-C6H6-w_wo-w_wo-w_wo-vs_www_valid/10-TS4444.xyz
# Found 21 geometries
# Estimate optimal threshold from EQ endpoints: 0 ← 1 → 2
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.4442054151836335
# Attempting exact match with iRMSD threshold: 0.4452054151836335
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.37725880499192826
# Best alignment found with iRMSD=0.3065514765838927
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5486626912606711
# Attempting exact match with iRMSD threshold: 0.3075514765838927
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3075514765838927
# Could not find alignment below iRMSD threshold 0.3075514765838927
# Aligning all remaining geometries found, w.r.t. to geometry 1, using optimal threshold 0.3075514765838927
# Processing structure n°0
# Processing structure n°1
# Processing structure n°2
# Processing structure n°3
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5569301061528612
# Attempting exact match with iRMSD threshold: 0.3075514765838927
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3075514765838927
# Best alignment found with iRMSD=0.03964007752971624
# Processing structure n°4
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7237562101184446
# Attempting exact match with iRMSD threshold: 0.3075514765838927
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3075514765838927
# Best alignment found with iRMSD=0.0651766968130039
# Processing structure n°5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.22839961378540594
# Attempting exact match with iRMSD threshold: 0.22939961378540594
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.030292366017143777
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.029292366017143776
# Processing structure n°6
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.25764902500375
# Attempting exact match with iRMSD threshold: 0.25864902500375
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.25284118180618437
# Best alignment found with iRMSD=0.25184118180618437
# Processing structure n°7
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.35722161270488234
# Attempting exact match with iRMSD threshold: 0.3075514765838927
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.27835767466613925
# Best alignment found with iRMSD=0.27735767466613925
# Processing structure n°8
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5633369304095021
# Attempting exact match with iRMSD threshold: 0.3075514765838927
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3075514765838927
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.029030783094553737
# Processing structure n°9
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.8103624019948121
# Attempting exact match with iRMSD threshold: 0.3075514765838927
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.2512017579389335
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.2502017579389335
# Processing structure n°10
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.47467913105145015
# Attempting exact match with iRMSD threshold: 0.3075514765838927
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.22462196355411043
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.22362196355411043
# Processing structure n°11
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.573478278815527
# Attempting exact match with iRMSD threshold: 0.3075514765838927
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3075514765838927
# Best alignment found with iRMSD=0.031431473458567685
# Processing structure n°12
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5532427033977154
# Attempting exact match with iRMSD threshold: 0.3075514765838927
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3075514765838927
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.019331009671568623
# Processing structure n°13
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.0693773851214513
# Attempting exact match with iRMSD threshold: 0.0703773851214513
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.06869815718849114
# Best alignment found with iRMSD=0.06769815718849113
# Processing structure n°14
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.569742055249382
# Attempting exact match with iRMSD threshold: 0.3075514765838927
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3075514765838927
# Best alignment found with iRMSD=0.01785487144281957
# Processing structure n°15
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5003820288631226
# Attempting exact match with iRMSD threshold: 0.3075514765838927
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3075514765838927
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.0748411511287646
# Processing structure n°16
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5300192225519634
# Attempting exact match with iRMSD threshold: 0.3075514765838927
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3075514765838927
# Best alignment found with iRMSD=0.11246713020452044
# Processing structure n°17
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.24337807497482403
# Attempting exact match with iRMSD threshold: 0.24437807497482403
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.12088830170586964
# Best alignment found with iRMSD=0.11988830170586964
# Processing structure n°18
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5482047801079177
# Attempting exact match with iRMSD threshold: 0.3075514765838927
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3075514765838927
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.10274580637969705
# Processing structure n°19
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.767904974111493
# Attempting exact match with iRMSD threshold: 0.3075514765838927
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3075514765838927
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.25387748554960154
# Processing structure n°20
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.03988969347480681
# Attempting exact match with iRMSD threshold: 0.04088969347480681
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.03976568249166368
# Best alignment found with iRMSD=0.03876568249166368
# Writing all 21 aligned geometries to results/sample_random_TS-20250903-C6H6-w_wo-w_wo-w_wo-vs_www_valid/10-TS4444_aligned_baseline0.31_strict.xyz
# Reading geometries from results/sample_random_TS-20250903-C6H6-w_wo-w_wo-w_wo-vs_www_valid/10-TS4444.xyz
# Found 21 geometries
# Estimate optimal threshold from EQ endpoints: 0 ← 1 → 2
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.4442054151836335
# Attempting exact match with iRMSD threshold: 0.4452054151836335
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.37725880499192826
# Best alignment found with iRMSD=0.3065514765838927
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5486626912606711
# Attempting exact match with iRMSD threshold: 0.5496626912606711
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.5006815358539688
# Best alignment found with iRMSD=0.49968153585396885
# Aligning all remaining geometries found, w.r.t. to geometry 1, using optimal threshold 0.5006815358539688
# Processing structure n°0
# Processing structure n°1
# Processing structure n°2
# Processing structure n°3
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5569301061528612
# Attempting exact match with iRMSD threshold: 0.5006815358539688
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.4879660154356364
# Best alignment found with iRMSD=0.03964007752971624
# Processing structure n°4
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7237562101184446
# Attempting exact match with iRMSD threshold: 0.5006815358539688
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.4697859346247087
# Best alignment found with iRMSD=0.0651766968130039
# Processing structure n°5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.22839961378540594
# Attempting exact match with iRMSD threshold: 0.22939961378540594
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.030292366017143777
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.029292366017143776
# Processing structure n°6
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.25764902500375
# Attempting exact match with iRMSD threshold: 0.25864902500375
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.25284118180618437
# Best alignment found with iRMSD=0.25184118180618437
# Processing structure n°7
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.35722161270488234
# Attempting exact match with iRMSD threshold: 0.35822161270488234
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.27835767466613925
# Best alignment found with iRMSD=0.27735767466613925
# Processing structure n°8
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5633369304095021
# Attempting exact match with iRMSD threshold: 0.5006815358539688
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.48273248360906085
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.029030783094553737
# Processing structure n°9
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.8103624019948121
# Attempting exact match with iRMSD threshold: 0.5006815358539688
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.2512017579389335
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.2502017579389335
# Processing structure n°10
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.47467913105145015
# Attempting exact match with iRMSD threshold: 0.47567913105145015
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.22462196355411043
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.22362196355411043
# Processing structure n°11
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.573478278815527
# Attempting exact match with iRMSD threshold: 0.5006815358539688
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.4843832488923077
# Best alignment found with iRMSD=0.031431473458567685
# Processing structure n°12
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5532427033977154
# Attempting exact match with iRMSD threshold: 0.5006815358539688
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.4873632035456831
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.019331009671568623
# Processing structure n°13
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.0693773851214513
# Attempting exact match with iRMSD threshold: 0.0703773851214513
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.06869815718849114
# Best alignment found with iRMSD=0.06769815718849113
# Processing structure n°14
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.569742055249382
# Attempting exact match with iRMSD threshold: 0.5006815358539688
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.489718478677792
# Best alignment found with iRMSD=0.01785487144281957
# Processing structure n°15
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5003820288631226
# Attempting exact match with iRMSD threshold: 0.5006815358539688
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.4893848734788446
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.0748411511287646
# Processing structure n°16
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5300192225519634
# Attempting exact match with iRMSD threshold: 0.5006815358539688
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.47043756966937417
# Best alignment found with iRMSD=0.11246713020452044
# Processing structure n°17
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.24337807497482403
# Attempting exact match with iRMSD threshold: 0.24437807497482403
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.12088830170586964
# Best alignment found with iRMSD=0.11988830170586964
# Processing structure n°18
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5482047801079177
# Attempting exact match with iRMSD threshold: 0.5006815358539688
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.48834245909633256
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.10274580637969705
# Processing structure n°19
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.767904974111493
# Attempting exact match with iRMSD threshold: 0.5006815358539688
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.43931885855164177
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.25387748554960154
# Processing structure n°20
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.03988969347480681
# Attempting exact match with iRMSD threshold: 0.04088969347480681
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.03976568249166368
# Best alignment found with iRMSD=0.03876568249166368
# Writing all 21 aligned geometries to results/sample_random_TS-20250903-C6H6-w_wo-w_wo-w_wo-vs_www_valid/10-TS4444_aligned_baseline0.50_loose.xyz
# Reading geometries from results/sample_random_TS-20250903-C6H6-w_wo-w_wo-w_wo-vs_www_valid/10-TS5348.xyz
# Found 21 geometries
# Estimate optimal threshold from EQ endpoints: 0 ← 1 → 2
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.29927744167770204
# Attempting exact match with iRMSD threshold: 0.30027744167770204
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.2898679615017096
# Best alignment found with iRMSD=0.2888679615017096
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.17514988812481716
# Attempting exact match with iRMSD threshold: 0.17614988812481716
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.16517981294157946
# Best alignment found with iRMSD=0.16417981294157946
# Aligning all remaining geometries found, w.r.t. to geometry 1, using optimal threshold 0.16517981294157946
# Processing structure n°0
# Processing structure n°1
# Processing structure n°2
# Processing structure n°3
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6655938266007893
# Attempting exact match with iRMSD threshold: 0.16517981294157946
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.03585518123565377
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.034855181235653766
# Processing structure n°4
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.034267654417515975
# Attempting exact match with iRMSD threshold: 0.035267654417515976
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.03457597155285864
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.03357597155285864
# Processing structure n°5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6107257090929209
# Attempting exact match with iRMSD threshold: 0.16517981294157946
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.16517981294157946
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.16517981294157946
# Processing structure n°6
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.4323144219409115
# Attempting exact match with iRMSD threshold: 0.16517981294157946
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.16517981294157946
# Best alignment found with iRMSD=0.04461777881311554
# Processing structure n°7
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.4156410298643612
# Attempting exact match with iRMSD threshold: 0.16517981294157946
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.16517981294157946
# Could not find alignment below iRMSD threshold 0.16517981294157946
# Processing structure n°8
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.4281540866753062
# Attempting exact match with iRMSD threshold: 0.16517981294157946
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.16517981294157946
# Could not find alignment below iRMSD threshold 0.16517981294157946
# Processing structure n°9
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.4246279021073555
# Attempting exact match with iRMSD threshold: 0.16517981294157946
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.16517981294157946
# Could not find alignment below iRMSD threshold 0.16517981294157946
# Processing structure n°10
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6264442716770043
# Attempting exact match with iRMSD threshold: 0.16517981294157946
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.16517981294157946
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.16517981294157946
# Processing structure n°11
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.45519771067168746
# Attempting exact match with iRMSD threshold: 0.16517981294157946
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.16517981294157946
# Could not find alignment below iRMSD threshold 0.16517981294157946
# Processing structure n°12
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5771638996191986
# Attempting exact match with iRMSD threshold: 0.16517981294157946
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.16517981294157946
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.041240870663876494
# Processing structure n°13
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6151147334820354
# Attempting exact match with iRMSD threshold: 0.16517981294157946
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.16517981294157946
# Could not find alignment below iRMSD threshold 0.16517981294157946
# Processing structure n°14
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.4577143946831317
# Attempting exact match with iRMSD threshold: 0.16517981294157946
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.16517981294157946
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.01271838525145335
# Processing structure n°15
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.67965353539755
# Attempting exact match with iRMSD threshold: 0.16517981294157946
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.16517981294157946
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.04346397100047189
# Processing structure n°16
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.4272808383998345
# Attempting exact match with iRMSD threshold: 0.16517981294157946
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.16517981294157946
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.05287439444701775
# Processing structure n°17
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.028027162510087345
# Attempting exact match with iRMSD threshold: 0.029027162510087346
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.028682538899599958
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.027682538899599957
# Processing structure n°18
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.04541617537494489
# Attempting exact match with iRMSD threshold: 0.04641617537494489
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.04367030296066084
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.042670302960660836
# Processing structure n°19
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.8075284234705838
# Attempting exact match with iRMSD threshold: 0.16517981294157946
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.16517981294157946
# Could not find alignment below iRMSD threshold 0.16517981294157946
# Processing structure n°20
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7049839000161068
# Attempting exact match with iRMSD threshold: 0.16517981294157946
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.06595994495301988
# Best alignment found with iRMSD=0.06495994495301988
# Writing all 21 aligned geometries to results/sample_random_TS-20250903-C6H6-w_wo-w_wo-w_wo-vs_www_valid/10-TS5348_aligned_baseline0.17_strict.xyz
# Reading geometries from results/sample_random_TS-20250903-C6H6-w_wo-w_wo-w_wo-vs_www_valid/10-TS5348.xyz
# Found 21 geometries
# Estimate optimal threshold from EQ endpoints: 0 ← 1 → 2
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.29927744167770204
# Attempting exact match with iRMSD threshold: 0.30027744167770204
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.2898679615017096
# Best alignment found with iRMSD=0.2888679615017096
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.17514988812481716
# Attempting exact match with iRMSD threshold: 0.17614988812481716
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.16517981294157946
# Best alignment found with iRMSD=0.16417981294157946
# Aligning all remaining geometries found, w.r.t. to geometry 1, using optimal threshold 0.2898679615017096
# Processing structure n°0
# Processing structure n°1
# Processing structure n°2
# Processing structure n°3
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6655938266007893
# Attempting exact match with iRMSD threshold: 0.2898679615017096
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.03585518123565377
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.034855181235653766
# Processing structure n°4
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.034267654417515975
# Attempting exact match with iRMSD threshold: 0.035267654417515976
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.03457597155285864
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.03357597155285864
# Processing structure n°5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6107257090929209
# Attempting exact match with iRMSD threshold: 0.2898679615017096
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.2898679615017096
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.2898679615017096
# Processing structure n°6
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.4323144219409115
# Attempting exact match with iRMSD threshold: 0.2898679615017096
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.2898679615017096
# Best alignment found with iRMSD=0.04461777881311554
# Processing structure n°7
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.4156410298643612
# Attempting exact match with iRMSD threshold: 0.2898679615017096
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.2898679615017096
# Could not find alignment below iRMSD threshold 0.2898679615017096
# Processing structure n°8
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.4281540866753062
# Attempting exact match with iRMSD threshold: 0.2898679615017096
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.2898679615017096
# Could not find alignment below iRMSD threshold 0.2898679615017096
# Processing structure n°9
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.4246279021073555
# Attempting exact match with iRMSD threshold: 0.2898679615017096
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.2898679615017096
# Could not find alignment below iRMSD threshold 0.2898679615017096
# Processing structure n°10
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6264442716770043
# Attempting exact match with iRMSD threshold: 0.2898679615017096
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.2898679615017096
# Info: Best alignment requires inversion/reflection
# Could not find alignment below iRMSD threshold 0.2898679615017096
# Processing structure n°11
# ...
# Aligning all remaining geometries found, w.r.t. to geometry 1, using optimal threshold 0.3181181932149246
# Processing structure n°0
# Processing structure n°1
# Processing structure n°2
# Processing structure n°3
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5935544076592125
# Attempting exact match with iRMSD threshold: 0.3181181932149246
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3181181932149246
# Best alignment found with iRMSD=0.024854607332079386
# Processing structure n°4
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7703923197185509
# Attempting exact match with iRMSD threshold: 0.3181181932149246
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3181181932149246
# Best alignment found with iRMSD=0.03343519453971409
# Processing structure n°5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6134144899628576
# Attempting exact match with iRMSD threshold: 0.3181181932149246
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.10708441685350487
# Best alignment found with iRMSD=0.10608441685350486
# Processing structure n°6
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.03738635568127711
# Attempting exact match with iRMSD threshold: 0.03838635568127711
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.03794357705179616
# Best alignment found with iRMSD=0.036943577051796156
# Processing structure n°7
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.03084896675563745
# Attempting exact match with iRMSD threshold: 0.03184896675563745
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.029943332029290157
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.028943332029290156
# Processing structure n°8
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6546390567427625
# Attempting exact match with iRMSD threshold: 0.3181181932149246
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3181181932149246
# Could not find alignment below iRMSD threshold 0.3181181932149246
# Processing structure n°9
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.47879233011184685
# Attempting exact match with iRMSD threshold: 0.3181181932149246
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3181181932149246
# Best alignment found with iRMSD=0.03360722056236929
# Processing structure n°10
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.557969836640431
# Attempting exact match with iRMSD threshold: 0.3181181932149246
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3181181932149246
# Best alignment found with iRMSD=0.034252147002301295
# Processing structure n°11
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.31244433795485543
# Attempting exact match with iRMSD threshold: 0.31344433795485543
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.31344433795485543
# Best alignment found with iRMSD=0.31244433795485543
# Processing structure n°12
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6785444590394126
# Attempting exact match with iRMSD threshold: 0.3181181932149246
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3181181932149246
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.0241650655140009
# Processing structure n°13
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6409551166565916
# Attempting exact match with iRMSD threshold: 0.3181181932149246
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3181181932149246
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.017658684635172027
# Processing structure n°14
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6178545484095997
# Attempting exact match with iRMSD threshold: 0.3181181932149246
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3181181932149246
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.30032606931326383
# Processing structure n°15
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6945027758073636
# Attempting exact match with iRMSD threshold: 0.3181181932149246
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3181181932149246
# Could not find alignment below iRMSD threshold 0.3181181932149246
# Processing structure n°16
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5262528277365471
# Attempting exact match with iRMSD threshold: 0.3181181932149246
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3181181932149246
# Could not find alignment below iRMSD threshold 0.3181181932149246
# Processing structure n°17
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.01846115388073589
# Attempting exact match with iRMSD threshold: 0.019461153880735892
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.01842140254109421
# Best alignment found with iRMSD=0.01742140254109421
# Processing structure n°18
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.018085605582594692
# Attempting exact match with iRMSD threshold: 0.019085605582594693
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.018558798162426678
# Best alignment found with iRMSD=0.017558798162426677
# Processing structure n°19
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6516860136052129
# Attempting exact match with iRMSD threshold: 0.3181181932149246
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3181181932149246
# Best alignment found with iRMSD=0.10646573696536524
# Processing structure n°20
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7042479402234935
# Attempting exact match with iRMSD threshold: 0.3181181932149246
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3181181932149246
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.3092668701585479
# Writing all 21 aligned geometries to results/sample_random_TS-20250903-C6H6-w_wo-w_wo-w_wo-vs_www_valid/10-TS18020_aligned_baseline0.32_strict.xyz
# Reading geometries from results/sample_random_TS-20250903-C6H6-w_wo-w_wo-w_wo-vs_www_valid/10-TS18020.xyz
# Found 21 geometries
# Estimate optimal threshold from EQ endpoints: 0 ← 1 → 2
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6469533477909356
# Attempting exact match with iRMSD threshold: 0.6479533477909356
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.5249655209439671
# Best alignment found with iRMSD=0.3283690416464359
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.3263336515676891
# Attempting exact match with iRMSD threshold: 0.3273336515676891
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3181181932149246
# Best alignment found with iRMSD=0.3171181932149246
# Aligning all remaining geometries found, w.r.t. to geometry 1, using optimal threshold 0.3293690416464359
# Processing structure n°0
# Processing structure n°1
# Processing structure n°2
# Processing structure n°3
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5935544076592125
# Attempting exact match with iRMSD threshold: 0.3293690416464359
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3293690416464359
# Best alignment found with iRMSD=0.024854607332079386
# Processing structure n°4
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7703923197185509
# Attempting exact match with iRMSD threshold: 0.3293690416464359
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3293690416464359
# Best alignment found with iRMSD=0.03343519453971409
# Processing structure n°5
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6134144899628576
# Attempting exact match with iRMSD threshold: 0.3293690416464359
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.10708441685350487
# Best alignment found with iRMSD=0.10608441685350486
# Processing structure n°6
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.03738635568127711
# Attempting exact match with iRMSD threshold: 0.03838635568127711
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.03794357705179616
# Best alignment found with iRMSD=0.036943577051796156
# Processing structure n°7
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.03084896675563745
# Attempting exact match with iRMSD threshold: 0.03184896675563745
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.029943332029290157
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.028943332029290156
# Processing structure n°8
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6546390567427625
# Attempting exact match with iRMSD threshold: 0.3293690416464359
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3293690416464359
# Could not find alignment below iRMSD threshold 0.3293690416464359
# Processing structure n°9
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.47879233011184685
# Attempting exact match with iRMSD threshold: 0.3293690416464359
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3293690416464359
# Best alignment found with iRMSD=0.03360722056236929
# Processing structure n°10
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.557969836640431
# Attempting exact match with iRMSD threshold: 0.3293690416464359
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3293690416464359
# Best alignment found with iRMSD=0.034252147002301295
# Processing structure n°11
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.31244433795485543
# Attempting exact match with iRMSD threshold: 0.31344433795485543
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.31344433795485543
# Best alignment found with iRMSD=0.31244433795485543
# Processing structure n°12
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6785444590394126
# Attempting exact match with iRMSD threshold: 0.3293690416464359
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3293690416464359
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.0241650655140009
# Processing structure n°13
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6409551166565916
# Attempting exact match with iRMSD threshold: 0.3293690416464359
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3293690416464359
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.017658684635172027
# Processing structure n°14
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6178545484095997
# Attempting exact match with iRMSD threshold: 0.3293690416464359
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3293690416464359
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.30032606931326383
# Processing structure n°15
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6945027758073636
# Attempting exact match with iRMSD threshold: 0.3293690416464359
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3293690416464359
# Could not find alignment below iRMSD threshold 0.3293690416464359
# Processing structure n°16
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.5262528277365471
# Attempting exact match with iRMSD threshold: 0.3293690416464359
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3293690416464359
# Could not find alignment below iRMSD threshold 0.3293690416464359
# Processing structure n°17
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.01846115388073589
# Attempting exact match with iRMSD threshold: 0.019461153880735892
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.01842140254109421
# Best alignment found with iRMSD=0.01742140254109421
# Processing structure n°18
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.018085605582594692
# Attempting exact match with iRMSD threshold: 0.019085605582594693
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.018558798162426678
# Best alignment found with iRMSD=0.017558798162426677
# Processing structure n°19
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.6516860136052129
# Attempting exact match with iRMSD threshold: 0.3293690416464359
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3293690416464359
# Best alignment found with iRMSD=0.10646573696536524
# Processing structure n°20
# Generating Pymatgen molecules from ASE atoms
# Computing initial guess via cheap and naive alignment
# Hungarian-based alignment yielded: iRMSD=0.7042479402234935
# Attempting exact match with iRMSD threshold: 0.3293690416464359
# Re-attempting exact match w/wo inversion with iRMSD threshold: 0.3293690416464359
# Info: Best alignment requires inversion/reflection
# Best alignment found with iRMSD=0.3092668701585479
# Writing all 21 aligned geometries to results/sample_random_TS-20250903-C6H6-w_wo-w_wo-w_wo-vs_www_valid/10-TS18020_aligned_baseline0.33_loose.xyz

# %%
import ase.io

all_atoms = ase.io.read('results/sample_random_TS-20250903-C6H6-w_wo-w_wo-w_wo-vs_www_valid/10-TS11525_aligned_baseline0.15_strict.xyz', index=':')
target = all_atoms[1]
aligned_base = all_atoms[2]
extract_comments(aligned_base)
# Out:
# ''

# %%
view_aligned(aligned_base, target)
# Out:
# HBox(children=(NGLWidget(), VBox(children=(Dropdown(description='Show', options=('All', 'H', 'C'), value='All'…

# %%
# TODO add to comment which EQ is the chosen alignement reference.
# Iteratively fragment and align? bigger fragmentation cutoff to respect hydrogen bonds etc.
# RS: "Our RMSD is still ill defined." Something ilke this exists for e.g. protein?
# OR: every atom should have the same local environment -- TL: split into triangles
